# %% [markdown]
# # **Universidad Nacional de Colombia, Sede Bogotá**
# ## **Minería de Datos**
# ### **Prof. Elizabeth León G.**
# ### **Tema**: Avance 2 de proyecto
#
# # Presentado por:
# ###                Juan Andrés Caballero Martínez
# ###                Katherin Quintero Parra

# %% [markdown]
# En un principio se carga el conjunto de datos y se consulta el número de registros y de atributos

# %%
import pandas as pd 
import numpy as np
from scipy.stats import trim_mean
from numpy import mean, absolute
from random import randint, uniform,random

datos = pd.read_csv("./brain_stroke.csv")
print('Número de registros = %d' % (datos.shape[0]))
print('Número de atributos = %d' % (datos.shape[1]))
datos
# Out:
# Número de registros = 4981
# Número de atributos = 11
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0
#
# [4981 rows x 11 columns]

# %% [markdown]
# # 1.1) Rango de valores por atributo:

# %% [markdown]
# A continuación se calcula el rango de valores que pueden tomar cada uno de los atributos del conjunto de datos.

# %%
def mayormenor(dato):
  datomenor = dato[0]
  datomayor = dato[0]
  tamano = dato.shape[0]

  for i in range(0,tamano):
    dato_actual = dato[i]
    if dato_actual > datomayor:
      datomayor = dato_actual
    if dato_actual < datomenor:
      datomenor = dato_actual
  return datomenor, datomayor

# %% [markdown]
# Rango de valores para el atributo: 'age'

# %%
edad = datos['age']
edad_menor, edad_mayor = mayormenor(edad)
print("Edad menor: "+str(edad_menor))
print("Edad mayor: "+str(edad_mayor))
# Out:
# Edad menor: 0.08
# Edad mayor: 108.0

# %% [markdown]
# Rango de valores para el atributo: 'hypertension':
#
# Valores binarios, 0 o 1.

# %% [markdown]
# Rango de valores para el atributo: 'heart_disease':
#
# Valores binarios, 0 o 1.

# %% [markdown]
# Rango de valores para el atributo: 'ever_married':
#
# Valores binarios, 'Yes', 'NO'.

# %% [markdown]
# Rango de valores para el atributo: 'work_type':
#
# Valores categóricos: 'Private', 'Self-employed', 'Govt job', 'Children'

# %% [markdown]
# Rango de valores para el atributo: 'Residence-type':
#
# Valores binarios, 'Urban', 'Rural'.

# %% [markdown]
# Rango de valores para el atributo: 'avg_glucose_level':

# %%
glucosa = datos['avg_glucose_level']
glucosa_menor,glucosa_mayor = mayormenor(glucosa)
print("Glucosa menor: "+str(glucosa_menor))
print("Glucosa mayor: "+str(glucosa_mayor))
# Out:
# Glucosa menor: 55.12
# Glucosa mayor: 271.74

# %% [markdown]
# Rango de valores para el atributo: 'bmi':

# %%
bmi = datos['bmi']
bmi_menor,bmi_mayor = mayormenor(bmi)
print("BMI menor: "+str(bmi_menor))
print("BMI mayor: "+str(bmi_mayor))
# Out:
# BMI menor: 14.0
# BMI mayor: 48.9

# %% [markdown]
# Rango de valores para el atributo: 'smoking_status':
#
# Valores categóricos: 'formerly smoked', 'never smoked', 'smokes', 'Unknown'

# %% [markdown]
# Rango de valores para el atributo: 'stroke':
#
# Valores binarios, 0 o 1.

# %% [markdown]
# # 1.2) Identificación de valores perdidos
# Se consulta el número de valores perdidos por cada atributo del conjunto:

# %%
print('Número de valores perdidos por cada atributo:')
for col in datos.columns:
    print('\t%s: %d' % (col,datos[col].isna().sum()))
# Out:
# Número de valores perdidos por cada atributo:
# 	gender: 0
# 	age: 0
# 	hypertension: 0
# 	heart_disease: 0
# 	ever_married: 0
# 	work_type: 0
# 	Residence_type: 0
# 	avg_glucose_level: 0
# 	bmi: 0
# 	smoking_status: 0
# 	stroke: 0

# %% [markdown]
# Ya que no existen valores perdidos en el conjunto de datos, se colocarán de forma intencionada valores NA en las columnas de los registros. Los valores a eliminar fueron determinados de forma aleatoria previamente.

# %%
import math
aleatorio1 = [2, 80, 233, 392, 491, 577, 694, 729, 854, 908, 1010, 1132, 1293, 1365, 1499, 1591, 1643, 1721, 1835, 1908, 2050, 2184, 2251, 2301, 2498, 2516, 2681, 2755, 2800, 2931, 3015, 3167, 3201, 3352, 3477, 3510, 3618, 3700, 3845, 3913, 4001]
aleatorio2 = ['Residence_type', 'gender', 'hypertension', 'stroke', 'smoking_status', 'heart_disease', 'age', 'ever_married', 'bmi', 'avg_glucose_level', 'work_type']
for i in aleatorio1:
    j = i % 11
    res = aleatorio2[j]
    datos[res][i] = math.nan

datos
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\4153999325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos[res][i] = math.nan
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0           0.0            1.0          Yes        Private
# 1       Male  80.0           0.0            1.0          Yes        Private
# 2     Female  49.0           NaN            0.0          Yes        Private
# 3     Female  79.0           1.0            0.0          Yes  Self-employed
# 4       Male  81.0           0.0            0.0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0           0.0            0.0           No        Private
# 4977    Male  40.0           0.0            0.0          Yes        Private
# 4978  Female  45.0           1.0            0.0          Yes       Govt_job
# 4979    Male  40.0           0.0            0.0          Yes        Private
# 4980  Female  80.0           1.0            0.0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked     1.0
# 1             Rural             105.92  32.5     never smoked     1.0
# 2             Urban             171.23  34.4           smokes     1.0
# 3             Rural             174.12  24.0     never smoked     1.0
# 4             Urban             186.21  29.0  formerly smoked     1.0
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked     0.0
# 4977          Urban             191.15  31.1           smokes     0.0
# 4978          Rural              95.02  31.8           smokes     0.0
# 4979          Rural              83.94  30.0           smokes     0.0
# 4980          Urban              83.75  29.1     never smoked     0.0
#
# [4981 rows x 11 columns]

# %% [markdown]
# Ahora se consulta el nuevo reporte de valores perdidos en el conjunto de datos.

# %%
print('Número de valores perdidos por cada atributo:')
for col in datos.columns:
    print('\t%s: %d' % (col,datos[col].isna().sum()))
# Out:
# Número de valores perdidos por cada atributo:
# 	gender: 6
# 	age: 5
# 	hypertension: 3
# 	heart_disease: 5
# 	ever_married: 5
# 	work_type: 3
# 	Residence_type: 1
# 	avg_glucose_level: 2
# 	bmi: 5
# 	smoking_status: 3
# 	stroke: 3

# %% [markdown]
# Se puede apreciar que, para los distintos atributos que conforman el conjunto de datos, se reportan valores perdidos en la totalidad de dimensiones.

# %% [markdown]
# # 1.3) Tratamiento de valores perdidos

# %% [markdown]
# A continuación, se hará un reemplazo de los valores perdidos. Para ello, se calculará la moda para cada una de las dimensiones del conjunto de datos y se utilizará dicho valor como un representante de la dimensión; así, los valores perdidos serán reemplazados por el valor de la moda acorde a su dimensión.

# %%
import statistics as stat
#cálculo de moda para cada una de las dimensiones
#calculo para genero
gender = datos['gender']
gender_moda = stat.mode(gender)
#calculo para edad
age = datos['age']
age_moda = stat.mode(age)
#calculo para hipertension
hypertension = datos['hypertension']
hypertension_moda = stat.mode(hypertension)
#calculo para enfermedad del corazon
heart_disease = datos['heart_disease']
heart_disease_moda = stat.mode(heart_disease)
#calculo para estado civil
ever_married = datos['ever_married']
ever_married_moda = stat.mode(ever_married)
#calculo para tipo de trabajo
work_type = datos['work_type']
work_type_moda = stat.mode(work_type)
#calculo para tipo de residencia
Residence_type = datos['Residence_type']
Residence_type_moda = stat.mode(Residence_type)
#calculo para promedio de glucosa
avg_glucose_level = datos['avg_glucose_level']
avg_glucose_level_moda = stat.mode(avg_glucose_level)
#calculo de BMI
bmi = datos['bmi']
bmi_moda = stat.mode(bmi)
#calculo para estado de fumador
smoking_status = datos['smoking_status']
smoking_status_moda = stat.mode(smoking_status)
#calculo para estado de accidente cerebro-vascular
stroke = datos['stroke']
stroke_moda = stat.mode(stroke)

# %% [markdown]
# Ahora, se reemplazará cada valor NA con su correspondiente valor de moda

# %%
total = datos.shape[0]
dimensiones = ['gender','age','hypertension','heart_disease','ever_married','work_type','Residence_type','avg_glucose_level','bmi','smoking_status','stroke']
for i in range(0,total):
    #print("hola")
    for j in dimensiones:
        #print(j)
        if pd.isna(datos[j][i]):
            if j == 'gender':
                datos[j][i] = gender_moda
            elif j == 'hypertension':
                datos[j][i] = hypertension_moda
            elif j == 'heart_disease':
                datos[j][i] = heart_disease_moda
            elif j == 'ever_married':
                datos[j][i] = ever_married_moda
            elif j == 'work_type':
                datos[j][i] = work_type_moda
            elif j == 'age':
                datos[j][i] = age_moda
            elif j == 'Residence_type':
                datos[j][i] = Residence_type_moda
            elif j == 'avg_glucose_level':
                datos[j][i] = avg_glucose_level_moda
            elif j == 'bmi':
                datos[j][i] = bmi_moda
            elif j == 'smoking_status':
                datos[j][i] = smoking_status_moda
            elif j == 'stroke':
                datos[j][i] = stroke_moda
datos
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\127214838.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos[j][i] = ever_married_moda
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\127214838.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos[j][i] = gender_moda
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\127214838.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos[j][i] = age_moda
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\127214838.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos[j][i] = avg_glucose_level_moda
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\127214838.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos[j][i] = work_type_moda
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\127214838.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos[j][i] = smoking_status_moda
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\127214838.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos[j][i] = bmi_moda
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\127214838.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos[j][i] = Residence_type_moda
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0           0.0            1.0          Yes        Private
# 1       Male  80.0           0.0            1.0          Yes        Private
# 2     Female  49.0           0.0            0.0          Yes        Private
# 3     Female  79.0           1.0            0.0          Yes  Self-employed
# 4       Male  81.0           0.0            0.0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0           0.0            0.0           No        Private
# 4977    Male  40.0           0.0            0.0          Yes        Private
# 4978  Female  45.0           1.0            0.0          Yes       Govt_job
# 4979    Male  40.0           0.0            0.0          Yes        Private
# 4980  Female  80.0           1.0            0.0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked     1.0
# 1             Rural             105.92  32.5     never smoked     1.0
# 2             Urban             171.23  34.4           smokes     1.0
# 3             Rural             174.12  24.0     never smoked     1.0
# 4             Urban             186.21  29.0  formerly smoked     1.0
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked     0.0
# 4977          Urban             191.15  31.1           smokes     0.0
# 4978          Rural              95.02  31.8           smokes     0.0
# 4979          Rural              83.94  30.0           smokes     0.0
# 4980          Urban              83.75  29.1     never smoked     0.0
#
# [4981 rows x 11 columns]

# %% [markdown]
# y ahora, se reporta el número de datos perdidos luego del tratamiento de la información. Es de esperarse que el número de valores perdidos sea cero ya que a cada uno de ellos se le asignó un valor representante acorde a la dimensión.

# %%
print('Número de valores perdidos por cada atributo:')
for col in datos.columns:
    print('\t%s: %d' % (col,datos[col].isna().sum()))
# Out:
# Número de valores perdidos por cada atributo:
# 	gender: 0
# 	age: 0
# 	hypertension: 0
# 	heart_disease: 0
# 	ever_married: 0
# 	work_type: 0
# 	Residence_type: 0
# 	avg_glucose_level: 0
# 	bmi: 0
# 	smoking_status: 0
# 	stroke: 0

# %% [markdown]
# # 2) Detección de outliers

# %% [markdown]
# Dado que la mayoría de los atributos del conjunto de datos son de tipo binario y categóricos, en ellos no sea realiza el proceso de detección de outliers.
#
# Debido a que el atributo de nivel de glucosa contiene información relevante incluso para valores que están 3 desviaciones estándar por encima de la media en pacientes que sufren de diabetes, se decide no hacer filtrado por outliers.
#
# De igual forma, para el atributo del índice de masa corporal BMI se decide  no hacer filtrado por outliers.

# %%
# %matplotlib inline

datos.boxplot(figsize=(20,3))
# Out:
# <AxesSubplot:>

# %% [markdown]
# En cambio, el atributo edad contiene datos inconsistentes como lo son edades dadas en valores decimales, menores a 1 y edades muy grandes superiores a los 100 años. Así que se realiza un filtrado de dichos valores inconsistentes.

# %%
datos = datos.drop(datos[datos['age'] > 100].index)
datos = datos.drop(datos[datos['age'] < 1].index)
datos
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0           0.0            1.0          Yes        Private
# 1       Male  80.0           0.0            1.0          Yes        Private
# 2     Female  49.0           0.0            0.0          Yes        Private
# 3     Female  79.0           1.0            0.0          Yes  Self-employed
# 4       Male  81.0           0.0            0.0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0           0.0            0.0           No        Private
# 4977    Male  40.0           0.0            0.0          Yes        Private
# 4978  Female  45.0           1.0            0.0          Yes       Govt_job
# 4979    Male  40.0           0.0            0.0          Yes        Private
# 4980  Female  80.0           1.0            0.0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked     1.0
# 1             Rural             105.92  32.5     never smoked     1.0
# 2             Urban             171.23  34.4           smokes     1.0
# 3             Rural             174.12  24.0     never smoked     1.0
# 4             Urban             186.21  29.0  formerly smoked     1.0
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked     0.0
# 4977          Urban             191.15  31.1           smokes     0.0
# 4978          Rural              95.02  31.8           smokes     0.0
# 4979          Rural              83.94  30.0           smokes     0.0
# 4980          Urban              83.75  29.1     never smoked     0.0
#
# [4939 rows x 11 columns]

# %% [markdown]
# Se eliminaron los registros con edades menores a 1 años y mayores a 88 años, resultando ahora 4939 registros.

# %% [markdown]
# # 3) Eliminación de datos duplicados:
#
# A continuación se detectan los valores duplicados del conjunto de datos

# %%
dups = datos.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 0

# %% [markdown]
# El conjunto de datos no cuenta con valores duplicados, así que de forma intencionada se agregarán filas que contienen valores duplicados, para posteriormente realizar un tratamiento y eliminar aquellas filas redundantes.

# %%
total = datos.shape[0]
aleatorio1 = [9, 80, 233, 392, 491, 577, 694, 729, 854, 908, 1010, 1132, 1293, 1365, 1499, 1591, 1643, 1721, 1835, 1908, 2050, 2184, 2251, 2301, 2498, 2516, 2681, 2755, 2800, 2931, 3015, 3167, 3201, 3352, 3477, 3510, 3618, 3700, 3845, 3913, 4001]
for i in aleatorio1:
    fila = datos.loc[i-1]
    datos.loc[i+1]= fila
datos
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0           0.0            1.0          Yes        Private
# 1       Male  80.0           0.0            1.0          Yes        Private
# 2     Female  49.0           0.0            0.0          Yes        Private
# 3     Female  79.0           1.0            0.0          Yes  Self-employed
# 4       Male  81.0           0.0            0.0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4977    Male  40.0           0.0            0.0          Yes        Private
# 4978  Female  45.0           1.0            0.0          Yes       Govt_job
# 4979    Male  40.0           0.0            0.0          Yes        Private
# 4980  Female  80.0           1.0            0.0          Yes        Private
# 909   Female  50.0           0.0            0.0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked     1.0
# 1             Rural             105.92  32.5     never smoked     1.0
# 2             Urban             171.23  34.4           smokes     1.0
# 3             Rural             174.12  24.0     never smoked     1.0
# 4             Urban             186.21  29.0  formerly smoked     1.0
# ...             ...                ...   ...              ...     ...
# 4977          Urban             191.15  31.1           smokes     0.0
# 4978          Rural              95.02  31.8           smokes     0.0
# 4979          Rural              83.94  30.0           smokes     0.0
# 4980          Urban              83.75  29.1     never smoked     0.0
# 909           Rural             124.45  24.6     never smoked     0.0
#
# [4940 rows x 11 columns]

# %%
dups = datos.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 41

# %% [markdown]
# Se agregaron filas duplicadas en el conjunto de datos, obteniendo en total 41 registros duplicados. Ahora se procederá a hacer un tratamiento de valores duplicados en el conjunto de datos.

# %%
datos.drop_duplicates(inplace = True)
datos
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0           0.0            1.0          Yes        Private
# 1       Male  80.0           0.0            1.0          Yes        Private
# 2     Female  49.0           0.0            0.0          Yes        Private
# 3     Female  79.0           1.0            0.0          Yes  Self-employed
# 4       Male  81.0           0.0            0.0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0           0.0            0.0           No        Private
# 4977    Male  40.0           0.0            0.0          Yes        Private
# 4978  Female  45.0           1.0            0.0          Yes       Govt_job
# 4979    Male  40.0           0.0            0.0          Yes        Private
# 4980  Female  80.0           1.0            0.0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked     1.0
# 1             Rural             105.92  32.5     never smoked     1.0
# 2             Urban             171.23  34.4           smokes     1.0
# 3             Rural             174.12  24.0     never smoked     1.0
# 4             Urban             186.21  29.0  formerly smoked     1.0
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked     0.0
# 4977          Urban             191.15  31.1           smokes     0.0
# 4978          Rural              95.02  31.8           smokes     0.0
# 4979          Rural              83.94  30.0           smokes     0.0
# 4980          Urban              83.75  29.1     never smoked     0.0
#
# [4899 rows x 11 columns]

# %% [markdown]
# Se eliminan las filas duplicadas del dataframe, resultando ahora en 4899 registros.

# %%
dups = datos.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 0

# %% [markdown]
# Finalmente se verifica que el conjunto de datos tenga 0 valores duplicados.

# %% [markdown]
# # 4) Agregación
#
# Para el presente conjunto de datos no es necesario hacer agregación de dimensiones, ya que se decidió que las 11 dimensiones con las que cuenta el conjunto son suficientes para la tarea de clasificación.

# %% [markdown]
# # 5) Muestreo
#
# A continuación se realiza un muestreo sin reemplazamiento del 1% del conjunto de datos.

# %%
datos_muestra = datos.sample(frac=0.01, replace=False, random_state=1)
datos_muestra
# Out:
#       gender    age  hypertension  heart_disease ever_married      work_type  \
# 847     Male  80.00           0.0            0.0          Yes  Self-employed
# 4615    Male  24.00           0.0            0.0           No        Private
# 2630    Male  32.00           0.0            0.0          Yes        Private
# 2134  Female   8.00           0.0            0.0           No       children
# 3177  Female  51.00           0.0            0.0          Yes       Govt_job
# 3845  Female  78.00           0.0            0.0          Yes        Private
# 782     Male   2.00           0.0            0.0           No       children
# 3495  Female  62.00           0.0            0.0          Yes        Private
# 4863    Male  76.00           0.0            1.0          Yes        Private
# 4375  Female  68.00           0.0            0.0          Yes  Self-employed
# 2050    Male  50.00           0.0            0.0          Yes        Private
# 4664  Female  79.00           0.0            0.0          Yes       Govt_job
# 2360  Female  45.00           0.0            0.0          Yes        Private
# 3753    Male  62.00           1.0            0.0          Yes  Self-employed
# 2684  Female  44.00           0.0            0.0          Yes        Private
# 4016    Male  57.00           0.0            0.0          Yes        Private
# 2790  Female  44.00           0.0            0.0          Yes        Private
# 4577  Female  34.00           0.0            0.0           No       Govt_job
# 1318  Female  57.00           0.0            0.0          Yes        Private
# 3403  Female  52.00           0.0            0.0          Yes        Private
# 446     Male  29.00           0.0            0.0          Yes  Self-employed
# 3232    Male  67.00           0.0            0.0          Yes        Private
# 2376    Male   7.00           0.0            0.0           No       children
# 3643  Female  65.00           0.0            0.0          Yes        Private
# 4277  Female  76.00           0.0            0.0          Yes       Govt_job
# 2926    Male  54.00           1.0            0.0          Yes        Private
# 3691  Female  61.00           0.0            0.0          Yes        Private
# 1383    Male  38.00           0.0            0.0           No        Private
# 2202  Female  26.00           0.0            0.0          Yes        Private
# 3727  Female   1.64           0.0            0.0           No       children
# 2728    Male  19.00           0.0            0.0           No        Private
# 1931  Female  27.00           0.0            0.0          Yes  Self-employed
# 807   Female  59.00           0.0            0.0          Yes        Private
# 4792    Male  75.00           0.0            0.0          Yes        Private
# 3104  Female  45.00           0.0            0.0          Yes        Private
# 511   Female  52.00           1.0            0.0          Yes  Self-employed
# 1080  Female  59.00           0.0            0.0          Yes        Private
# 3001  Female  36.00           0.0            0.0          Yes        Private
# 2647  Female   8.00           0.0            0.0           No       children
# 574   Female  66.00           0.0            1.0          Yes        Private
# 1653  Female  56.00           0.0            0.0          Yes  Self-employed
# 563   Female  40.00           0.0            0.0          Yes        Private
# 3265  Female  55.00           0.0            0.0          Yes        Private
# 1652  Female  26.00           0.0            0.0           No        Private
# 3444    Male  34.00           0.0            0.0          Yes        Private
# 4683  Female  59.00           0.0            0.0          Yes       Govt_job
# 3686  Female  80.00           0.0            0.0          Yes  Self-employed
# 4956    Male  31.00           0.0            0.0          Yes        Private
# 1046  Female  28.00           0.0            0.0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 847           Rural             236.84  26.8     never smoked     0.0
# 4615          Rural              91.21  28.1  formerly smoked     0.0
# 2630          Urban              78.30  31.0          Unknown     0.0
# 2134          Urban              80.47  20.6          Unknown     0.0
# 3177          Rural              85.59  30.5     never smoked     0.0
# 3845          Urban              99.72  22.3           smokes     0.0
# 782           Rural              56.77  20.9          Unknown     0.0
# 3495          Urban             101.19  23.4     never smoked     0.0
# 4863          Urban              79.05  28.3          Unknown     0.0
# 4375          Rural              80.63  20.2     never smoked     0.0
# 2050          Rural             104.02  29.5     never smoked     0.0
# 4664          Urban              95.42  21.5  formerly smoked     0.0
# 2360          Urban             106.83  32.1  formerly smoked     0.0
# 3753          Rural              95.49  40.2           smokes     0.0
# 2684          Rural              97.27  26.0     never smoked     0.0
# 4016          Urban             134.76  29.1          Unknown     0.0
# 2790          Urban             121.46  40.4          Unknown     0.0
# 4577          Urban              79.60  46.3     never smoked     0.0
# 1318          Rural             169.97  25.8     never smoked     0.0
# 3403          Urban              67.30  36.3     never smoked     0.0
# 446           Urban             118.70  33.2          Unknown     0.0
# 3232          Urban             238.78  35.7  formerly smoked     0.0
# 2376          Urban              86.60  17.1          Unknown     0.0
# 3643          Rural              95.87  29.8     never smoked     0.0
# 4277          Urban             223.64  27.1           smokes     0.0
# 2926          Urban             220.26  28.0  formerly smoked     0.0
# 3691          Rural              60.91  29.8          Unknown     0.0
# 1383          Rural              86.86  36.5          Unknown     0.0
# 2202          Rural              84.90  26.2     never smoked     0.0
# 3727          Urban              90.74  19.9          Unknown     0.0
# 2728          Urban             103.92  24.1          Unknown     0.0
# 1931          Urban              88.97  28.8     never smoked     0.0
# 807           Rural             237.15  27.7     never smoked     0.0
# 4792          Urban             104.72  28.3          Unknown     1.0
# 3104          Rural              92.21  31.0     never smoked     0.0
# 511           Urban             114.25  24.3  formerly smoked     0.0
# 1080          Rural             224.71  42.9     never smoked     0.0
# 3001          Urban              91.34  29.9     never smoked     0.0
# 2647          Rural              92.65  17.5          Unknown     0.0
# 574           Urban              94.62  29.7  formerly smoked     0.0
# 1653          Urban             224.63  42.8     never smoked     0.0
# 563           Urban              71.20  27.1     never smoked     0.0
# 3265          Urban             102.10  22.5  formerly smoked     0.0
# 1652          Urban             168.15  22.9     never smoked     0.0
# 3444          Urban              66.96  26.1     never smoked     0.0
# 4683          Urban             101.19  29.9  formerly smoked     0.0
# 3686          Urban             223.26  25.4     never smoked     0.0
# 4956          Urban             108.62  29.2           smokes     0.0
# 1046          Rural             106.68  29.3     never smoked     0.0

# %% [markdown]
# # 6) Discretización
#
# ### 6.1) Discretización de las edades.

# %%
datos['age'].hist(bins=20)
datos['age'].value_counts(sort=False)
# Out:
# 67.00    47
# 80.00    70
# 49.00    76
# 79.00    84
# 81.00    60
#          ..
# 1.88      7
# 1.24      6
# 1.48      6
# 1.32      8
# 1.64      7
# Name: age, Length: 93, dtype: int64

# %% [markdown]
# ### 6.2) Histograma de género

# %%
datos['gender'].hist(bins=10)
datos['gender'].value_counts(sort=False)
# Out:
# Male      2028
# Female    2871
# Name: gender, dtype: int64

# %% [markdown]
# Se puede apreciar que los datos contienen más personas de género femenino que del masculino.

# %% [markdown]
# ### 6.3) Histograma de hipertensión

# %%
datos['hypertension'].hist(bins=10)
datos['hypertension'].value_counts(sort=False)
# Out:
# 0.0    4423
# 1.0     476
# Name: hypertension, dtype: int64

# %% [markdown]
# Se puede apreciar que existen muchas más personas que no sufren de hipertensión comparada con aquella que sí padece dicha enfermedad.

# %% [markdown]
# ### 6.4) Histograma de enfermedad del corazón

# %%
datos['heart_disease'].hist(bins=10)
datos['heart_disease'].value_counts(sort=False)
# Out:
# 1.0     274
# 0.0    4625
# Name: heart_disease, dtype: int64

# %% [markdown]
# Se aprecia que existe mucho más gente que no sufre de enfermedad del corazón que aquellos que sí la padecen.

# %% [markdown]
# ### 6.5) Histograma de estado civil

# %%
datos['ever_married'].hist(bins=10)
datos['ever_married'].value_counts(sort=False)
# Out:
# Yes    3257
# No     1642
# Name: ever_married, dtype: int64

# %% [markdown]
# ### 6.6) Histograma de tipo de trabajo

# %%
datos['work_type'].hist(bins=10)
datos['work_type'].value_counts(sort=False)
# Out:
# Private          2840
# Self-employed     801
# Govt_job          635
# children          623
# Name: work_type, dtype: int64

# %% [markdown]
# Se observa que el tipo de trabajo mayoritario es de tipo privado.

# %% [markdown]
# ### 6.7) Histograma de tipo de residencia:

# %%
datos['Residence_type'].hist(bins=10)
datos['Residence_type'].value_counts(sort=False)
# Out:
# Urban    2491
# Rural    2408
# Name: Residence_type, dtype: int64

# %% [markdown]
# Los tipos de residencia tanto urbanos como rurales son muy similares.

# %% [markdown]
# ### 6.8) Histograma de nivel de glucosa promedio:

# %%
datos['avg_glucose_level'].hist(bins=100)
datos['avg_glucose_level'].value_counts(sort=False)
# Out:
# 228.69    1
# 105.92    1
# 171.23    1
# 174.12    1
# 186.21    1
#          ..
# 84.94     1
# 215.07    1
# 191.15    1
# 95.02     1
# 83.94     1
# Name: avg_glucose_level, Length: 3844, dtype: int64

# %% [markdown]
# La distribución del nivel de glucosa es muy similar a una Chi-cuadrado con los siguientes parámetros:

# %%
media_glucosa = datos['avg_glucose_level'].mean()
print("Valor de media:  ")
print(media_glucosa)
desviacion_glucosa = datos['avg_glucose_level'].std()
print("Valor de desviación estándar:  ")
print(desviacion_glucosa)
# Out:
# Valor de media:
# 106.07824249846873
# Valor de desviación estándar:
# 45.195549816177554

# %% [markdown]
# Se aprecia que la mayoría de datos se encuentra entre el rango 70-120, el cual es el límite normal de glucosa para una persona sana.

# %% [markdown]
# ### 6.9) Histograma de índice de masa corporal IMC

# %%
datos['bmi'].hist(bins=100)
datos['bmi'].value_counts(sort=False)
# Out:
# 36.6    14
# 32.5    22
# 34.4    18
# 24.0    28
# 29.0    29
#         ..
# 46.9     2
# 47.1     1
# 48.1     1
# 46.3     1
# 14.9     1
# Name: bmi, Length: 342, dtype: int64

# %% [markdown]
# Se puede apreciar en el histograma una forma de campana muy similar a una distribución norma, con los siguientes parámetros:

# %%
media_glucosa = datos['bmi'].mean()
print("Valor de media:  ")
print(media_glucosa)
desviacion_glucosa = datos['bmi'].std()
print("Valor de desviación estándar:  ")
print(desviacion_glucosa)
# Out:
# Valor de media:
# 28.5933455807308
# Valor de desviación estándar:
# 6.750978379345119

# %% [markdown]
# ### 6.10) Histograma de estatus de fumador:

# %%
datos['smoking_status'].hist(bins=10)
datos['smoking_status'].value_counts(sort=False)
# Out:
# formerly smoked     857
# never smoked       1827
# smokes              770
# Unknown            1445
# Name: smoking_status, dtype: int64

# %% [markdown]
# ### 6.11) Histograma de accidente cerebrovascular

# %%
datos['stroke'].hist(bins=10)
datos['stroke'].value_counts(sort=False)
# Out:
# 1.0     245
# 0.0    4654
# Name: stroke, dtype: int64

# %% [markdown]
# # 7) Transformación de variables categóricas a numéricas

# %% [markdown]
# A continuación se realizará una transformación de las variables categóricas a valores numéricos. Esto permite tener un conjunto de datos con únicamente variables numéricas, lo cual hace posible la implementación de algoritmos de minería de datos.
#
# En el siguiente fragmento de código se ejecuta un mapeo de variables, en el cual se asigna un valor numérico a cada uno de los posibles valores que toma cada variable categórica.

# %%
datos_numericos = datos.copy()
datos_numericos['gender'] = datos_numericos['gender'].astype('category').cat.codes
datos_numericos['ever_married'] = datos_numericos['ever_married'].astype('category').cat.codes
datos_numericos['work_type'] = datos_numericos['work_type'].astype('category').cat.codes
datos_numericos['Residence_type'] = datos_numericos['Residence_type'].astype('category').cat.codes
datos_numericos['smoking_status'] = datos_numericos['smoking_status'].astype('category').cat.codes
datos_numericos
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0           0.0            1.0             1          1
# 1          1  80.0           0.0            1.0             1          1
# 2          0  49.0           0.0            0.0             1          1
# 3          0  79.0           1.0            0.0             1          2
# 4          1  81.0           0.0            0.0             1          1
# ...      ...   ...           ...            ...           ...        ...
# 4976       1  41.0           0.0            0.0             0          1
# 4977       1  40.0           0.0            0.0             1          1
# 4978       0  45.0           1.0            0.0             1          0
# 4979       1  40.0           0.0            0.0             1          1
# 4980       0  80.0           1.0            0.0             1          1
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0                  1             228.69  36.6               1     1.0
# 1                  0             105.92  32.5               2     1.0
# 2                  1             171.23  34.4               3     1.0
# 3                  0             174.12  24.0               2     1.0
# 4                  1             186.21  29.0               1     1.0
# ...              ...                ...   ...             ...     ...
# 4976               0              70.15  29.8               1     0.0
# 4977               1             191.15  31.1               3     0.0
# 4978               0              95.02  31.8               3     0.0
# 4979               0              83.94  30.0               3     0.0
# 4980               1              83.75  29.1               2     0.0
#
# [4899 rows x 11 columns]

# %% [markdown]
# # 8) Reducción de dimensionalidad

# %% [markdown]
# A continuación se realizará un procedimiento de reducción de dimensiones del conjunto de datos. En un principio se hace necesario remover la columna asociada a la clase.

# %%
datos_sin_clase = datos_numericos.drop(['stroke'], axis = 1)
datos_sin_clase
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0           0.0            1.0             1          1
# 1          1  80.0           0.0            1.0             1          1
# 2          0  49.0           0.0            0.0             1          1
# 3          0  79.0           1.0            0.0             1          2
# 4          1  81.0           0.0            0.0             1          1
# ...      ...   ...           ...            ...           ...        ...
# 4976       1  41.0           0.0            0.0             0          1
# 4977       1  40.0           0.0            0.0             1          1
# 4978       0  45.0           1.0            0.0             1          0
# 4979       1  40.0           0.0            0.0             1          1
# 4980       0  80.0           1.0            0.0             1          1
#
#       Residence_type  avg_glucose_level   bmi  smoking_status
# 0                  1             228.69  36.6               1
# 1                  0             105.92  32.5               2
# 2                  1             171.23  34.4               3
# 3                  0             174.12  24.0               2
# 4                  1             186.21  29.0               1
# ...              ...                ...   ...             ...
# 4976               0              70.15  29.8               1
# 4977               1             191.15  31.1               3
# 4978               0              95.02  31.8               3
# 4979               0              83.94  30.0               3
# 4980               1              83.75  29.1               2
#
# [4899 rows x 10 columns]

# %% [markdown]
# Luego se realiza una normalización de los datos. En pruebas previas se determinó que el algoritmo PCA tiene un mejor desempeño en la varianza explicada acumulada cuando se realizó una normalización MinMax, comparada con tras normalizaciones como la Standard.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler



#normalizamos los datos
scaler = MinMaxScaler(feature_range=(0,1))
scaler.fit(datos_sin_clase)                                     # calculo la media para poder hacer la transformacion
datos_normalizados = scaler.transform(datos_sin_clase)          # Ahora si, escalo los datos y los normalizo
print(datos_normalizados)
# Out:
# [[1.         0.81481481 0.         ... 0.80126489 0.64756447 0.33333333]
#  [1.         0.97530864 0.         ... 0.23451205 0.53008596 0.66666667]
#  [0.         0.59259259 0.         ... 0.53600776 0.58452722 1.        ]
#  ...
#  [0.         0.54320988 1.         ... 0.18419352 0.51002865 1.        ]
#  [1.         0.48148148 0.         ... 0.13304404 0.45845272 1.        ]
#  [0.         0.97530864 1.         ... 0.13216693 0.43266476 0.66666667]]

# %%
datos_sin_pca = datos_normalizados.copy()
pca=PCA(n_components=10)
pca.fit(datos_sin_pca) 
datos_pca=pca.transform(datos_sin_pca)
print("shape of X_pca", datos_pca.shape)
expl = pca.explained_variance_ratio_
print(expl)
print('suma:',sum(expl[0:10]))
# Out:
# shape of X_pca (4899, 10)
# [0.26000448 0.20484899 0.19908285 0.09412738 0.07280292 0.04720489
#  0.04499768 0.03202087 0.02305383 0.02185611]
# suma: 1.0000000000000002

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %% [markdown]
# Se puede apreciar que la varianza explicada acumulada cae por debajo del 90% para dimensiones menores a 7, lo cual nos indica que una reducción de dimensionalidad igual a 7 puede ser la adecuada para nuestro conjunto de datos. Así que se ejecutará dicha reducción.

# %%
datos_sin_pca = datos_normalizados.copy()
pca=PCA(n_components=7)
pca.fit(datos_sin_pca) 
datos_pca=pca.transform(datos_sin_pca)
print("shape of X_pca", datos_pca.shape)
expl = pca.explained_variance_ratio_
print(expl)
print('suma:',sum(expl[0:7]))
# Out:
# shape of X_pca (4899, 7)
# [0.26000448 0.20484899 0.19908285 0.09412738 0.07280292 0.04720489
#  0.04499768]
# suma: 0.923069191148864

# %% [markdown]
# Se obtiene una varianza explicada acumulada de 92.3%.
#
# Finalmente se grafica la proyección del conjunto de datos a  dos dimensiones, esto con el fin de ver si es viable realizar la predicción de accidente cerebro-vascular usando sólo dos dimensiones. De inicio se sabe que la varianza explicada acumulada para dos dimensiones es de tan solo el 46%, así que puede que no se logren los resultados esperados.

# %%
Xax=datos_pca[:,0]
Yax=datos_pca[:,1]
labels=datos_numericos['stroke'].values
cdict={0:'red' ,1:'green'}
labl={0:'NO_ACV',1:'SI_ACV'}
marker={0:'*',1:'o'}
alpha={0:.3, 1:.5}
fig,ax=plt.subplots(figsize=(7,5))
fig.patch.set_facecolor('white')
for l in np.unique(labels):
    ix=np.where(labels==l)
    ax.scatter(Xax[ix],Yax[ix],c=cdict[l],label=labl[l],s=40,marker=marker[l],alpha=alpha[l])
 
plt.xlabel("First Principal Component",fontsize=14)
plt.ylabel("Second Principal Component",fontsize=14)
plt.legend()
plt.show()

# %% [markdown]
# Se puede observar que los casos en los que hubo accidente cerebro-vascular se solapan con aquellos en los que no hubo, así que el uso de dos dimensiones no sirve para implementar algoritmos de predicción de existencia de accidente cerebro-vascular.

# %% [markdown]
# # 9) Tratamiento del conjunto de datos para realizar asociación

# %% [markdown]
# ### 9.1) Discretización de variables numéricas

# %% [markdown]
# Ya que naturalmente los algoritmos de asociación trabajan con datos categóricos, se hace necesario discretizar las variables numéricas. Para ello, se usa una función de Python con la cual se establecen los intervalos en los que se quiere discretizar las siguientes variables numéricas: 'age', 'avg_glucose_level' y 'bmi'.
#
# Para la columna 'age', se hace una discretización teniendo en cuenta la clasificación sugerida por la OMS de las etapas de la vida humana según desarrollo y deterioro biológico, asignando las siguientes categorías: Infancia y niñez de 0 a 12 años, Adolescencia de 12 a 20 años, Adultez joven de 20 a 40 años, Adultez intermedia de 40 a 50 años, Adultez tardía de 50 a 60 años, Senectud de 60 a 70 años, Vejez de 70 a 80 años, y Grandes anciamos por encima de los 80 años.
#
# Se realiza esta clasificación basada en criterios médicos, con el fin de dar un sentido biológico y del desarrollo humano a las asociaciones que se puedan encontrar entre la edad y las demás dimensiones del conjunto de datos.

# %%
datos_asociacion = datos.copy()
datos_asociacion['age']=pd.cut(x=datos_asociacion['age'], bins=[0,12,20,40,50,60,70,80,88],labels=["Infancia_y_niñez", "Adolescencia", "Adultez_joven", "Adultez_intermedia", "Adultez_tardía", "Senectud", "Vejez", "Grandes ancianos"])
datos_asociacion['age'].hist()
datos_asociacion['age'].value_counts(sort=False)
# Out:
# Infancia_y_niñez       524
# Adolescencia           409
# Adultez_joven         1180
# Adultez_intermedia     705
# Adultez_tardía         790
# Senectud               581
# Vejez                  594
# Grandes ancianos       116
# Name: age, dtype: int64

# %% [markdown]
# Ahora se discretizará la columna 'avg_glucose_level'. Para ello se toman las clasficaciones del nivel de glucosa en sangre en ayunas que se sugiere en la literatura médica.
#
# Se tiene la siguiente clasificación: 'Hipoglicemia' entre 50 y 70, 'Glucosa_normal' entre 70 y 108, 'Prediabetes' entre 108 y 125, y 'Diabetes' por encima de 125.
#
# Se realiza una clasificación con base en criterios médicos con el fin de dar un sentido a las posibles asociaciones que se puedan presentar.

# %%
datos_asociacion['avg_glucose_level']=pd.cut(x=datos_asociacion['avg_glucose_level'], bins=[50,70,108,125,300],labels=["Hipoglicemia", "Glucosa_normal", "Prediabetes", "Diabetes"])
datos_asociacion['avg_glucose_level'].hist()
datos_asociacion['avg_glucose_level'].value_counts(sort=False)
# Out:
# Hipoglicemia       721
# Glucosa_normal    2695
# Prediabetes        529
# Diabetes           954
# Name: avg_glucose_level, dtype: int64

# %% [markdown]
# A continuación se discretizará la columna correspondiente a 'bmi'. Nuevamente se toma en cuenta la clasificación según Índice de Masa Corporal de la siguiente forma: 'Delgadez_severa' por debajo de 16, 'Delgadez_moderada' entre 16 y 17, 'Delgadez_leve' entre 17 y 18.5, 'Peso_normal' entre 18.5 y 25, 'Sobrepeso' entre 25 y 30, 'Obesidad_leve' entre 30 y 35, 'Obesidad_media' entre 35 y 40, y 'Obesidad mórbida' por encima de 40.

# %%
datos_asociacion['bmi']=pd.cut(x=datos_asociacion['bmi'], bins=[13,16,17,18.5,25,30,35,40,50],labels=["Delgadez_severa", "Delgadez_moderada", "Delgadez_leve", "Peso_normal", "Sobrepeso", "Obesidad_leve", "Obesidad_media", "Obesidad_morbida"])
datos_asociacion['bmi'].hist()
datos_asociacion['bmi'].value_counts(sort=False)
# Out:
# Delgadez_severa        65
# Delgadez_moderada      79
# Delgadez_leve         162
# Peso_normal          1230
# Sobrepeso            1492
# Obesidad_leve        1057
# Obesidad_media        499
# Obesidad_morbida      315
# Name: bmi, dtype: int64

# %% [markdown]
# El conjunto de datos ahora luce así:

# %%
datos_asociacion
# Out:
#       gender                 age  hypertension  heart_disease ever_married  \
# 0       Male            Senectud           0.0            1.0          Yes
# 1       Male               Vejez           0.0            1.0          Yes
# 2     Female  Adultez_intermedia           0.0            0.0          Yes
# 3     Female               Vejez           1.0            0.0          Yes
# 4       Male    Grandes ancianos           0.0            0.0          Yes
# ...      ...                 ...           ...            ...          ...
# 4976    Male  Adultez_intermedia           0.0            0.0           No
# 4977    Male       Adultez_joven           0.0            0.0          Yes
# 4978  Female  Adultez_intermedia           1.0            0.0          Yes
# 4979    Male       Adultez_joven           0.0            0.0          Yes
# 4980  Female               Vejez           1.0            0.0          Yes
#
#           work_type Residence_type avg_glucose_level             bmi  \
# 0           Private          Urban          Diabetes  Obesidad_media
# 1           Private          Rural    Glucosa_normal   Obesidad_leve
# 2           Private          Urban          Diabetes   Obesidad_leve
# 3     Self-employed          Rural          Diabetes     Peso_normal
# 4           Private          Urban          Diabetes       Sobrepeso
# ...             ...            ...               ...             ...
# 4976        Private          Rural    Glucosa_normal       Sobrepeso
# 4977        Private          Urban          Diabetes   Obesidad_leve
# 4978       Govt_job          Rural    Glucosa_normal   Obesidad_leve
# 4979        Private          Rural    Glucosa_normal       Sobrepeso
# 4980        Private          Urban    Glucosa_normal       Sobrepeso
#
#        smoking_status  stroke
# 0     formerly smoked     1.0
# 1        never smoked     1.0
# 2              smokes     1.0
# 3        never smoked     1.0
# 4     formerly smoked     1.0
# ...               ...     ...
# 4976  formerly smoked     0.0
# 4977           smokes     0.0
# 4978           smokes     0.0
# 4979           smokes     0.0
# 4980     never smoked     0.0
#
# [4899 rows x 11 columns]

# %% [markdown]
# ### 9.2) Tratamiento de variables binarias

# %% [markdown]
# En el caso de variables binarias es mucho más sencillo hacer la discretización ya que un valor de "0" en la variable representa una etiqueta, mientras que el valor de "1" representa la otra etiqueta.
#
# Para la columna de hipertensión se realiza la asignación de las etiquetas correspondientes:

# %%
datos_asociacion['hypertension']=pd.cut(x=datos_asociacion['hypertension'], bins=[-1,0,1],labels=["No_hipertension", "Si_hipertension"])
datos_asociacion['hypertension'].hist()
datos_asociacion['hypertension'].value_counts(sort=False)
# Out:
# No_hipertension    4423
# Si_hipertension     476
# Name: hypertension, dtype: int64

# %% [markdown]
# Para la columna correspondiente a enfermedad del corazón se realiza un procedimiento similar:

# %%
datos_asociacion['heart_disease']=pd.cut(x=datos_asociacion['heart_disease'], bins=[-1,0,1],labels=["No_enfermedad_corazon", "Si_enfermedad_corazon"])
datos_asociacion['heart_disease'].hist()
datos_asociacion['heart_disease'].value_counts(sort=False)
# Out:
# No_enfermedad_corazon    4625
# Si_enfermedad_corazon     274
# Name: heart_disease, dtype: int64

# %% [markdown]
# Finalmente se le asignan las etiquetas a la columna correspondiente a la clase, cuyo nombre en el dataframe es 'stroke' y representa si la persona en cuestión ha sufrido de accidente cerebrovascular.

# %%
datos_asociacion['stroke']=pd.cut(x=datos_asociacion['stroke'], bins=[-1,0,1],labels=["No_ACV", "Si_ACV"])
datos_asociacion['stroke'].hist()
datos_asociacion['stroke'].value_counts(sort=False)
# Out:
# No_ACV    4654
# Si_ACV     245
# Name: stroke, dtype: int64

# %% [markdown]
# Ya se tienen todas las variables numéricas y binarias ya en forma categórica, luciendo el dataset así:

# %%
datos_asociacion
# Out:
#       gender                 age     hypertension          heart_disease  \
# 0       Male            Senectud  No_hipertension  Si_enfermedad_corazon
# 1       Male               Vejez  No_hipertension  Si_enfermedad_corazon
# 2     Female  Adultez_intermedia  No_hipertension  No_enfermedad_corazon
# 3     Female               Vejez  Si_hipertension  No_enfermedad_corazon
# 4       Male    Grandes ancianos  No_hipertension  No_enfermedad_corazon
# ...      ...                 ...              ...                    ...
# 4976    Male  Adultez_intermedia  No_hipertension  No_enfermedad_corazon
# 4977    Male       Adultez_joven  No_hipertension  No_enfermedad_corazon
# 4978  Female  Adultez_intermedia  Si_hipertension  No_enfermedad_corazon
# 4979    Male       Adultez_joven  No_hipertension  No_enfermedad_corazon
# 4980  Female               Vejez  Si_hipertension  No_enfermedad_corazon
#
#      ever_married      work_type Residence_type avg_glucose_level  \
# 0             Yes        Private          Urban          Diabetes
# 1             Yes        Private          Rural    Glucosa_normal
# 2             Yes        Private          Urban          Diabetes
# 3             Yes  Self-employed          Rural          Diabetes
# 4             Yes        Private          Urban          Diabetes
# ...           ...            ...            ...               ...
# 4976           No        Private          Rural    Glucosa_normal
# 4977          Yes        Private          Urban          Diabetes
# 4978          Yes       Govt_job          Rural    Glucosa_normal
# 4979          Yes        Private          Rural    Glucosa_normal
# 4980          Yes        Private          Urban    Glucosa_normal
#
#                  bmi   smoking_status  stroke
# 0     Obesidad_media  formerly smoked  Si_ACV
# 1      Obesidad_leve     never smoked  Si_ACV
# 2      Obesidad_leve           smokes  Si_ACV
# 3        Peso_normal     never smoked  Si_ACV
# 4          Sobrepeso  formerly smoked  Si_ACV
# ...              ...              ...     ...
# 4976       Sobrepeso  formerly smoked  No_ACV
# 4977   Obesidad_leve           smokes  No_ACV
# 4978   Obesidad_leve           smokes  No_ACV
# 4979       Sobrepeso           smokes  No_ACV
# 4980       Sobrepeso     never smoked  No_ACV
#
# [4899 rows x 11 columns]

# %% [markdown]
# ### 9.3) Re-etiquetado de variables

# %% [markdown]
# Ya que los elementos de las dimensiones de estado civil y tipo de trabajo no tienen una referencia de la columna a la que se refiere dicha información, a continuación se re-etiquietarán dichas variables, de tal forma que ahora será explícita la información que contienen.

# %%
total = datos_asociacion.shape[0]
for i in datos_asociacion.index:
    if datos_asociacion['ever_married'][i] == 'Yes':
        datos_asociacion['ever_married'][i] = 'Casado'
    elif datos_asociacion['ever_married'][i] == 'No':
        datos_asociacion['ever_married'][i] = 'No_casado'

datos_asociacion['ever_married'].hist()
datos_asociacion['ever_married'].value_counts(sort=False)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\2460349084.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_asociacion['ever_married'][i] = 'Casado'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\2460349084.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_asociacion['ever_married'][i] = 'No_casado'
# Casado       3257
# No_casado    1642
# Name: ever_married, dtype: int64

# %%
for i in datos_asociacion.index:
    if datos_asociacion['work_type'][i] == 'Private':
        datos_asociacion['work_type'][i] = 'Trabajo_privado'
    elif datos_asociacion['work_type'][i] == 'Self-employed':
        datos_asociacion['work_type'][i] = 'Auto-empleado'
    elif datos_asociacion['work_type'][i] == 'Govt_job':
        datos_asociacion['work_type'][i] = 'Trabajo_gobierno'
    elif datos_asociacion['work_type'][i] == 'children':
        datos_asociacion['work_type'][i] = 'Menor_edad'

datos_asociacion['work_type'].hist()
datos_asociacion['work_type'].value_counts(sort=False)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\3774318431.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_asociacion['work_type'][i] = 'Trabajo_privado'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\3774318431.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_asociacion['work_type'][i] = 'Auto-empleado'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\3774318431.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_asociacion['work_type'][i] = 'Trabajo_gobierno'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22576\3774318431.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_asociacion['work_type'][i] = 'Menor_edad'
# Trabajo_privado     2840
# Auto-empleado        801
# Trabajo_gobierno     635
# Menor_edad           623
# Name: work_type, dtype: int64

# %%
for i in datos_asociacion.index:
    if datos_asociacion['Residence_type'][i] == 'Urban':
        datos_asociacion['Residence_type'][i] = 'Residencia_urbana'
    elif datos_asociacion['Residence_type'][i] == 'Rural':
        datos_asociacion['Residence_type'][i] = 'Residencia_rural'


datos_asociacion['Residence_type'].hist()
datos_asociacion['Residence_type'].value_counts(sort=False)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14424\2866655736.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_asociacion['Residence_type'][i] = 'Residencia_urbana'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14424\2866655736.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_asociacion['Residence_type'][i] = 'Residencia_rural'
# Residencia_urbana    2491
# Residencia_rural     2408
# Name: Residence_type, dtype: int64

# %%
datos_asociacion
# Out:
#       gender                 age     hypertension          heart_disease  \
# 0       Male            Senectud  No_hipertension  Si_enfermedad_corazon
# 1       Male               Vejez  No_hipertension  Si_enfermedad_corazon
# 2     Female  Adultez_intermedia  No_hipertension  No_enfermedad_corazon
# 3     Female               Vejez  Si_hipertension  No_enfermedad_corazon
# 4       Male    Grandes ancianos  No_hipertension  No_enfermedad_corazon
# ...      ...                 ...              ...                    ...
# 4976    Male  Adultez_intermedia  No_hipertension  No_enfermedad_corazon
# 4977    Male       Adultez_joven  No_hipertension  No_enfermedad_corazon
# 4978  Female  Adultez_intermedia  Si_hipertension  No_enfermedad_corazon
# 4979    Male       Adultez_joven  No_hipertension  No_enfermedad_corazon
# 4980  Female               Vejez  Si_hipertension  No_enfermedad_corazon
#
#      ever_married         work_type     Residence_type avg_glucose_level  \
# 0          Casado   Trabajo_privado  Residencia_urbana          Diabetes
# 1          Casado   Trabajo_privado   Residencia_rural    Glucosa_normal
# 2          Casado   Trabajo_privado  Residencia_urbana          Diabetes
# 3          Casado     Auto-empleado   Residencia_rural          Diabetes
# 4          Casado   Trabajo_privado  Residencia_urbana          Diabetes
# ...           ...               ...                ...               ...
# 4976    No_casado   Trabajo_privado   Residencia_rural    Glucosa_normal
# 4977       Casado   Trabajo_privado  Residencia_urbana          Diabetes
# 4978       Casado  Trabajo_gobierno   Residencia_rural    Glucosa_normal
# 4979       Casado   Trabajo_privado   Residencia_rural    Glucosa_normal
# 4980       Casado   Trabajo_privado  Residencia_urbana    Glucosa_normal
#
#                  bmi   smoking_status  stroke
# 0     Obesidad_media  formerly smoked  Si_ACV
# 1      Obesidad_leve     never smoked  Si_ACV
# 2      Obesidad_leve           smokes  Si_ACV
# 3        Peso_normal     never smoked  Si_ACV
# 4          Sobrepeso  formerly smoked  Si_ACV
# ...              ...              ...     ...
# 4976       Sobrepeso  formerly smoked  No_ACV
# 4977   Obesidad_leve           smokes  No_ACV
# 4978   Obesidad_leve           smokes  No_ACV
# 4979       Sobrepeso           smokes  No_ACV
# 4980       Sobrepeso     never smoked  No_ACV
#
# [4899 rows x 11 columns]

# %% [markdown]
# # 10) Aplicación de algoritmos de asociación

# %% [markdown]
# ### 10.1) Algoritmo de asociación Apriori

# %% [markdown]
# En un principio es necesario convertir el dataframe del conjunto de datos a una lista de grupos de etiquetas, ya que las librerías encargadas de hacer asociación en Python reciben como entrada este formato.

# %%
datos_asociacion_lista = datos_asociacion.copy()
datos_asociacion_lista = datos_asociacion.values.tolist()
datos_asociacion_lista
# Out:
# [['Male',
#   'Senectud',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_media',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_leve',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Diabetes',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Peso_normal',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Prediabetes',
#   'Obesidad_media',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_media',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_media',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Diabetes',
#   'Peso_normal',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_morbida',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Grandes ancianos',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'Unknown',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_morbida',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Grandes ancianos',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Diabetes',
#   'Peso_normal',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_media',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Obesidad_media',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_media',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_morbida',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_morbida',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'Unknown',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Prediabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Peso_normal',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Peso_normal',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_morbida',
#   'Unknown',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_morbida',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Prediabetes',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_morbida',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Obesidad_media',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'Unknown',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'smokes',
#   'No_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Sobrepeso',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_morbida',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Obesidad_morbida',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Peso_normal',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Peso_normal',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'Unknown',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Obesidad_leve',
#   'Unknown',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_media',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'Unknown',
#   'Si_ACV'],
#  ['Male',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_media',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_media',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_media',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_leve',
#   'Unknown',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'Unknown',
#   'Si_ACV'],
#  ['Male',
#   'Grandes ancianos',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Prediabetes',
#   'Peso_normal',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'No_casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_media',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_media',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_media',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_morbida',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Peso_normal',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_media',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Obesidad_morbida',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Obesidad_media',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_morbida',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Obesidad_morbida',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Prediabetes',
#   'Obesidad_media',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_media',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_morbida',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Prediabetes',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_leve',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_media',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Grandes ancianos',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_morbida',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_leve',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Obesidad_media',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Delgadez_moderada',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'smokes',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_media',
#   'Unknown',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'Unknown',
#   'Si_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_media',
#   'smokes',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_morbida',
#   'never smoked',
#   'Si_ACV'],
#  ['Female',
#   'Senectud',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_morbida',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_media',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Adolescencia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Menor_edad',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Obesidad_leve',
#   'Unknown',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'formerly smoked',
#   'Si_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'Unknown',
#   'Si_ACV'],
#  ['Male',
#   'Infancia_y_niñez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Menor_edad',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Delgadez_leve',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_media',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Infancia_y_niñez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Delgadez_leve',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Obesidad_media',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Delgadez_leve',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'smokes',
#   'No_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Peso_normal',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_media',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_morbida',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adolescencia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'smokes',
#   'No_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Peso_normal',
#   'smokes',
#   'No_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'smokes',
#   'No_ACV'],
#  ['Female',
#   'Senectud',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_morbida',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Obesidad_leve',
#   'smokes',
#   'No_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'smokes',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'smokes',
#   'No_ACV'],
#  ['Female',
#   'Infancia_y_niñez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Menor_edad',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Delgadez_severa',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Sobrepeso',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Adolescencia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Peso_normal',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Adolescencia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Sobrepeso',
#   'smokes',
#   'No_ACV'],
#  ['Male',
#   'Adolescencia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Menor_edad',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Delgadez_leve',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Infancia_y_niñez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Menor_edad',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Adolescencia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Menor_edad',
#   'Residencia_rural',
#   'Prediabetes',
#   'Peso_normal',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
# ...
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Obesidad_media',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_media',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Prediabetes',
#   'Sobrepeso',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'smokes',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Sobrepeso',
#   'smokes',
#   'No_ACV'],
#  ['Male',
#   'Adultez_intermedia',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Infancia_y_niñez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Menor_edad',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Delgadez_leve',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Obesidad_leve',
#   'smokes',
#   'No_ACV'],
#  ['Male',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'smokes',
#   'No_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_media',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adolescencia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Prediabetes',
#   'Obesidad_leve',
#   'smokes',
#   'No_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adolescencia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Infancia_y_niñez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Menor_edad',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Delgadez_leve',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'smokes',
#   'No_ACV'],
#  ['Male',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_media',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_morbida',
#   'formerly smoked',
#   'No_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Prediabetes',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Infancia_y_niñez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Menor_edad',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Obesidad_media',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Obesidad_media',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_media',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Adolescencia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Vejez',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Prediabetes',
#   'Obesidad_leve',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Adolescencia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Peso_normal',
#   'smokes',
#   'No_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Senectud',
#   'Si_hipertension',
#   'Si_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Infancia_y_niñez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Menor_edad',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Delgadez_severa',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Grandes ancianos',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Diabetes',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_morbida',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Infancia_y_niñez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Menor_edad',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Delgadez_leve',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Adultez_intermedia',
#   'Si_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Obesidad_morbida',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Obesidad_morbida',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'smokes',
#   'No_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_morbida',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Prediabetes',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_morbida',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Adolescencia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_media',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Prediabetes',
#   'Sobrepeso',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_leve',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Hipoglicemia',
#   'Sobrepeso',
#   'smokes',
#   'No_ACV'],
#  ['Male',
#   'Adolescencia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ['Male',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Obesidad_morbida',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Diabetes',
#   'Obesidad_media',
#   'formerly smoked',
#   'No_ACV'],
#  ['Female',
#   'Vejez',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_rural',
#   'Glucosa_normal',
#   'Peso_normal',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Sobrepeso',
#   'Unknown',
#   'No_ACV'],
#  ['Female',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Auto-empleado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_tardía',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Obesidad_leve',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Senectud',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_rural',
#   'Diabetes',
#   'Obesidad_leve',
#   'Unknown',
#   'No_ACV'],
#  ['Male',
#   'Adultez_intermedia',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'Casado',
#   'Trabajo_gobierno',
#   'Residencia_urbana',
#   'Hipoglicemia',
#   'Obesidad_leve',
#   'never smoked',
#   'No_ACV'],
#  ['Female',
#   'Adultez_joven',
#   'No_hipertension',
#   'No_enfermedad_corazon',
#   'No_casado',
#   'Trabajo_privado',
#   'Residencia_urbana',
#   'Glucosa_normal',
#   'Peso_normal',
#   'never smoked',
#   'No_ACV'],
#  ...]

# %% [markdown]
# Luego, se procede a hacer uso de la librería efficient_apriori de Python con la cual, dados valores umbrales de soporte y confianza, el algoritmo extrae tanto la lista de itemsets frecuentes como las reglas de asociación derivadas de dichos itemsets.

# %% [markdown]
# Se realizó una exploración de los resultados del algoritmo para distintos valores de soporte y confianza umbral. Cuando se hizo uso de soportes por debajo del 30% se obtuvo una gran cantidad de itemsets, muchos de ellos con reglas poco interesantes y, debido a la gran cantidad de datos, resultaría muy tedioso analizar todos los itemsets y reglas de asociación resultantes.
#
# Así que establece un umbral de soporte igual al 30% y una confianza umbral igual al 80%

# %%
from efficient_apriori import apriori
itemsets_apriori, rules_apriori = apriori(datos_asociacion_lista, min_support=0.3,  min_confidence=0.8)
print(itemsets_apriori)
# Out:
# {1: {('Male',): 2028, ('No_hipertension',): 4423, ('Casado',): 3257, ('Trabajo_privado',): 2840, ('Residencia_urbana',): 2491, ('Residencia_rural',): 2408, ('Glucosa_normal',): 2695, ('never smoked',): 1827, ('Female',): 2871, ('No_enfermedad_corazon',): 4625, ('Sobrepeso',): 1492, ('No_casado',): 1642, ('No_ACV',): 4654}, 2: {('Casado', 'Female'): 1936, ('Casado', 'Glucosa_normal'): 1727, ('Casado', 'No_ACV'): 3041, ('Casado', 'No_enfermedad_corazon'): 3014, ('Casado', 'No_hipertension'): 2830, ('Casado', 'Residencia_rural'): 1590, ('Casado', 'Residencia_urbana'): 1667, ('Casado', 'Trabajo_privado'): 2043, ('Female', 'Glucosa_normal'): 1614, ('Female', 'No_ACV'): 2732, ('Female', 'No_enfermedad_corazon'): 2759, ('Female', 'No_hipertension'): 2608, ('Female', 'Trabajo_privado'): 1690, ('Glucosa_normal', 'No_ACV'): 2594, ('Glucosa_normal', 'No_enfermedad_corazon'): 2584, ('Glucosa_normal', 'No_hipertension'): 2495, ('Glucosa_normal', 'Trabajo_privado'): 1571, ('Male', 'No_ACV'): 1922, ('Male', 'No_enfermedad_corazon'): 1866, ('Male', 'No_hipertension'): 1815, ('No_ACV', 'No_casado'): 1613, ('No_ACV', 'No_enfermedad_corazon'): 4426, ('No_ACV', 'No_hipertension'): 4243, ('No_ACV', 'Residencia_rural'): 2296, ('No_ACV', 'Residencia_urbana'): 2358, ('No_ACV', 'Trabajo_privado'): 2694, ('No_ACV', 'never smoked'): 1738, ('No_casado', 'No_enfermedad_corazon'): 1611, ('No_casado', 'No_hipertension'): 1593, ('No_enfermedad_corazon', 'No_hipertension'): 4213, ('No_enfermedad_corazon', 'Residencia_rural'): 2274, ('No_enfermedad_corazon', 'Residencia_urbana'): 2351, ('No_enfermedad_corazon', 'Trabajo_privado'): 2684, ('No_enfermedad_corazon', 'never smoked'): 1739, ('No_hipertension', 'Residencia_rural'): 2169, ('No_hipertension', 'Residencia_urbana'): 2254, ('No_hipertension', 'Trabajo_privado'): 2569, ('No_hipertension', 'never smoked'): 1604}, 3: {('Casado', 'Female', 'No_ACV'): 1818, ('Casado', 'Female', 'No_enfermedad_corazon'): 1841, ('Casado', 'Female', 'No_hipertension'): 1702, ('Casado', 'Glucosa_normal', 'No_ACV'): 1643, ('Casado', 'Glucosa_normal', 'No_enfermedad_corazon'): 1629, ('Casado', 'Glucosa_normal', 'No_hipertension'): 1551, ('Casado', 'No_ACV', 'No_enfermedad_corazon'): 2837, ('Casado', 'No_ACV', 'No_hipertension'): 2668, ('Casado', 'No_ACV', 'Residencia_rural'): 1486, ('Casado', 'No_ACV', 'Residencia_urbana'): 1555, ('Casado', 'No_ACV', 'Trabajo_privado'): 1911, ('Casado', 'No_enfermedad_corazon', 'No_hipertension'): 2642, ('Casado', 'No_enfermedad_corazon', 'Residencia_urbana'): 1545, ('Casado', 'No_enfermedad_corazon', 'Trabajo_privado'): 1901, ('Casado', 'No_hipertension', 'Trabajo_privado'): 1804, ('Female', 'Glucosa_normal', 'No_ACV'): 1554, ('Female', 'Glucosa_normal', 'No_enfermedad_corazon'): 1577, ('Female', 'Glucosa_normal', 'No_hipertension'): 1508, ('Female', 'No_ACV', 'No_enfermedad_corazon'): 2639, ('Female', 'No_ACV', 'No_hipertension'): 2508, ('Female', 'No_ACV', 'Trabajo_privado'): 1616, ('Female', 'No_enfermedad_corazon', 'No_hipertension'): 2525, ('Female', 'No_enfermedad_corazon', 'Trabajo_privado'): 1623, ('Female', 'No_hipertension', 'Trabajo_privado'): 1543, ('Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'): 2492, ('Glucosa_normal', 'No_ACV', 'No_hipertension'): 2414, ('Glucosa_normal', 'No_ACV', 'Trabajo_privado'): 1509, ('Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'): 2403, ('Glucosa_normal', 'No_enfermedad_corazon', 'Trabajo_privado'): 1517, ('Male', 'No_ACV', 'No_enfermedad_corazon'): 1787, ('Male', 'No_ACV', 'No_hipertension'): 1735, ('Male', 'No_enfermedad_corazon', 'No_hipertension'): 1688, ('No_ACV', 'No_casado', 'No_enfermedad_corazon'): 1589, ('No_ACV', 'No_casado', 'No_hipertension'): 1575, ('No_ACV', 'No_enfermedad_corazon', 'No_hipertension'): 4066, ('No_ACV', 'No_enfermedad_corazon', 'Residencia_rural'): 2181, ('No_ACV', 'No_enfermedad_corazon', 'Residencia_urbana'): 2245, ('No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'): 2568, ('No_ACV', 'No_enfermedad_cora ...

# %%
print(rules_apriori)
# Out:
# [{Casado} -> {No_ACV}, {Casado} -> {No_enfermedad_corazon}, {Casado} -> {No_hipertension}, {Female} -> {No_ACV}, {Female} -> {No_enfermedad_corazon}, {Female} -> {No_hipertension}, {Glucosa_normal} -> {No_ACV}, {Glucosa_normal} -> {No_enfermedad_corazon}, {Glucosa_normal} -> {No_hipertension}, {Male} -> {No_ACV}, {Male} -> {No_enfermedad_corazon}, {Male} -> {No_hipertension}, {No_casado} -> {No_ACV}, {No_enfermedad_corazon} -> {No_ACV}, {No_ACV} -> {No_enfermedad_corazon}, {No_hipertension} -> {No_ACV}, {No_ACV} -> {No_hipertension}, {Residencia_rural} -> {No_ACV}, {Residencia_urbana} -> {No_ACV}, {Trabajo_privado} -> {No_ACV}, {never smoked} -> {No_ACV}, {No_casado} -> {No_enfermedad_corazon}, {No_casado} -> {No_hipertension}, {No_hipertension} -> {No_enfermedad_corazon}, {No_enfermedad_corazon} -> {No_hipertension}, {Residencia_rural} -> {No_enfermedad_corazon}, {Residencia_urbana} -> {No_enfermedad_corazon}, {Trabajo_privado} -> {No_enfermedad_corazon}, {never smoked} -> {No_enfermedad_corazon}, {Residencia_rural} -> {No_hipertension}, {Residencia_urbana} -> {No_hipertension}, {Trabajo_privado} -> {No_hipertension}, {never smoked} -> {No_hipertension}, {Casado, Female} -> {No_ACV}, {Casado, Female} -> {No_enfermedad_corazon}, {Casado, Female} -> {No_hipertension}, {Casado, Glucosa_normal} -> {No_ACV}, {Casado, Glucosa_normal} -> {No_enfermedad_corazon}, {Casado, Glucosa_normal} -> {No_hipertension}, {Casado, No_enfermedad_corazon} -> {No_ACV}, {Casado, No_ACV} -> {No_enfermedad_corazon}, {Casado} -> {No_ACV, No_enfermedad_corazon}, {Casado, No_hipertension} -> {No_ACV}, {Casado, No_ACV} -> {No_hipertension}, {Casado} -> {No_ACV, No_hipertension}, {Casado, Residencia_rural} -> {No_ACV}, {Casado, Residencia_urbana} -> {No_ACV}, {Casado, Trabajo_privado} -> {No_ACV}, {Casado, No_hipertension} -> {No_enfermedad_corazon}, {Casado, No_enfermedad_corazon} -> {No_hipertension}, {Casado} -> {No_enfermedad_corazon, No_hipertension}, {Casado, Residencia_urbana} -> {No_enfermedad_corazon}, {Casado, Trabajo_privado} -> {No_enfermedad_corazon}, {Casado, Trabajo_privado} -> {No_hipertension}, {Female, Glucosa_normal} -> {No_ACV}, {Female, Glucosa_normal} -> {No_enfermedad_corazon}, {Female, Glucosa_normal} -> {No_hipertension}, {Female, No_enfermedad_corazon} -> {No_ACV}, {Female, No_ACV} -> {No_enfermedad_corazon}, {Female} -> {No_ACV, No_enfermedad_corazon}, {Female, No_hipertension} -> {No_ACV}, {Female, No_ACV} -> {No_hipertension}, {Female} -> {No_ACV, No_hipertension}, {Female, Trabajo_privado} -> {No_ACV}, {Female, No_hipertension} -> {No_enfermedad_corazon}, {Female, No_enfermedad_corazon} -> {No_hipertension}, {Female} -> {No_enfermedad_corazon, No_hipertension}, {Female, Trabajo_privado} -> {No_enfermedad_corazon}, {Female, Trabajo_privado} -> {No_hipertension}, {Glucosa_normal, No_enfermedad_corazon} -> {No_ACV}, {Glucosa_normal, No_ACV} -> {No_enfermedad_corazon}, {Glucosa_normal} -> {No_ACV, No_enfermedad_corazon}, {Glucosa_normal, No_hipertension} -> {No_ACV}, {Glucosa_normal, No_ACV} -> {No_hipertension}, {Glucosa_normal} -> {No_ACV, No_hipertension}, {Glucosa_normal, Trabajo_privado} -> {No_ACV}, {Glucosa_normal, No_hipertension} -> {No_enfermedad_corazon}, {Glucosa_normal, No_enfermedad_corazon} -> {No_hipertension}, {Glucosa_normal} -> {No_enfermedad_corazon, No_hipertension}, {Glucosa_normal, Trabajo_privado} -> {No_enfermedad_corazon}, {Male, No_enfermedad_corazon} -> {No_ACV}, {Male, No_ACV} -> {No_enfermedad_corazon}, {Male} -> {No_ACV, No_enfermedad_corazon}, {Male, No_hipertension} -> {No_ACV}, {Male, No_ACV} -> {No_hipertension}, {Male} -> {No_ACV, No_hipertension}, {Male, No_hipertension} -> {No_enfermedad_corazon}, {Male, No_enfermedad_corazon} -> {No_hipertension}, {Male} -> {No_enfermedad_corazon, No_hipertension}, {No_casado, No_enfermedad_corazon} -> {No_ACV}, {No_ACV, No_casado} -> {No_enfermedad_corazon}, {No_casado} -> {No_ACV, No_enfermedad_corazon}, {No_casado, No_hipertension} -> {No_ACV}, {No_ACV, No_ ...

# %% [markdown]
# Algunas reglas que se obtienen del algoritmo son las siguientes:
#
#
# {Female, No_ACV, Trabajo_privado} -> {No_hipertension}
#
# {Glucosa_normal, No_hipertension} -> {No_ACV}
#
# {No_enfermedad_corazon, No_hipertension} -> {No_ACV}
#
# {No_enfermedad_corazon, Residencia_rural} -> {No_ACV}
#
# {No_ACV, never smoked} -> {No_hipertension}
#
# {No_hipertension, Residencia_rural} -> {No_enfermedad_corazon}
#
# {Casado, Female, No_enfermedad_corazon} -> {No_ACV}
#
# {Casado, Glucosa_normal, No_hipertension} -> {No_ACV}
#
# {Casado, No_enfermedad_corazon, Trabajo_privado} -> {No_ACV}
#
# {Male, No_enfermedad_corazon, No_hipertension} -> {No_ACV}
#
# {No_ACV, No_hipertension, Trabajo_privado} -> {No_enfermedad_corazon}
#
# Muchas de ellas son redundantes e intuitivas, a lo que se le suma el bajo valor de soporte.
#
# Adicionalmente, el algoritmo no extrajo ninguna regla relacionada a Si_ACV.
# Esto se puede explicar debido a que existen 20 veces menos registros para Si_ACV comparado con No_ACV. Por tanto, es necesario hacer asociación separando los registros en dos grupos: cuando existe ACV y cuando no existe ACV.

# %% [markdown]
# ### 10.1.1) Separación de datos por clase

# %%
total = len(datos_asociacion_lista)
datos_Si_ACV = []
datos_No_ACV = []
for i in range(0,total):
    if clase[i] == 1:
        datos_Si_ACV.append(datos_asociacion_lista[i])
    elif clase[i] == 0:
        datos_No_ACV.append(datos_asociacion_lista[i])

# %% [markdown]
# ### 10.1.2) Asociación para la clase Si_ACV

# %% [markdown]
# Se hará uso de las librerías de efficient_apriori para aquellos datos con la clase Si_ACV.
#
# Se empieza con un valor de soporte del 30% con una confianza del 80%.

# %%
itemsets_apriori, rules_apriori = apriori(datos_Si_ACV, min_support=0.3,  min_confidence=0.8)
print(itemsets_apriori)
# Out:
# {1: {('Male',): 106, ('No_hipertension',): 180, ('Casado',): 216, ('Trabajo_privado',): 146, ('Residencia_urbana',): 133, ('Diabetes',): 98, ('Si_ACV',): 245, ('Vejez',): 105, ('Residencia_rural',): 112, ('Glucosa_normal',): 101, ('never smoked',): 89, ('Female',): 139, ('No_enfermedad_corazon',): 199, ('Sobrepeso',): 99}, 2: {('Casado', 'Diabetes'): 92, ('Casado', 'Female'): 118, ('Casado', 'Glucosa_normal'): 84, ('Casado', 'Male'): 98, ('Casado', 'No_enfermedad_corazon'): 177, ('Casado', 'No_hipertension'): 162, ('Casado', 'Residencia_rural'): 104, ('Casado', 'Residencia_urbana'): 112, ('Casado', 'Si_ACV'): 216, ('Casado', 'Sobrepeso'): 89, ('Casado', 'Trabajo_privado'): 132, ('Casado', 'Vejez'): 92, ('Casado', 'never smoked'): 74, ('Diabetes', 'Si_ACV'): 98, ('Female', 'No_enfermedad_corazon'): 120, ('Female', 'No_hipertension'): 100, ('Female', 'Residencia_urbana'): 76, ('Female', 'Si_ACV'): 139, ('Female', 'Trabajo_privado'): 74, ('Glucosa_normal', 'No_enfermedad_corazon'): 92, ('Glucosa_normal', 'No_hipertension'): 81, ('Glucosa_normal', 'Si_ACV'): 101, ('Male', 'No_enfermedad_corazon'): 79, ('Male', 'No_hipertension'): 80, ('Male', 'Si_ACV'): 106, ('No_enfermedad_corazon', 'No_hipertension'): 147, ('No_enfermedad_corazon', 'Residencia_rural'): 93, ('No_enfermedad_corazon', 'Residencia_urbana'): 106, ('No_enfermedad_corazon', 'Si_ACV'): 199, ('No_enfermedad_corazon', 'Sobrepeso'): 83, ('No_enfermedad_corazon', 'Trabajo_privado'): 116, ('No_enfermedad_corazon', 'Vejez'): 86, ('No_enfermedad_corazon', 'never smoked'): 77, ('No_hipertension', 'Residencia_rural'): 80, ('No_hipertension', 'Residencia_urbana'): 100, ('No_hipertension', 'Si_ACV'): 180, ('No_hipertension', 'Sobrepeso'): 75, ('No_hipertension', 'Trabajo_privado'): 113, ('Residencia_rural', 'Si_ACV'): 112, ('Residencia_urbana', 'Si_ACV'): 133, ('Residencia_urbana', 'Trabajo_privado'): 80, ('Si_ACV', 'Sobrepeso'): 99, ('Si_ACV', 'Trabajo_privado'): 146, ('Si_ACV', 'Vejez'): 105, ('Si_ACV', 'never smoked'): 89}, 3: {('Casado', 'Diabetes', 'Si_ACV'): 92, ('Casado', 'Female', 'No_enfermedad_corazon'): 104, ('Casado', 'Female', 'No_hipertension'): 87, ('Casado', 'Female', 'Si_ACV'): 118, ('Casado', 'Glucosa_normal', 'No_enfermedad_corazon'): 77, ('Casado', 'Glucosa_normal', 'Si_ACV'): 84, ('Casado', 'Male', 'No_hipertension'): 75, ('Casado', 'Male', 'Si_ACV'): 98, ('Casado', 'No_enfermedad_corazon', 'No_hipertension'): 132, ('Casado', 'No_enfermedad_corazon', 'Residencia_rural'): 88, ('Casado', 'No_enfermedad_corazon', 'Residencia_urbana'): 89, ('Casado', 'No_enfermedad_corazon', 'Si_ACV'): 177, ('Casado', 'No_enfermedad_corazon', 'Sobrepeso'): 76, ('Casado', 'No_enfermedad_corazon', 'Trabajo_privado'): 104, ('Casado', 'No_enfermedad_corazon', 'Vejez'): 77, ('Casado', 'No_hipertension', 'Residencia_rural'): 76, ('Casado', 'No_hipertension', 'Residencia_urbana'): 86, ('Casado', 'No_hipertension', 'Si_ACV'): 162, ('Casado', 'No_hipertension', 'Trabajo_privado'): 105, ('Casado', 'Residencia_rural', 'Si_ACV'): 104, ('Casado', 'Residencia_urbana', 'Si_ACV'): 112, ('Casado', 'Si_ACV', 'Sobrepeso'): 89, ('Casado', 'Si_ACV', 'Trabajo_privado'): 132, ('Casado', 'Si_ACV', 'Vejez'): 92, ('Casado', 'Si_ACV', 'never smoked'): 74, ('Female', 'No_enfermedad_corazon', 'No_hipertension'): 88, ('Female', 'No_enfermedad_corazon', 'Si_ACV'): 120, ('Female', 'No_hipertension', 'Si_ACV'): 100, ('Female', 'Residencia_urbana', 'Si_ACV'): 76, ('Female', 'Si_ACV', 'Trabajo_privado'): 74, ('Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'): 75, ('Glucosa_normal', 'No_enfermedad_corazon', 'Si_ACV'): 92, ('Glucosa_normal', 'No_hipertension', 'Si_ACV'): 81, ('Male', 'No_enfermedad_corazon', 'Si_ACV'): 79, ('Male', 'No_hipertension', 'Si_ACV'): 80, ('No_enfermedad_corazon', 'No_hipertension', 'Residencia_urbana'): 81, ('No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'): 147, ('No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'): 91, ('No_enfermedad_corazon', 'Residencia_rural ...

# %%
print(rules_apriori)
# Out:
# [{Diabetes} -> {Casado}, {Female} -> {Casado}, {Glucosa_normal} -> {Casado}, {Male} -> {Casado}, {No_enfermedad_corazon} -> {Casado}, {Casado} -> {No_enfermedad_corazon}, {No_hipertension} -> {Casado}, {Residencia_rural} -> {Casado}, {Residencia_urbana} -> {Casado}, {Si_ACV} -> {Casado}, {Casado} -> {Si_ACV}, {Sobrepeso} -> {Casado}, {Trabajo_privado} -> {Casado}, {Vejez} -> {Casado}, {never smoked} -> {Casado}, {Diabetes} -> {Si_ACV}, {Female} -> {No_enfermedad_corazon}, {Female} -> {Si_ACV}, {Glucosa_normal} -> {No_enfermedad_corazon}, {Glucosa_normal} -> {No_hipertension}, {Glucosa_normal} -> {Si_ACV}, {Male} -> {Si_ACV}, {No_hipertension} -> {No_enfermedad_corazon}, {Residencia_rural} -> {No_enfermedad_corazon}, {Si_ACV} -> {No_enfermedad_corazon}, {No_enfermedad_corazon} -> {Si_ACV}, {Sobrepeso} -> {No_enfermedad_corazon}, {Vejez} -> {No_enfermedad_corazon}, {never smoked} -> {No_enfermedad_corazon}, {No_hipertension} -> {Si_ACV}, {Residencia_rural} -> {Si_ACV}, {Residencia_urbana} -> {Si_ACV}, {Sobrepeso} -> {Si_ACV}, {Trabajo_privado} -> {Si_ACV}, {Vejez} -> {Si_ACV}, {never smoked} -> {Si_ACV}, {Diabetes, Si_ACV} -> {Casado}, {Casado, Diabetes} -> {Si_ACV}, {Diabetes} -> {Casado, Si_ACV}, {Female, No_enfermedad_corazon} -> {Casado}, {Casado, Female} -> {No_enfermedad_corazon}, {Female, No_hipertension} -> {Casado}, {Female, Si_ACV} -> {Casado}, {Casado, Female} -> {Si_ACV}, {Female} -> {Casado, Si_ACV}, {Glucosa_normal, No_enfermedad_corazon} -> {Casado}, {Casado, Glucosa_normal} -> {No_enfermedad_corazon}, {Glucosa_normal, Si_ACV} -> {Casado}, {Casado, Glucosa_normal} -> {Si_ACV}, {Glucosa_normal} -> {Casado, Si_ACV}, {Male, No_hipertension} -> {Casado}, {Male, Si_ACV} -> {Casado}, {Casado, Male} -> {Si_ACV}, {Male} -> {Casado, Si_ACV}, {No_enfermedad_corazon, No_hipertension} -> {Casado}, {Casado, No_hipertension} -> {No_enfermedad_corazon}, {No_enfermedad_corazon, Residencia_rural} -> {Casado}, {Casado, Residencia_rural} -> {No_enfermedad_corazon}, {No_enfermedad_corazon, Residencia_urbana} -> {Casado}, {No_enfermedad_corazon, Si_ACV} -> {Casado}, {Casado, Si_ACV} -> {No_enfermedad_corazon}, {Casado, No_enfermedad_corazon} -> {Si_ACV}, {No_enfermedad_corazon} -> {Casado, Si_ACV}, {Casado} -> {No_enfermedad_corazon, Si_ACV}, {No_enfermedad_corazon, Sobrepeso} -> {Casado}, {Casado, Sobrepeso} -> {No_enfermedad_corazon}, {No_enfermedad_corazon, Trabajo_privado} -> {Casado}, {No_enfermedad_corazon, Vejez} -> {Casado}, {Casado, Vejez} -> {No_enfermedad_corazon}, {No_hipertension, Residencia_rural} -> {Casado}, {No_hipertension, Residencia_urbana} -> {Casado}, {No_hipertension, Si_ACV} -> {Casado}, {Casado, No_hipertension} -> {Si_ACV}, {No_hipertension} -> {Casado, Si_ACV}, {No_hipertension, Trabajo_privado} -> {Casado}, {Residencia_rural, Si_ACV} -> {Casado}, {Casado, Residencia_rural} -> {Si_ACV}, {Residencia_rural} -> {Casado, Si_ACV}, {Residencia_urbana, Si_ACV} -> {Casado}, {Casado, Residencia_urbana} -> {Si_ACV}, {Residencia_urbana} -> {Casado, Si_ACV}, {Si_ACV, Sobrepeso} -> {Casado}, {Casado, Sobrepeso} -> {Si_ACV}, {Sobrepeso} -> {Casado, Si_ACV}, {Si_ACV, Trabajo_privado} -> {Casado}, {Casado, Trabajo_privado} -> {Si_ACV}, {Trabajo_privado} -> {Casado, Si_ACV}, {Si_ACV, Vejez} -> {Casado}, {Casado, Vejez} -> {Si_ACV}, {Vejez} -> {Casado, Si_ACV}, {Si_ACV, never smoked} -> {Casado}, {Casado, never smoked} -> {Si_ACV}, {never smoked} -> {Casado, Si_ACV}, {Female, No_hipertension} -> {No_enfermedad_corazon}, {Female, Si_ACV} -> {No_enfermedad_corazon}, {Female, No_enfermedad_corazon} -> {Si_ACV}, {Female} -> {No_enfermedad_corazon, Si_ACV}, {Female, No_hipertension} -> {Si_ACV}, {Female, Residencia_urbana} -> {Si_ACV}, {Female, Trabajo_privado} -> {Si_ACV}, {Glucosa_normal, No_hipertension} -> {No_enfermedad_corazon}, {Glucosa_normal, No_enfermedad_corazon} -> {No_hipertension}, {Glucosa_normal, Si_ACV} -> {No_enfermedad_corazon}, {Glucosa_normal, No_enfermedad_corazon} -> {Si_ACV}, {Glucosa_normal} -> {No_enferme ...

# %% [markdown]
# {Diabetes} -> {Si_ACV}
#
# {Sobrepeso} -> {Si_ACV}
#
# {Vejez} -> {Si_ACV}
#
# {Female, Residencia_urbana} -> {Si_ACV}
#
# {Female, Trabajo_privado} -> {Si_ACV}
#
# {Si_hipertension, Vejez} -> {Si_ACV} ***
#
# {Casado, Si_enfermedad_corazon, Residencia_urbana} -> {Si_ACV} ***
#
# {Residencia_urbana} -> {Si_ACV}
#
# {Casado, Si_enfermedad_corazon} -> {Si_ACV}
#
# {No_enfermedad_corazon, No_hipertension} -> {Si_ACV} ***

# %% [markdown]
# Ahora se fija un soporte de 50% con una confianza del 80%

# %%
itemsets_apriori, rules_apriori = apriori(datos_Si_ACV, min_support=0.5,  min_confidence=0.8)
print(itemsets_apriori)
# Out:
# {1: {('No_hipertension',): 180, ('Casado',): 216, ('Trabajo_privado',): 146, ('Residencia_urbana',): 133, ('Si_ACV',): 245, ('Female',): 139, ('No_enfermedad_corazon',): 199}, 2: {('Casado', 'No_enfermedad_corazon'): 177, ('Casado', 'No_hipertension'): 162, ('Casado', 'Si_ACV'): 216, ('Casado', 'Trabajo_privado'): 132, ('Female', 'Si_ACV'): 139, ('No_enfermedad_corazon', 'No_hipertension'): 147, ('No_enfermedad_corazon', 'Si_ACV'): 199, ('No_hipertension', 'Si_ACV'): 180, ('Residencia_urbana', 'Si_ACV'): 133, ('Si_ACV', 'Trabajo_privado'): 146}, 3: {('Casado', 'No_enfermedad_corazon', 'No_hipertension'): 132, ('Casado', 'No_enfermedad_corazon', 'Si_ACV'): 177, ('Casado', 'No_hipertension', 'Si_ACV'): 162, ('Casado', 'Si_ACV', 'Trabajo_privado'): 132, ('No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'): 147}, 4: {('Casado', 'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'): 132}}

# %%
print(rules_apriori)
# Out:
# [{No_enfermedad_corazon} -> {Casado}, {Casado} -> {No_enfermedad_corazon}, {No_hipertension} -> {Casado}, {Si_ACV} -> {Casado}, {Casado} -> {Si_ACV}, {Trabajo_privado} -> {Casado}, {Female} -> {Si_ACV}, {No_hipertension} -> {No_enfermedad_corazon}, {Si_ACV} -> {No_enfermedad_corazon}, {No_enfermedad_corazon} -> {Si_ACV}, {No_hipertension} -> {Si_ACV}, {Residencia_urbana} -> {Si_ACV}, {Trabajo_privado} -> {Si_ACV}, {No_enfermedad_corazon, No_hipertension} -> {Casado}, {Casado, No_hipertension} -> {No_enfermedad_corazon}, {No_enfermedad_corazon, Si_ACV} -> {Casado}, {Casado, Si_ACV} -> {No_enfermedad_corazon}, {Casado, No_enfermedad_corazon} -> {Si_ACV}, {No_enfermedad_corazon} -> {Casado, Si_ACV}, {Casado} -> {No_enfermedad_corazon, Si_ACV}, {No_hipertension, Si_ACV} -> {Casado}, {Casado, No_hipertension} -> {Si_ACV}, {No_hipertension} -> {Casado, Si_ACV}, {Si_ACV, Trabajo_privado} -> {Casado}, {Casado, Trabajo_privado} -> {Si_ACV}, {Trabajo_privado} -> {Casado, Si_ACV}, {No_hipertension, Si_ACV} -> {No_enfermedad_corazon}, {No_enfermedad_corazon, No_hipertension} -> {Si_ACV}, {No_hipertension} -> {No_enfermedad_corazon, Si_ACV}, {No_enfermedad_corazon, No_hipertension, Si_ACV} -> {Casado}, {Casado, No_hipertension, Si_ACV} -> {No_enfermedad_corazon}, {Casado, No_enfermedad_corazon, No_hipertension} -> {Si_ACV}, {No_enfermedad_corazon, No_hipertension} -> {Casado, Si_ACV}, {Casado, No_hipertension} -> {No_enfermedad_corazon, Si_ACV}]

# %% [markdown]
# Se destacan las siguientes reglas:
#
# {Casado} -> {Si_ACV}
#
# {Female} -> {Si_ACV}
#
# {Residencia_urbana} -> {Si_ACV}
#
# {Casado, Si_enfermedad_corazon} -> {Si_ACV}
#
# {Casado, No_enfermedad_corazon, No_hipertension} -> {Si_ACV}

# %% [markdown]
# ### 10.1.3) Asociación para la clase No_ACV

# %% [markdown]
# Se hará uso de las librerías de efficient_apriori para aquellos datos con la clase No_ACV.

# %%
itemsets_apriori, rules_apriori = apriori(datos_No_ACV, min_support=0.3,  min_confidence=0.8)
print(itemsets_apriori)
# Out:
# {1: {('Male',): 1922, ('No_hipertension',): 4243, ('Casado',): 3041, ('Trabajo_privado',): 2694, ('Residencia_rural',): 2296, ('No_ACV',): 4654, ('No_enfermedad_corazon',): 4426, ('No_casado',): 1613, ('Glucosa_normal',): 2594, ('Unknown',): 1398, ('Residencia_urbana',): 2358, ('never smoked',): 1738, ('Female',): 2732}, 2: {('Casado', 'Female'): 1818, ('Casado', 'Glucosa_normal'): 1643, ('Casado', 'No_ACV'): 3041, ('Casado', 'No_enfermedad_corazon'): 2837, ('Casado', 'No_hipertension'): 2668, ('Casado', 'Residencia_rural'): 1486, ('Casado', 'Residencia_urbana'): 1555, ('Casado', 'Trabajo_privado'): 1911, ('Female', 'Glucosa_normal'): 1554, ('Female', 'No_ACV'): 2732, ('Female', 'No_enfermedad_corazon'): 2639, ('Female', 'No_hipertension'): 2508, ('Female', 'Trabajo_privado'): 1616, ('Glucosa_normal', 'No_ACV'): 2594, ('Glucosa_normal', 'No_enfermedad_corazon'): 2492, ('Glucosa_normal', 'No_hipertension'): 2414, ('Glucosa_normal', 'Trabajo_privado'): 1509, ('Male', 'No_ACV'): 1922, ('Male', 'No_enfermedad_corazon'): 1787, ('Male', 'No_hipertension'): 1735, ('No_ACV', 'No_casado'): 1613, ('No_ACV', 'No_enfermedad_corazon'): 4426, ('No_ACV', 'No_hipertension'): 4243, ('No_ACV', 'Residencia_rural'): 2296, ('No_ACV', 'Residencia_urbana'): 2358, ('No_ACV', 'Trabajo_privado'): 2694, ('No_ACV', 'Unknown'): 1398, ('No_ACV', 'never smoked'): 1738, ('No_casado', 'No_enfermedad_corazon'): 1589, ('No_casado', 'No_hipertension'): 1575, ('No_enfermedad_corazon', 'No_hipertension'): 4066, ('No_enfermedad_corazon', 'Residencia_rural'): 2181, ('No_enfermedad_corazon', 'Residencia_urbana'): 2245, ('No_enfermedad_corazon', 'Trabajo_privado'): 2568, ('No_enfermedad_corazon', 'never smoked'): 1662, ('No_hipertension', 'Residencia_rural'): 2089, ('No_hipertension', 'Residencia_urbana'): 2154, ('No_hipertension', 'Trabajo_privado'): 2456, ('No_hipertension', 'never smoked'): 1547}, 3: {('Casado', 'Female', 'No_ACV'): 1818, ('Casado', 'Female', 'No_enfermedad_corazon'): 1737, ('Casado', 'Female', 'No_hipertension'): 1615, ('Casado', 'Glucosa_normal', 'No_ACV'): 1643, ('Casado', 'Glucosa_normal', 'No_enfermedad_corazon'): 1552, ('Casado', 'Glucosa_normal', 'No_hipertension'): 1483, ('Casado', 'No_ACV', 'No_enfermedad_corazon'): 2837, ('Casado', 'No_ACV', 'No_hipertension'): 2668, ('Casado', 'No_ACV', 'Residencia_rural'): 1486, ('Casado', 'No_ACV', 'Residencia_urbana'): 1555, ('Casado', 'No_ACV', 'Trabajo_privado'): 1911, ('Casado', 'No_enfermedad_corazon', 'No_hipertension'): 2510, ('Casado', 'No_enfermedad_corazon', 'Residencia_urbana'): 1456, ('Casado', 'No_enfermedad_corazon', 'Trabajo_privado'): 1797, ('Casado', 'No_hipertension', 'Trabajo_privado'): 1699, ('Female', 'Glucosa_normal', 'No_ACV'): 1554, ('Female', 'Glucosa_normal', 'No_enfermedad_corazon'): 1520, ('Female', 'Glucosa_normal', 'No_hipertension'): 1462, ('Female', 'No_ACV', 'No_enfermedad_corazon'): 2639, ('Female', 'No_ACV', 'No_hipertension'): 2508, ('Female', 'No_ACV', 'Trabajo_privado'): 1616, ('Female', 'No_enfermedad_corazon', 'No_hipertension'): 2437, ('Female', 'No_enfermedad_corazon', 'Trabajo_privado'): 1560, ('Female', 'No_hipertension', 'Trabajo_privado'): 1486, ('Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'): 2492, ('Glucosa_normal', 'No_ACV', 'No_hipertension'): 2414, ('Glucosa_normal', 'No_ACV', 'Trabajo_privado'): 1509, ('Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'): 2328, ('Glucosa_normal', 'No_enfermedad_corazon', 'Trabajo_privado'): 1460, ('Glucosa_normal', 'No_hipertension', 'Trabajo_privado'): 1408, ('Male', 'No_ACV', 'No_enfermedad_corazon'): 1787, ('Male', 'No_ACV', 'No_hipertension'): 1735, ('Male', 'No_enfermedad_corazon', 'No_hipertension'): 1629, ('No_ACV', 'No_casado', 'No_enfermedad_corazon'): 1589, ('No_ACV', 'No_casado', 'No_hipertension'): 1575, ('No_ACV', 'No_enfermedad_corazon', 'No_hipertension'): 4066, ('No_ACV', 'No_enfermedad_corazon', 'Residencia_rural'): 2181, ('No_ACV', 'No_enfermedad_corazon', 'Residencia_urbana'): 2245, ( ...

# %%
print(rules_apriori)
# Out:
# [{Casado} -> {No_ACV}, {Casado} -> {No_enfermedad_corazon}, {Casado} -> {No_hipertension}, {Female} -> {No_ACV}, {Female} -> {No_enfermedad_corazon}, {Female} -> {No_hipertension}, {Glucosa_normal} -> {No_ACV}, {Glucosa_normal} -> {No_enfermedad_corazon}, {Glucosa_normal} -> {No_hipertension}, {Male} -> {No_ACV}, {Male} -> {No_enfermedad_corazon}, {Male} -> {No_hipertension}, {No_casado} -> {No_ACV}, {No_enfermedad_corazon} -> {No_ACV}, {No_ACV} -> {No_enfermedad_corazon}, {No_hipertension} -> {No_ACV}, {No_ACV} -> {No_hipertension}, {Residencia_rural} -> {No_ACV}, {Residencia_urbana} -> {No_ACV}, {Trabajo_privado} -> {No_ACV}, {Unknown} -> {No_ACV}, {never smoked} -> {No_ACV}, {No_casado} -> {No_enfermedad_corazon}, {No_casado} -> {No_hipertension}, {No_hipertension} -> {No_enfermedad_corazon}, {No_enfermedad_corazon} -> {No_hipertension}, {Residencia_rural} -> {No_enfermedad_corazon}, {Residencia_urbana} -> {No_enfermedad_corazon}, {Trabajo_privado} -> {No_enfermedad_corazon}, {never smoked} -> {No_enfermedad_corazon}, {Residencia_rural} -> {No_hipertension}, {Residencia_urbana} -> {No_hipertension}, {Trabajo_privado} -> {No_hipertension}, {never smoked} -> {No_hipertension}, {Casado, Female} -> {No_ACV}, {Casado, Female} -> {No_enfermedad_corazon}, {Casado, Female} -> {No_hipertension}, {Casado, Glucosa_normal} -> {No_ACV}, {Casado, Glucosa_normal} -> {No_enfermedad_corazon}, {Casado, Glucosa_normal} -> {No_hipertension}, {Casado, No_enfermedad_corazon} -> {No_ACV}, {Casado, No_ACV} -> {No_enfermedad_corazon}, {Casado} -> {No_ACV, No_enfermedad_corazon}, {Casado, No_hipertension} -> {No_ACV}, {Casado, No_ACV} -> {No_hipertension}, {Casado} -> {No_ACV, No_hipertension}, {Casado, Residencia_rural} -> {No_ACV}, {Casado, Residencia_urbana} -> {No_ACV}, {Casado, Trabajo_privado} -> {No_ACV}, {Casado, No_hipertension} -> {No_enfermedad_corazon}, {Casado, No_enfermedad_corazon} -> {No_hipertension}, {Casado} -> {No_enfermedad_corazon, No_hipertension}, {Casado, Residencia_urbana} -> {No_enfermedad_corazon}, {Casado, Trabajo_privado} -> {No_enfermedad_corazon}, {Casado, Trabajo_privado} -> {No_hipertension}, {Female, Glucosa_normal} -> {No_ACV}, {Female, Glucosa_normal} -> {No_enfermedad_corazon}, {Female, Glucosa_normal} -> {No_hipertension}, {Female, No_enfermedad_corazon} -> {No_ACV}, {Female, No_ACV} -> {No_enfermedad_corazon}, {Female} -> {No_ACV, No_enfermedad_corazon}, {Female, No_hipertension} -> {No_ACV}, {Female, No_ACV} -> {No_hipertension}, {Female} -> {No_ACV, No_hipertension}, {Female, Trabajo_privado} -> {No_ACV}, {Female, No_hipertension} -> {No_enfermedad_corazon}, {Female, No_enfermedad_corazon} -> {No_hipertension}, {Female} -> {No_enfermedad_corazon, No_hipertension}, {Female, Trabajo_privado} -> {No_enfermedad_corazon}, {Female, Trabajo_privado} -> {No_hipertension}, {Glucosa_normal, No_enfermedad_corazon} -> {No_ACV}, {Glucosa_normal, No_ACV} -> {No_enfermedad_corazon}, {Glucosa_normal} -> {No_ACV, No_enfermedad_corazon}, {Glucosa_normal, No_hipertension} -> {No_ACV}, {Glucosa_normal, No_ACV} -> {No_hipertension}, {Glucosa_normal} -> {No_ACV, No_hipertension}, {Glucosa_normal, Trabajo_privado} -> {No_ACV}, {Glucosa_normal, No_hipertension} -> {No_enfermedad_corazon}, {Glucosa_normal, No_enfermedad_corazon} -> {No_hipertension}, {Glucosa_normal} -> {No_enfermedad_corazon, No_hipertension}, {Glucosa_normal, Trabajo_privado} -> {No_enfermedad_corazon}, {Glucosa_normal, Trabajo_privado} -> {No_hipertension}, {Male, No_enfermedad_corazon} -> {No_ACV}, {Male, No_ACV} -> {No_enfermedad_corazon}, {Male} -> {No_ACV, No_enfermedad_corazon}, {Male, No_hipertension} -> {No_ACV}, {Male, No_ACV} -> {No_hipertension}, {Male} -> {No_ACV, No_hipertension}, {Male, No_hipertension} -> {No_enfermedad_corazon}, {Male, No_enfermedad_corazon} -> {No_hipertension}, {Male} -> {No_enfermedad_corazon, No_hipertension}, {No_casado, No_enfermedad_corazon} -> {No_ACV}, {No_ACV, No_casado} -> {No_enfermedad_corazon}, {No_casado} -> {No_ACV, ...

# %% [markdown]
# {Casado, Glucosa_normal, No_enfermedad_corazon} -> {No_ACV}
#
# {Casado, Residencia_rural} -> {No_ACV}
#
# {Male, No_hipertension} -> {No_ACV}
#
# {No_casado, No_hipertension} -> {No_ACV}
#
# {No_enfermedad_corazon, Trabajo_privado} -> {No_ACV}
#
# {No_enfermedad_corazon, never smoked} -> {No_ACV}
#
# {No_hipertension, Residencia_rural} -> {No_ACV}
#
# {Casado, No_hipertension, Trabajo_privado} -> {No_ACV}
#
# {Male, No_enfermedad_corazon, No_hipertension} -> {No_ACV}
#
# {No_casado, No_enfermedad_corazon, No_hipertension} -> {No_ACV}
#
# {Female, No_enfermedad_corazon, No_hipertension, Trabajo_privado} -> {No_ACV}

# %%
itemsets_apriori, rules_apriori = apriori(datos_No_ACV, min_support=0.5,  min_confidence=0.9)
print(itemsets_apriori)
# Out:
# {1: {('No_hipertension',): 4243, ('Casado',): 3041, ('Trabajo_privado',): 2694, ('No_ACV',): 4654, ('No_enfermedad_corazon',): 4426, ('Glucosa_normal',): 2594, ('Residencia_urbana',): 2358, ('Female',): 2732}, 2: {('Casado', 'No_ACV'): 3041, ('Casado', 'No_enfermedad_corazon'): 2837, ('Casado', 'No_hipertension'): 2668, ('Female', 'No_ACV'): 2732, ('Female', 'No_enfermedad_corazon'): 2639, ('Female', 'No_hipertension'): 2508, ('Glucosa_normal', 'No_ACV'): 2594, ('Glucosa_normal', 'No_enfermedad_corazon'): 2492, ('Glucosa_normal', 'No_hipertension'): 2414, ('No_ACV', 'No_enfermedad_corazon'): 4426, ('No_ACV', 'No_hipertension'): 4243, ('No_ACV', 'Residencia_urbana'): 2358, ('No_ACV', 'Trabajo_privado'): 2694, ('No_enfermedad_corazon', 'No_hipertension'): 4066, ('No_enfermedad_corazon', 'Trabajo_privado'): 2568, ('No_hipertension', 'Trabajo_privado'): 2456}, 3: {('Casado', 'No_ACV', 'No_enfermedad_corazon'): 2837, ('Casado', 'No_ACV', 'No_hipertension'): 2668, ('Casado', 'No_enfermedad_corazon', 'No_hipertension'): 2510, ('Female', 'No_ACV', 'No_enfermedad_corazon'): 2639, ('Female', 'No_ACV', 'No_hipertension'): 2508, ('Female', 'No_enfermedad_corazon', 'No_hipertension'): 2437, ('Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'): 2492, ('Glucosa_normal', 'No_ACV', 'No_hipertension'): 2414, ('Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'): 2328, ('No_ACV', 'No_enfermedad_corazon', 'No_hipertension'): 4066, ('No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'): 2568, ('No_ACV', 'No_hipertension', 'Trabajo_privado'): 2456, ('No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'): 2361}, 4: {('Casado', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'): 2510, ('Female', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'): 2437, ('Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'): 2328, ('No_ACV', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'): 2361}}

# %%
print(rules_apriori)
# Out:
# [{Casado} -> {No_ACV}, {Casado} -> {No_enfermedad_corazon}, {Female} -> {No_ACV}, {Female} -> {No_enfermedad_corazon}, {Female} -> {No_hipertension}, {Glucosa_normal} -> {No_ACV}, {Glucosa_normal} -> {No_enfermedad_corazon}, {Glucosa_normal} -> {No_hipertension}, {No_enfermedad_corazon} -> {No_ACV}, {No_ACV} -> {No_enfermedad_corazon}, {No_hipertension} -> {No_ACV}, {No_ACV} -> {No_hipertension}, {Residencia_urbana} -> {No_ACV}, {Trabajo_privado} -> {No_ACV}, {No_hipertension} -> {No_enfermedad_corazon}, {No_enfermedad_corazon} -> {No_hipertension}, {Trabajo_privado} -> {No_enfermedad_corazon}, {Trabajo_privado} -> {No_hipertension}, {Casado, No_enfermedad_corazon} -> {No_ACV}, {Casado, No_ACV} -> {No_enfermedad_corazon}, {Casado} -> {No_ACV, No_enfermedad_corazon}, {Casado, No_hipertension} -> {No_ACV}, {Casado, No_hipertension} -> {No_enfermedad_corazon}, {Female, No_enfermedad_corazon} -> {No_ACV}, {Female, No_ACV} -> {No_enfermedad_corazon}, {Female} -> {No_ACV, No_enfermedad_corazon}, {Female, No_hipertension} -> {No_ACV}, {Female, No_ACV} -> {No_hipertension}, {Female} -> {No_ACV, No_hipertension}, {Female, No_hipertension} -> {No_enfermedad_corazon}, {Female, No_enfermedad_corazon} -> {No_hipertension}, {Glucosa_normal, No_enfermedad_corazon} -> {No_ACV}, {Glucosa_normal, No_ACV} -> {No_enfermedad_corazon}, {Glucosa_normal} -> {No_ACV, No_enfermedad_corazon}, {Glucosa_normal, No_hipertension} -> {No_ACV}, {Glucosa_normal, No_ACV} -> {No_hipertension}, {Glucosa_normal} -> {No_ACV, No_hipertension}, {Glucosa_normal, No_hipertension} -> {No_enfermedad_corazon}, {Glucosa_normal, No_enfermedad_corazon} -> {No_hipertension}, {No_enfermedad_corazon, No_hipertension} -> {No_ACV}, {No_ACV, No_hipertension} -> {No_enfermedad_corazon}, {No_ACV, No_enfermedad_corazon} -> {No_hipertension}, {No_hipertension} -> {No_ACV, No_enfermedad_corazon}, {No_enfermedad_corazon} -> {No_ACV, No_hipertension}, {No_enfermedad_corazon, Trabajo_privado} -> {No_ACV}, {No_ACV, Trabajo_privado} -> {No_enfermedad_corazon}, {Trabajo_privado} -> {No_ACV, No_enfermedad_corazon}, {No_hipertension, Trabajo_privado} -> {No_ACV}, {No_ACV, Trabajo_privado} -> {No_hipertension}, {Trabajo_privado} -> {No_ACV, No_hipertension}, {No_hipertension, Trabajo_privado} -> {No_enfermedad_corazon}, {No_enfermedad_corazon, Trabajo_privado} -> {No_hipertension}, {Casado, No_enfermedad_corazon, No_hipertension} -> {No_ACV}, {Casado, No_ACV, No_hipertension} -> {No_enfermedad_corazon}, {Casado, No_hipertension} -> {No_ACV, No_enfermedad_corazon}, {Female, No_enfermedad_corazon, No_hipertension} -> {No_ACV}, {Female, No_ACV, No_hipertension} -> {No_enfermedad_corazon}, {Female, No_ACV, No_enfermedad_corazon} -> {No_hipertension}, {Female, No_hipertension} -> {No_ACV, No_enfermedad_corazon}, {Female, No_enfermedad_corazon} -> {No_ACV, No_hipertension}, {Glucosa_normal, No_enfermedad_corazon, No_hipertension} -> {No_ACV}, {Glucosa_normal, No_ACV, No_hipertension} -> {No_enfermedad_corazon}, {Glucosa_normal, No_ACV, No_enfermedad_corazon} -> {No_hipertension}, {Glucosa_normal, No_hipertension} -> {No_ACV, No_enfermedad_corazon}, {Glucosa_normal, No_enfermedad_corazon} -> {No_ACV, No_hipertension}, {No_enfermedad_corazon, No_hipertension, Trabajo_privado} -> {No_ACV}, {No_ACV, No_hipertension, Trabajo_privado} -> {No_enfermedad_corazon}, {No_ACV, No_enfermedad_corazon, Trabajo_privado} -> {No_hipertension}, {No_hipertension, Trabajo_privado} -> {No_ACV, No_enfermedad_corazon}, {No_enfermedad_corazon, Trabajo_privado} -> {No_ACV, No_hipertension}]

# %% [markdown]
# Se destacan las siguientes reglas:
#
# {Glucosa_normal, No_enfermedad_corazon, No_hipertension} -> {No_ACV}
#
# {Casado, No_enfermedad_corazon, No_hipertension} -> {No_ACV}
#
# {No_enfermedad_corazon, No_hipertension, Trabajo_privado} -> {No_ACV}

# %% [markdown]
# ### 10.1.4) Uso del algoritmo con ambas clases

# %% [markdown]
# Se sube el valor de soporte a 60%, con una confianza del 90%.

# %%
itemsets_apriori, rules_apriori = apriori(datos_asociacion_lista, min_support=0.6,  min_confidence=0.9)
print(itemsets_apriori)
# Out:
# {1: {('No_hipertension',): 4423, ('Casado',): 3257, ('No_enfermedad_corazon',): 4625, ('No_ACV',): 4654}, 2: {('Casado', 'No_ACV'): 3041, ('Casado', 'No_enfermedad_corazon'): 3014, ('No_ACV', 'No_enfermedad_corazon'): 4426, ('No_ACV', 'No_hipertension'): 4243, ('No_enfermedad_corazon', 'No_hipertension'): 4213}, 3: {('No_ACV', 'No_enfermedad_corazon', 'No_hipertension'): 4066}}

# %%
print(rules_apriori)
# Out:
# [{Casado} -> {No_ACV}, {Casado} -> {No_enfermedad_corazon}, {No_enfermedad_corazon} -> {No_ACV}, {No_ACV} -> {No_enfermedad_corazon}, {No_hipertension} -> {No_ACV}, {No_ACV} -> {No_hipertension}, {No_hipertension} -> {No_enfermedad_corazon}, {No_enfermedad_corazon} -> {No_hipertension}, {No_enfermedad_corazon, No_hipertension} -> {No_ACV}, {No_ACV, No_hipertension} -> {No_enfermedad_corazon}, {No_ACV, No_enfermedad_corazon} -> {No_hipertension}, {No_hipertension} -> {No_ACV, No_enfermedad_corazon}]

# %% [markdown]
# {No_enfermedad_corazon, No_hipertension} -> {No_ACV} ************
#
# {No_ACV} -> {No_enfermedad_corazon}
#
# {No_ACV} -> {No_hipertension}
#
# {No_hipertension} -> {No_enfermedad_corazon} ***
#
# {No_enfermedad_corazon} -> {No_hipertension} ***
#
# {Casado} -> {No_ACV}
#
# {No_enfermedad_corazon} -> {No_ACV}
#
# {No_hipertension} -> {No_ACV}
#
# {Casado} -> {No_enfermedad_corazon}  ***
#
# {No_ACV, No_enfermedad_corazon} -> {No_hipertension} ***

# %% [markdown]
# Estas reglas están soportadas por valores de soporte y confianza altos. La regla más importante es {No_enfermedad_corazon, No_hipertension} -> {No_ACV}, y con ella se podría prepecir si la persona no ha sufrido accidente cerebro-vascular.
#
# Otras reglas interesantes son {No_hipertension} -> {No_enfermedad_corazon}, {No_enfermedad_corazon} -> {No_hipertension} y
# {No_ACV, No_enfermedad_corazon} -> {No_hipertension}

# %% [markdown]
# ### 10.2) Algoritmo de asociación FP-Growth

# %% [markdown]
# Ahora se hará uso de las librerías de Python del algoritmo de asociación FP-Growth.
#
# Así como en el algoritmo Apriori, en un principio se establece un valor de soporte umbral del 30% con una confianza del 80%
#
# Primero se muestra la totalidad de itemsets frecuentes dado el umbral de soporte y luego se muestran las reglas de asociación derivadas de los itemsets.

# %%
from fpgrowth_py import fpgrowth
itemsets_fpgrowth, rules_fpgrowth = fpgrowth(datos_asociacion_lista, minSupRatio=0.3, minConf=0.8)
itemsets_fpgrowth
# Out:
# [{'Sobrepeso'},
#  {'No_casado'},
#  {'No_casado', 'No_hipertension'},
#  {'No_casado', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'No_ACV', 'No_casado', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'No_ACV', 'No_casado', 'No_hipertension'},
#  {'No_casado', 'No_enfermedad_corazon'},
#  {'No_ACV', 'No_casado', 'No_enfermedad_corazon'},
#  {'No_ACV', 'No_casado'},
#  {'never smoked'},
#  {'No_hipertension', 'never smoked'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'never smoked'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension', 'never smoked'},
#  {'No_ACV', 'No_hipertension', 'never smoked'},
#  {'No_ACV', 'never smoked'},
#  {'No_ACV', 'No_enfermedad_corazon', 'never smoked'},
#  {'No_enfermedad_corazon', 'never smoked'},
#  {'Male'},
#  {'Male', 'No_hipertension'},
#  {'Male', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Male', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Male', 'No_ACV', 'No_hipertension'},
#  {'Male', 'No_enfermedad_corazon'},
#  {'Male', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Male', 'No_ACV'},
#  {'Residencia_rural'},
#  {'Casado', 'Residencia_rural'},
#  {'Casado', 'No_ACV', 'Residencia_rural'},
#  {'No_hipertension', 'Residencia_rural'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Residencia_rural'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension', 'Residencia_rural'},
#  {'No_ACV', 'No_hipertension', 'Residencia_rural'},
#  {'No_enfermedad_corazon', 'Residencia_rural'},
#  {'No_ACV', 'No_enfermedad_corazon', 'Residencia_rural'},
#  {'No_ACV', 'Residencia_rural'},
#  {'Residencia_urbana'},
#  {'Casado', 'Residencia_urbana'},
#  {'Casado', 'No_enfermedad_corazon', 'Residencia_urbana'},
#  {'Casado', 'No_ACV', 'Residencia_urbana'},
#  {'No_hipertension', 'Residencia_urbana'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Residencia_urbana'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension', 'Residencia_urbana'},
#  {'No_ACV', 'No_hipertension', 'Residencia_urbana'},
#  {'No_enfermedad_corazon', 'Residencia_urbana'},
#  {'No_ACV', 'No_enfermedad_corazon', 'Residencia_urbana'},
#  {'No_ACV', 'Residencia_urbana'},
#  {'Glucosa_normal'},
#  {'Glucosa_normal', 'Trabajo_privado'},
#  {'Glucosa_normal', 'No_ACV', 'Trabajo_privado'},
#  {'Glucosa_normal', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Female', 'Glucosa_normal'},
#  {'Female', 'Glucosa_normal', 'No_hipertension'},
#  {'Female', 'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Female', 'Glucosa_normal', 'No_ACV'},
#  {'Female', 'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Female', 'Glucosa_normal', 'No_enfermedad_corazon'},
#  {'Casado', 'Glucosa_normal'},
#  {'Casado', 'Glucosa_normal', 'No_hipertension'},
#  {'Casado', 'Glucosa_normal', 'No_ACV', 'No_hipertension'},
#  {'Casado', 'Glucosa_normal', 'No_enfermedad_corazon'},
#  {'Casado', 'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Casado', 'Glucosa_normal', 'No_ACV'},
#  {'Glucosa_normal', 'No_hipertension'},
#  {'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Glucosa_normal', 'No_ACV', 'No_hipertension'},
#  {'Glucosa_normal', 'No_enfermedad_corazon'},
#  {'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Glucosa_normal', 'No_ACV'},
#  {'Trabajo_privado'},
#  {'Female', 'Trabajo_privado'},
#  {'Female', 'No_hipertension', 'Trabajo_privado'},
#  {'Female', 'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#  {'Female', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#  {'Female', 'No_ACV', 'Trabajo_privado'},
#  {'Female', 'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Female', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Casado', 'Trabajo_privado'},
#  {'Casado', 'No_hipertension', 'Trabajo_privado'},
#  {'Casado', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#  {'Casado',
#   'No_ACV',
#   'No_enfermedad_corazon',
#   'No_hipertension',
#   'Trabajo_privado'},
#  {'Casado', 'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#  {'Casado', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Casado', 'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Casado', 'No_ACV', 'Trabajo_privado'},
#  {'No_hipertension', 'Trabajo_privado'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#  {'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#  {'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'No_ACV', 'Trabajo_privado'},
#  {'Female'},
#  {'Casado', 'Female'},
#  {'Casado', 'Female', 'No_hipertension'},
#  {'Casado', 'Female', 'No_ACV', 'No_hipertension'},
#  {'Casado', 'Female', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'Female', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'Female', 'No_ACV'},
#  {'Casado', 'Female', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Casado', 'Female', 'No_enfermedad_corazon'},
#  {'Female', 'No_hipertension'},
#  {'Female', 'No_ACV', 'No_hipertension'},
#  {'Female', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Female', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Female', 'No_ACV'},
#  {'Female', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Female', 'No_enfermedad_corazon'},
#  {'Casado'},
#  {'Casado', 'No_hipertension'},
#  {'Casado', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'No_ACV', 'No_hipertension'},
#  {'Casado', 'No_enfermedad_corazon'},
#  {'Casado', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Casado', 'No_ACV'},
#  {'No_hipertension'},
#  {'No_enfermedad_corazon', 'No_hipertension'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'No_ACV', 'No_hipertension'},
#  {'No_enfermedad_corazon'},
#  {'No_ACV', 'No_enfermedad_corazon'},
#  {'No_ACV'}]

# %%
rules_fpgrowth
# Out:
# [[{'No_casado'}, {'No_hipertension'}, 0.9701583434835567],
#  [{'No_casado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.9567600487210719],
#  [{'No_casado', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9861895794099184],
#  [{'No_casado', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9751707014276847],
#  [{'No_casado'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.9476248477466505],
#  [{'No_ACV', 'No_casado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.9646621202727836],
#  [{'No_casado', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9767733835530445],
#  [{'No_casado', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.9658597144630664],
#  [{'No_ACV', 'No_casado', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9879365079365079],
#  [{'No_ACV', 'No_casado', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9792322215229704],
#  [{'No_casado', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'No_ACV'},
#   0.9904519414385742],
#  [{'No_casado'}, {'No_ACV', 'No_hipertension'}, 0.9591961023142509],
#  [{'No_ACV', 'No_casado'}, {'No_hipertension'}, 0.9764414135151891],
#  [{'No_casado', 'No_hipertension'}, {'No_ACV'}, 0.9887005649717514],
#  [{'No_casado'}, {'No_enfermedad_corazon'}, 0.9811205846528623],
#  [{'No_casado'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.9677222898903776],
#  [{'No_ACV', 'No_casado'}, {'No_enfermedad_corazon'}, 0.9851208927464352],
#  [{'No_casado', 'No_enfermedad_corazon'}, {'No_ACV'}, 0.9863438857852266],
#  [{'No_casado'}, {'No_ACV'}, 0.9823386114494519],
#  [{'never smoked'}, {'No_hipertension'}, 0.8779419813902573],
#  [{'never smoked'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8423645320197044],
#  [{'No_hipertension', 'never smoked'},
#   {'No_enfermedad_corazon'},
#   0.9594763092269327],
#  [{'No_enfermedad_corazon', 'never smoked'},
#   {'No_hipertension'},
#   0.8849913743530765],
#  [{'never smoked'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8155446086480569],
#  [{'No_ACV', 'never smoked'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.857307249712313],
#  [{'No_hipertension', 'never smoked'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.928927680798005],
#  [{'No_enfermedad_corazon', 'never smoked'},
#   {'No_ACV', 'No_hipertension'},
#   0.8568142610695803],
#  [{'No_ACV', 'No_hipertension', 'never smoked'},
#   {'No_enfermedad_corazon'},
#   0.9631544925662573],
#  [{'No_ACV', 'No_enfermedad_corazon', 'never smoked'},
#   {'No_hipertension'},
#   0.8965102286401926],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'never smoked'},
#   {'No_ACV'},
#   0.96816114359974],
#  [{'never smoked'}, {'No_ACV', 'No_hipertension'}, 0.8467432950191571],
#  [{'No_ACV', 'never smoked'}, {'No_hipertension'}, 0.8901035673187572],
#  [{'No_hipertension', 'never smoked'}, {'No_ACV'}, 0.9644638403990025],
#  [{'never smoked'}, {'No_ACV'}, 0.9512862616310892],
#  [{'never smoked'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.909688013136289],
#  [{'No_ACV', 'never smoked'}, {'No_enfermedad_corazon'}, 0.956271576524741],
#  [{'No_enfermedad_corazon', 'never smoked'}, {'No_ACV'}, 0.9557216791259344],
#  [{'never smoked'}, {'No_enfermedad_corazon'}, 0.9518336070060208],
#  [{'Male'}, {'No_hipertension'}, 0.8949704142011834],
#  [{'Male'}, {'No_enfermedad_corazon', 'No_hipertension'}, 0.8323471400394478],
#  [{'Male', 'No_hipertension'}, {'No_enfermedad_corazon'}, 0.9300275482093664],
#  [{'Male', 'No_enfermedad_corazon'}, {'No_hipertension'}, 0.9046087888531619],
#  [{'Male'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8032544378698225],
#  [{'Male', 'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8475546305931322],
#  [{'Male', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.8975206611570248],
#  [{'Male', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.8729903536977492],
#  [{'Male', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9389048991354467],
#  [{'Male', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9115836597649692],
#  [{'Male', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'No_ACV'},
#   0.965047393364929],
#  [{'Male'}, {'No_ACV', 'No_hipertension'}, 0.8555226824457594],
#  [{'Male', 'No_ACV'}, {'No_hipertension'}, 0.9027055150884495],
#  [{'Male', 'No_hipertension'}, {'No_ACV'}, 0.9559228650137741],
#  [{'Male'}, {'No_enfermedad_corazon'}, 0.9201183431952663],
#  [{'Male'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.881163708086785],
#  [{'Male', 'No_ACV'}, {'No_enfermedad_corazon'}, 0.9297606659729448],
#  [{'Male', 'No_enfermedad_corazon'}, {'No_ACV'}, 0.9576634512325831],
#  [{'Male'}, {'No_ACV'}, 0.9477317554240631],
#  [{'Casado', 'Residencia_rural'}, {'No_ACV'}, 0.9345911949685535],
#  [{'Residencia_rural'}, {'No_hipertension'}, 0.9007475083056479],
#  [{'Residencia_rural'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8588039867109635],
#  [{'No_hipertension', 'Residencia_rural'},
#   {'No_enfermedad_corazon'},
#   0.9534347625633933],
#  [{'No_enfermedad_corazon', 'Residencia_rural'},
#   {'No_hipertension'},
#   0.909410729991205],
#  [{'Residencia_rural'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8313953488372093],
#  [{'No_ACV', 'Residencia_rural'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8719512195121951],
#  [{'No_hipertension', 'Residencia_rural'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9230059935454127],
#  [{'No_enfermedad_corazon', 'Residencia_rural'},
#   {'No_ACV', 'No_hipertension'},
#   0.8803869832893579],
#  [{'No_ACV', 'No_hipertension', 'Residencia_rural'},
#   {'No_enfermedad_corazon'},
#   0.9583532790809],
#  [{'No_ACV', 'No_enfermedad_corazon', 'Residencia_rural'},
#   {'No_hipertension'},
#   0.9179275561668959],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Residencia_rural'},
#   {'No_ACV'},
#   0.9680851063829787],
#  [{'Residencia_rural'}, {'No_ACV', 'No_hipertension'}, 0.8675249169435216],
#  [{'No_ACV', 'Residencia_rural'}, {'No_hipertension'}, 0.9098432055749129],
#  [{'No_hipertension', 'Residencia_rural'}, {'No_ACV'}, 0.963116643614569],
#  [{'Residencia_rural'}, {'No_enfermedad_corazon'}, 0.9443521594684385],
#  [{'Residencia_rural'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9057308970099668],
#  [{'No_ACV', 'Residencia_rural'},
#   {'No_enfermedad_corazon'},
#   0.9499128919860628],
#  [{'No_enfermedad_corazon', 'Residencia_rural'},
#   {'No_ACV'},
#   0.9591029023746702],
#  [{'Residencia_rural'}, {'No_ACV'}, 0.9534883720930233],
#  [{'Casado', 'Residencia_urbana'},
#   {'No_enfermedad_corazon'},
#   0.9268146370725855],
#  [{'Casado', 'Residencia_urbana'}, {'No_ACV'}, 0.9328134373125375],
#  [{'Residencia_urbana'}, {'No_hipertension'}, 0.9048574869530309],
#  [{'Residencia_urbana'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8610999598554797],
#  [{'No_hipertension', 'Residencia_urbana'},
#   {'No_enfermedad_corazon'},
#   0.9516415261756876],
#  [{'No_enfermedad_corazon', 'Residencia_urbana'},
#   {'No_hipertension'},
#   0.9123777116120799],
#  [{'Residencia_urbana'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8285828984343637],
#  [{'No_ACV', 'Residencia_urbana'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8753180661577609],
#  [{'No_hipertension', 'Residencia_urbana'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9157054125998225],
#  [{'No_enfermedad_corazon', 'Residencia_urbana'},
#   {'No_ACV', 'No_hipertension'},
#   0.8779242875372182],
#  [{'No_ACV', 'No_hipertension', 'Residencia_urbana'},
#   {'No_enfermedad_corazon'},
#   0.958217270194986],
#  [{'No_ACV', 'No_enfermedad_corazon', 'Residencia_urbana'},
#   {'No_hipertension'},
#   0.9193763919821827],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Residencia_urbana'},
#   {'No_ACV'},
#   0.9622377622377623],
#  [{'Residencia_urbana'}, {'No_ACV', 'No_hipertension'}, 0.8647129666800482],
#  [{'No_ACV', 'Residencia_urbana'}, {'No_hipertension'}, 0.9134860050890585],
#  [{'No_hipertension', 'Residencia_urbana'}, {'No_ACV'}, 0.9556344276841171],
#  [{'Residencia_urbana'}, {'No_enfermedad_corazon'}, 0.9437976716178241],
#  [{'Residencia_urbana'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9012444801284625],
#  [{'No_ACV', 'Residencia_urbana'},
#   {'No_enfermedad_corazon'},
#   0.952078032230704],
#  [{'No_enfermedad_corazon', 'Residencia_urbana'},
#   {'No_ACV'},
#   0.9549128030625266],
#  [{'Residencia_urbana'}, {'No_ACV'}, 0.9466077880369329],
#  [{'Glucosa_normal', 'Trabajo_privado'}, {'No_ACV'}, 0.9605346912794398],
#  [{'Glucosa_normal', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9656269891788669],
#  [{'Female', 'Glucosa_normal'}, {'No_hipertension'}, 0.9343246592317225],
#  [{'Female', 'Glucosa_normal'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.9157372986369269],
#  [{'Female', 'Glucosa_normal', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.980106100795756],
#  [{'Female', 'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9372225745085606],
#  [{'Female', 'Glucosa_normal'}, {'No_ACV'}, 0.9628252788104089],
#  [{'Female', 'Glucosa_normal'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9417596034696406],
#  [{'Female', 'Glucosa_normal', 'No_ACV'},
#   {'No_enfermedad_corazon'},
#   0.9781209781209781],
#  [{'Female', 'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_ACV'},
#   0.963855421686747],
#  [{'Female', 'Glucosa_normal'}, {'No_enfermedad_corazon'}, 0.9770755885997522],
#  [{'Casado', 'Glucosa_normal'}, {'No_hipertension'}, 0.8980891719745223],
#  [{'Casado', 'Glucosa_normal'},
#   {'No_ACV', 'No_hipertension'},
#   0.8587145338737695],
#  [{'Casado', 'Glucosa_normal', 'No_hipertension'},
#   {'No_ACV'},
#   0.9561573178594455],
#  [{'Casado', 'Glucosa_normal', 'No_ACV'},
#   {'No_hipertension'},
#   0.9026171637248935],
#  [{'Casado', 'Glucosa_normal'}, {'No_enfermedad_corazon'}, 0.9432541980312681],
#  [{'Casado', 'Glucosa_normal'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.8986682107701216],
#  [{'Casado', 'Glucosa_normal', 'No_ACV'},
#   {'No_enfermedad_corazon'},
#   0.9446135118685332],
#  [{'Casado', 'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_ACV'},
#   0.952731737262124],
#  [{'Casado', 'Glucosa_normal'}, {'No_ACV'}, 0.9513607411696584],
#  [{'Glucosa_normal'}, {'No_hipertension'}, 0.9257884972170687],
#  [{'Glucosa_normal'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8916512059369203],
#  [{'Glucosa_normal', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.96312625250501],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.929953560371517],
#  [{'Glucosa_normal'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.863821892393321],
#  [{'Glucosa_normal', 'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.89745566692367],
#  [{'Glucosa_normal', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9330661322645291],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.9009287925696594],
#  [{'Glucosa_normal', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9643744821872411],
#  [{'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9341894060995185],
#  [{'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'No_ACV'},
#   0.968789013732834],
#  [{'Glucosa_normal'}, {'No_ACV', 'No_hipertension'}, 0.8957328385899814],
#  [{'Glucosa_normal', 'No_ACV'}, {'No_hipertension'}, 0.930609097918273],
#  [{'Glucosa_normal', 'No_hipertension'}, {'No_ACV'}, 0.9675350701402805],
#  [{'Glucosa_normal'}, {'No_enfermedad_corazon'}, 0.9588126159554731],
#  [{'Glucosa_normal'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.9246753246753247],
#  [{'Glucosa_normal', 'No_ACV'}, {'No_enfermedad_corazon'}, 0.9606784888203547],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'}, {'No_ACV'}, 0.9643962848297214],
#  [{'Glucosa_normal'}, {'No_ACV'}, 0.9625231910946197],
#  [{'Female', 'Trabajo_privado'}, {'No_hipertension'}, 0.91301775147929],
#  [{'Female', 'Trabajo_privado'},
#   {'No_ACV', 'No_hipertension'},
#   0.8792899408284024],
#  [{'Female', 'No_ACV', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.9195544554455446],
#  [{'Female', 'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV'},
#   0.9630589760207389],
#  [{'Female', 'Trabajo_privado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8840236686390532],
#  [{'Female', 'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9682436811406351],
#  [{'Female', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.9205175600739371],
#  [{'Female', 'Trabajo_privado'}, {'No_ACV'}, 0.9562130177514793],
#  [{'Female', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9230769230769231],
#  [{'Female', 'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9653465346534653],
#  [{'Female', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_ACV'},
#   0.9611829944547134],
#  [{'Female', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9603550295857988],
#  [{'Casado', 'Trabajo_privado'}, {'No_hipertension'}, 0.8830151737640725],
#  [{'Casado', 'Trabajo_privado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8311306901615272],
#  [{'Casado', 'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9412416851441242],
#  [{'Casado', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.8932140978432404],
#  [{'Casado', 'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.8946784922394678],
#  [{'Casado', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_ACV', 'No_hipertension'},
#   0.849026827985271],
#  [{'Casado', 'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8445839874411303],
#  [{'Casado', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV'},
#   0.950530035335689],
#  [{'Casado', 'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.949970570924073],
#  [{'Casado', 'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.8981636060100167],
#  [{'Casado', 'Trabajo_privado'},
#   {'No_ACV', 'No_hipertension'},
#   0.8316201664219285],
#  [{'Casado', 'No_ACV', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.8890633176347462],
#  [{'Casado', 'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV'},
#   0.9417960088691796],
#  [{'Casado', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9304943710230054],
#  [{'Casado', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.8795888399412628],
#  [{'Casado', 'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9403453689167975],
#  [{'Casado', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_ACV'},
#   0.9452919516044187],
#  [{'Casado', 'Trabajo_privado'}, {'No_ACV'}, 0.9353891336270191],
#  [{'Trabajo_privado'}, {'No_hipertension'}, 0.9045774647887324],
#  [{'Trabajo_privado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8633802816901408],
#  [{'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9544569871545349],
#  [{'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.9135618479880775],
#  [{'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.831338028169014],
#  [{'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.876391982182628],
#  [{'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9190346438302841],
#  [{'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_ACV', 'No_hipertension'},
#   0.8796572280178837],
#  [{'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9613192182410424],
#  [{'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.919392523364486],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV'},
#   0.9628874388254486],
#  [{'Trabajo_privado'}, {'No_ACV', 'No_hipertension'}, 0.8647887323943662],
#  [{'No_ACV', 'Trabajo_privado'}, {'No_hipertension'}, 0.9116555308092057],
#  [{'No_hipertension', 'Trabajo_privado'}, {'No_ACV'}, 0.9560140132347217],
#  [{'Trabajo_privado'}, {'No_enfermedad_corazon'}, 0.9450704225352112],
#  [{'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9042253521126761],
#  [{'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9532293986636972],
#  [{'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_ACV'},
#   0.9567809239940388],
#  [{'Trabajo_privado'}, {'No_ACV'}, 0.9485915492957746],
#  [{'Casado', 'Female'}, {'No_hipertension'}, 0.8791322314049587],
#  [{'Casado', 'Female'}, {'No_ACV', 'No_hipertension'}, 0.8341942148760331],
#  [{'Casado', 'Female', 'No_ACV'}, {'No_hipertension'}, 0.8883388338833883],
#  [{'Casado', 'Female', 'No_hipertension'}, {'No_ACV'}, 0.9488836662749707],
#  [{'Casado', 'Female'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8026859504132231],
#  [{'Casado', 'Female', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9130434782608695],
#  [{'Casado', 'Female', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.844106463878327],
#  [{'Casado', 'Female', 'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8547854785478548],
#  [{'Casado', 'Female', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'No_ACV'},
#   0.9527896995708155],
#  [{'Casado', 'Female', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9622291021671827],
#  [{'Casado', 'Female', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.8946459412780656],
#  [{'Casado', 'Female'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8424586776859504],
#  [{'Casado', 'Female', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9582843713278496],
#  [{'Casado', 'Female', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.8859315589353612],
#  [{'Casado', 'Female'}, {'No_ACV'}, 0.9390495867768595],
#  [{'Casado', 'Female'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.8972107438016529],
#  [{'Casado', 'Female', 'No_ACV'},
#   {'No_enfermedad_corazon'},
#   0.9554455445544554],
#  [{'Casado', 'Female', 'No_enfermedad_corazon'},
#   {'No_ACV'},
#   0.9435089625203693],
#  [{'Casado', 'Female'}, {'No_enfermedad_corazon'}, 0.9509297520661157],
#  [{'Female'}, {'No_hipertension'}, 0.9083942877046325],
#  [{'Female'}, {'No_ACV', 'No_hipertension'}, 0.8735632183908046],
#  [{'Female', 'No_ACV'}, {'No_hipertension'}, 0.91800878477306],
#  [{'Female', 'No_hipertension'}, {'No_ACV'}, 0.9616564417177914],
#  [{'Female'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8488331591779867],
#  [{'Female', 'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8920204978038068],
#  [{'Female', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9344325153374233],
#  [{'Female', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.8832910474809713],
#  [{'Female', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9716905901116427],
#  [{'Female', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9234558544903373],
#  [{'Female', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'No_ACV'},
#   0.9651485148514851],
#  [{'Female'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8794845001741554],
#  [{'Female', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9681748466257669],
#  [{'Female', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9151866618339978],
#  [{'Female'}, {'No_ACV'}, 0.9515848136537791],
#  [{'Female'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.9191919191919192],
#  [{'Female', 'No_ACV'}, {'No_enfermedad_corazon'}, 0.9659590043923866],
#  [{'Female', 'No_enfermedad_corazon'}, {'No_ACV'}, 0.9565059804276912],
#  [{'Female'}, {'No_enfermedad_corazon'}, 0.9609892023685127],
#  [{'Casado'}, {'No_hipertension'}, 0.8688977586736261],
#  [{'Casado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8111759287688056],
#  [{'Casado', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9335689045936396],
#  [{'Casado', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.8765759787657598],
#  [{'Casado', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.8869257950530035],
#  [{'Casado', 'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.825386386057218],
#  [{'Casado', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.8327803583278036],
#  [{'Casado', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9407796101949025],
#  [{'Casado', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'No_ACV'},
#   0.9500378501135504],
#  [{'Casado', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.8847373986605569],
#  [{'Casado'}, {'No_ACV', 'No_hipertension'}, 0.8191587350322382],
#  [{'Casado', 'No_hipertension'}, {'No_ACV'}, 0.942756183745583],
#  [{'Casado', 'No_ACV'}, {'No_hipertension'}, 0.8773429792831305],
#  [{'Casado'}, {'No_enfermedad_corazon'}, 0.9253914645379183],
#  [{'Casado'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.8710469757445501],
#  [{'Casado', 'No_ACV'}, {'No_enfermedad_corazon'}, 0.932916803682999],
#  [{'Casado', 'No_enfermedad_corazon'}, {'No_ACV'}, 0.9412740544127406],
#  [{'Casado'}, {'No_ACV'}, 0.933681301811483],
#  [{'No_hipertension'}, {'No_enfermedad_corazon'}, 0.9525209134071897],
#  [{'No_enfermedad_corazon'}, {'No_hipertension'}, 0.910918918918919],
#  [{'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8736570691877954],
#  [{'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9192855527922225],
#  [{'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.8791351351351351],
#  [{'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9582842328541127],
#  [{'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9186624491640307],
#  [{'No_enfermedad_corazon', 'No_hipertension'},
#   {'No_ACV'},
#   0.9651079990505578],
#  [{'No_ACV'}, {'No_hipertension'}, 0.9116888697894284],
#  [{'No_hipertension'}, {'No_ACV'}, 0.9593036400633055],
#  [{'No_ACV'}, {'No_enfermedad_corazon'}, 0.9510098839707778],
#  [{'No_enfermedad_corazon'}, {'No_ACV'}, 0.956972972972973]]

# %% [markdown]
# Estas reglas de asociación son transformadas a un dataframe para una mejor visualización de los datos.

# %%
reglas_fpgrowth = pd.DataFrame(rules_fpgrowth, columns = ['Antecedente', 'Consecuente', 'Confianza'])
pd.set_option('display.max_columns', 254)
reglas_fpgrowth
# Out:
#                                   Antecedente  \
# 0                                 {No_casado}
# 1                                 {No_casado}
# 2                {No_hipertension, No_casado}
# 3          {No_enfermedad_corazon, No_casado}
# 4                                 {No_casado}
# ..                                        ...
# 249  {No_hipertension, No_enfermedad_corazon}
# 250                                  {No_ACV}
# 251                         {No_hipertension}
# 252                                  {No_ACV}
# 253                   {No_enfermedad_corazon}
#
#                                           Consecuente  Confianza
# 0                                   {No_hipertension}   0.970158
# 1            {No_hipertension, No_enfermedad_corazon}   0.956760
# 2                             {No_enfermedad_corazon}   0.986190
# 3                                   {No_hipertension}   0.975171
# 4    {No_ACV, No_hipertension, No_enfermedad_corazon}   0.947625
# ..                                                ...        ...
# 249                                          {No_ACV}   0.965108
# 250                                 {No_hipertension}   0.911689
# 251                                          {No_ACV}   0.959304
# 252                           {No_enfermedad_corazon}   0.951010
# 253                                          {No_ACV}   0.956973
#
# [254 rows x 3 columns]

# %% [markdown]
# A contiuación se presentan algunas reglas presentadas por el algoritmo.

# %% [markdown]
# {No_hipertension, Residencia_rural} -> {No_enfermedad_corazon}
#
# {'No_ACV', 'No_casado'} -> {'No_hipertension'} ***
#
# {'No_ACV', 'No_enfermedad_corazon', 'never smoked'} -> {'No_hipertension'} ***
#
# {No_enfermedad_corazon, Residencia_rural} -> {No_ACV}
#
# {No_ACV, No_hipertension, Trabajo_privado} -> {No_enfermedad_corazon}
#
# {Female, No_ACV, Trabajo_privado} -> {No_hipertension}
#
# {'No_enfermedad_corazon', 'No_hipertension', 'Residencia_rural'} -> {'No_ACV'} ***
#
# {'Glucosa_normal', 'Trabajo_privado'}, {'No_ACV'} *** regla no obvia
#
# {Male, No_enfermedad_corazon, No_hipertension} -> {No_ACV}
#
# {No_enfermedad_corazon, No_hipertension} -> {No_ACV}

# %% [markdown]
# El algoritmo no extrajo ninguna regla relacionada a Si_ACV. Esto se puede explicar debido a que existen 20 veces menos registros para Si_ACV comparado con No_ACV. Por tanto, es necesario hacer asociación separando los registros en dos grupos: cuando existe ACV y cuando no existe ACV.

# %% [markdown]
# ### 10.1.1) Asociación para la clase Si_ACV

# %% [markdown]
# Se hará uso de las librerías de fpgrowth para aquellos datos con la clase Si_ACV.
#
# Se empieza con un valor de soporte del 30% con una confianza del 80%.

# %%
itemsets_fpgrowth, rules_fpgrowth = fpgrowth(datos_Si_ACV, minSupRatio=0.3, minConf=0.8)
itemsets_fpgrowth
# Out:
# [{'never smoked'},
#  {'Casado', 'never smoked'},
#  {'Casado', 'Si_ACV', 'never smoked'},
#  {'No_enfermedad_corazon', 'never smoked'},
#  {'No_enfermedad_corazon', 'Si_ACV', 'never smoked'},
#  {'Si_ACV', 'never smoked'},
#  {'Diabetes'},
#  {'Casado', 'Diabetes'},
#  {'Casado', 'Diabetes', 'Si_ACV'},
#  {'Diabetes', 'Si_ACV'},
#  {'Sobrepeso'},
#  {'No_hipertension', 'Sobrepeso'},
#  {'No_hipertension', 'Si_ACV', 'Sobrepeso'},
#  {'No_enfermedad_corazon', 'Sobrepeso'},
#  {'Casado', 'No_enfermedad_corazon', 'Sobrepeso'},
#  {'Casado', 'No_enfermedad_corazon', 'Si_ACV', 'Sobrepeso'},
#  {'No_enfermedad_corazon', 'Si_ACV', 'Sobrepeso'},
#  {'Casado', 'Sobrepeso'},
#  {'Casado', 'Si_ACV', 'Sobrepeso'},
#  {'Si_ACV', 'Sobrepeso'},
#  {'Glucosa_normal'},
#  {'Glucosa_normal', 'No_hipertension'},
#  {'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'},
#  {'Glucosa_normal', 'No_hipertension', 'Si_ACV'},
#  {'Casado', 'Glucosa_normal'},
#  {'Casado', 'Glucosa_normal', 'No_enfermedad_corazon'},
#  {'Casado', 'Glucosa_normal', 'No_enfermedad_corazon', 'Si_ACV'},
#  {'Casado', 'Glucosa_normal', 'Si_ACV'},
#  {'Glucosa_normal', 'No_enfermedad_corazon'},
#  {'Glucosa_normal', 'No_enfermedad_corazon', 'Si_ACV'},
#  {'Glucosa_normal', 'Si_ACV'},
#  {'Vejez'},
#  {'No_enfermedad_corazon', 'Vejez'},
#  {'Casado', 'No_enfermedad_corazon', 'Vejez'},
#  {'Casado', 'No_enfermedad_corazon', 'Si_ACV', 'Vejez'},
#  {'No_enfermedad_corazon', 'Si_ACV', 'Vejez'},
#  {'Casado', 'Vejez'},
#  {'Casado', 'Si_ACV', 'Vejez'},
#  {'Si_ACV', 'Vejez'},
#  {'Male'},
#  {'Male', 'No_enfermedad_corazon'},
#  {'Male', 'No_enfermedad_corazon', 'Si_ACV'},
#  {'Male', 'No_hipertension'},
#  {'Casado', 'Male', 'No_hipertension'},
#  {'Casado', 'Male', 'No_hipertension', 'Si_ACV'},
#  {'Male', 'No_hipertension', 'Si_ACV'},
#  {'Casado', 'Male'},
#  {'Casado', 'Male', 'Si_ACV'},
#  {'Male', 'Si_ACV'},
#  {'Residencia_rural'},
#  {'No_hipertension', 'Residencia_rural'},
#  {'Casado', 'No_hipertension', 'Residencia_rural'},
#  {'Casado', 'No_hipertension', 'Residencia_rural', 'Si_ACV'},
#  {'No_hipertension', 'Residencia_rural', 'Si_ACV'},
#  {'No_enfermedad_corazon', 'Residencia_rural'},
#  {'Casado', 'No_enfermedad_corazon', 'Residencia_rural'},
#  {'Casado', 'No_enfermedad_corazon', 'Residencia_rural', 'Si_ACV'},
#  {'No_enfermedad_corazon', 'Residencia_rural', 'Si_ACV'},
#  {'Casado', 'Residencia_rural'},
#  {'Casado', 'Residencia_rural', 'Si_ACV'},
#  {'Residencia_rural', 'Si_ACV'},
#  {'Residencia_urbana'},
#  {'Female', 'Residencia_urbana'},
#  {'Female', 'Residencia_urbana', 'Si_ACV'},
#  {'Residencia_urbana', 'Trabajo_privado'},
#  {'Residencia_urbana', 'Si_ACV', 'Trabajo_privado'},
#  {'No_hipertension', 'Residencia_urbana'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Residencia_urbana'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Residencia_urbana', 'Si_ACV'},
#  {'Casado', 'No_hipertension', 'Residencia_urbana'},
#  {'Casado', 'No_hipertension', 'Residencia_urbana', 'Si_ACV'},
#  {'No_hipertension', 'Residencia_urbana', 'Si_ACV'},
#  {'No_enfermedad_corazon', 'Residencia_urbana'},
#  {'Casado', 'No_enfermedad_corazon', 'Residencia_urbana'},
#  {'Casado', 'No_enfermedad_corazon', 'Residencia_urbana', 'Si_ACV'},
#  {'No_enfermedad_corazon', 'Residencia_urbana', 'Si_ACV'},
#  {'Casado', 'Residencia_urbana'},
#  {'Casado', 'Residencia_urbana', 'Si_ACV'},
#  {'Residencia_urbana', 'Si_ACV'},
#  {'Female'},
#  {'Female', 'Trabajo_privado'},
#  {'Female', 'Si_ACV', 'Trabajo_privado'},
#  {'Female', 'No_hipertension'},
#  {'Casado', 'Female', 'No_hipertension'},
#  {'Casado', 'Female', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'Female', 'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'},
#  {'Casado', 'Female', 'No_hipertension', 'Si_ACV'},
#  {'Female', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Female', 'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'},
#  {'Female', 'No_hipertension', 'Si_ACV'},
#  {'Casado', 'Female'},
#  {'Casado', 'Female', 'No_enfermedad_corazon'},
#  {'Casado', 'Female', 'No_enfermedad_corazon', 'Si_ACV'},
#  {'Casado', 'Female', 'Si_ACV'},
#  {'Female', 'No_enfermedad_corazon'},
#  {'Female', 'No_enfermedad_corazon', 'Si_ACV'},
#  {'Female', 'Si_ACV'},
#  {'Trabajo_privado'},
#  {'No_hipertension', 'Trabajo_privado'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#  {'Casado', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#  {'Casado',
#   'No_enfermedad_corazon',
#   'No_hipertension',
#   'Si_ACV',
#   'Trabajo_privado'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV', 'Trabajo_privado'},
#  {'Casado', 'No_hipertension', 'Trabajo_privado'},
#  {'Casado', 'No_hipertension', 'Si_ACV', 'Trabajo_privado'},
#  {'No_hipertension', 'Si_ACV', 'Trabajo_privado'},
#  {'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Casado', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Casado', 'No_enfermedad_corazon', 'Si_ACV', 'Trabajo_privado'},
#  {'No_enfermedad_corazon', 'Si_ACV', 'Trabajo_privado'},
#  {'Casado', 'Trabajo_privado'},
#  {'Casado', 'Si_ACV', 'Trabajo_privado'},
#  {'Si_ACV', 'Trabajo_privado'},
#  {'No_hipertension'},
#  {'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'},
#  {'Casado', 'No_hipertension'},
#  {'Casado', 'No_hipertension', 'Si_ACV'},
#  {'No_hipertension', 'Si_ACV'},
#  {'No_enfermedad_corazon'},
#  {'Casado', 'No_enfermedad_corazon'},
#  {'Casado', 'No_enfermedad_corazon', 'Si_ACV'},
#  {'No_enfermedad_corazon', 'Si_ACV'},
#  {'Casado'},
#  {'Casado', 'Si_ACV'},
#  {'Si_ACV'}]

# %%
rules_fpgrowth
# Out:
# [[{'never smoked'}, {'Casado'}, 0.8314606741573034],
#  [{'never smoked'}, {'Casado', 'Si_ACV'}, 0.8314606741573034],
#  [{'Si_ACV', 'never smoked'}, {'Casado'}, 0.8314606741573034],
#  [{'Casado', 'never smoked'}, {'Si_ACV'}, 1.0],
#  [{'never smoked'}, {'No_enfermedad_corazon'}, 0.8651685393258427],
#  [{'never smoked'}, {'No_enfermedad_corazon', 'Si_ACV'}, 0.8651685393258427],
#  [{'Si_ACV', 'never smoked'}, {'No_enfermedad_corazon'}, 0.8651685393258427],
#  [{'No_enfermedad_corazon', 'never smoked'}, {'Si_ACV'}, 1.0],
#  [{'never smoked'}, {'Si_ACV'}, 1.0],
#  [{'Diabetes'}, {'Casado'}, 0.9387755102040817],
#  [{'Diabetes'}, {'Casado', 'Si_ACV'}, 0.9387755102040817],
#  [{'Diabetes', 'Si_ACV'}, {'Casado'}, 0.9387755102040817],
#  [{'Casado', 'Diabetes'}, {'Si_ACV'}, 1.0],
#  [{'Diabetes'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension', 'Sobrepeso'}, {'Si_ACV'}, 1.0],
#  [{'Sobrepeso'}, {'No_enfermedad_corazon'}, 0.8383838383838383],
#  [{'No_enfermedad_corazon', 'Sobrepeso'}, {'Casado'}, 0.9156626506024096],
#  [{'Casado', 'Sobrepeso'}, {'No_enfermedad_corazon'}, 0.8539325842696629],
#  [{'No_enfermedad_corazon', 'Sobrepeso'},
#   {'Casado', 'Si_ACV'},
#   0.9156626506024096],
#  [{'Casado', 'Sobrepeso'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.8539325842696629],
#  [{'No_enfermedad_corazon', 'Si_ACV', 'Sobrepeso'},
#   {'Casado'},
#   0.9156626506024096],
#  [{'Casado', 'Si_ACV', 'Sobrepeso'},
#   {'No_enfermedad_corazon'},
#   0.8539325842696629],
#  [{'Casado', 'No_enfermedad_corazon', 'Sobrepeso'}, {'Si_ACV'}, 1.0],
#  [{'Sobrepeso'}, {'No_enfermedad_corazon', 'Si_ACV'}, 0.8383838383838383],
#  [{'Si_ACV', 'Sobrepeso'}, {'No_enfermedad_corazon'}, 0.8383838383838383],
#  [{'No_enfermedad_corazon', 'Sobrepeso'}, {'Si_ACV'}, 1.0],
#  [{'Sobrepeso'}, {'Casado'}, 0.898989898989899],
#  [{'Sobrepeso'}, {'Casado', 'Si_ACV'}, 0.898989898989899],
#  [{'Si_ACV', 'Sobrepeso'}, {'Casado'}, 0.898989898989899],
#  [{'Casado', 'Sobrepeso'}, {'Si_ACV'}, 1.0],
#  [{'Sobrepeso'}, {'Si_ACV'}, 1.0],
#  [{'Glucosa_normal'}, {'No_hipertension'}, 0.801980198019802],
#  [{'Glucosa_normal', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9259259259259259],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.8152173913043478],
#  [{'Glucosa_normal', 'No_hipertension'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.9259259259259259],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_hipertension', 'Si_ACV'},
#   0.8152173913043478],
#  [{'Glucosa_normal', 'No_hipertension', 'Si_ACV'},
#   {'No_enfermedad_corazon'},
#   0.9259259259259259],
#  [{'Glucosa_normal', 'No_enfermedad_corazon', 'Si_ACV'},
#   {'No_hipertension'},
#   0.8152173913043478],
#  [{'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'Si_ACV'},
#   1.0],
#  [{'Glucosa_normal'}, {'No_hipertension', 'Si_ACV'}, 0.801980198019802],
#  [{'Glucosa_normal', 'Si_ACV'}, {'No_hipertension'}, 0.801980198019802],
#  [{'Glucosa_normal', 'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'Glucosa_normal'}, {'Casado'}, 0.8316831683168316],
#  [{'Casado', 'Glucosa_normal'}, {'No_enfermedad_corazon'}, 0.9166666666666666],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'}, {'Casado'}, 0.8369565217391305],
#  [{'Casado', 'Glucosa_normal'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.9166666666666666],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'Casado', 'Si_ACV'},
#   0.8369565217391305],
#  [{'Casado', 'Glucosa_normal', 'Si_ACV'},
#   {'No_enfermedad_corazon'},
#   0.9166666666666666],
#  [{'Glucosa_normal', 'No_enfermedad_corazon', 'Si_ACV'},
#   {'Casado'},
#   0.8369565217391305],
#  [{'Casado', 'Glucosa_normal', 'No_enfermedad_corazon'}, {'Si_ACV'}, 1.0],
#  [{'Glucosa_normal'}, {'Casado', 'Si_ACV'}, 0.8316831683168316],
#  [{'Glucosa_normal', 'Si_ACV'}, {'Casado'}, 0.8316831683168316],
#  [{'Casado', 'Glucosa_normal'}, {'Si_ACV'}, 1.0],
#  [{'Glucosa_normal'}, {'No_enfermedad_corazon'}, 0.9108910891089109],
#  [{'Glucosa_normal'}, {'No_enfermedad_corazon', 'Si_ACV'}, 0.9108910891089109],
#  [{'Glucosa_normal', 'Si_ACV'}, {'No_enfermedad_corazon'}, 0.9108910891089109],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'}, {'Si_ACV'}, 1.0],
#  [{'Glucosa_normal'}, {'Si_ACV'}, 1.0],
#  [{'Vejez'}, {'No_enfermedad_corazon'}, 0.819047619047619],
#  [{'No_enfermedad_corazon', 'Vejez'}, {'Casado'}, 0.8953488372093024],
#  [{'Casado', 'Vejez'}, {'No_enfermedad_corazon'}, 0.8369565217391305],
#  [{'No_enfermedad_corazon', 'Vejez'},
#   {'Casado', 'Si_ACV'},
#   0.8953488372093024],
#  [{'Casado', 'Vejez'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.8369565217391305],
#  [{'No_enfermedad_corazon', 'Si_ACV', 'Vejez'},
#   {'Casado'},
#   0.8953488372093024],
#  [{'Casado', 'Si_ACV', 'Vejez'},
#   {'No_enfermedad_corazon'},
#   0.8369565217391305],
#  [{'Casado', 'No_enfermedad_corazon', 'Vejez'}, {'Si_ACV'}, 1.0],
#  [{'Vejez'}, {'No_enfermedad_corazon', 'Si_ACV'}, 0.819047619047619],
#  [{'Si_ACV', 'Vejez'}, {'No_enfermedad_corazon'}, 0.819047619047619],
#  [{'No_enfermedad_corazon', 'Vejez'}, {'Si_ACV'}, 1.0],
#  [{'Vejez'}, {'Casado'}, 0.8761904761904762],
#  [{'Vejez'}, {'Casado', 'Si_ACV'}, 0.8761904761904762],
#  [{'Si_ACV', 'Vejez'}, {'Casado'}, 0.8761904761904762],
#  [{'Casado', 'Vejez'}, {'Si_ACV'}, 1.0],
#  [{'Vejez'}, {'Si_ACV'}, 1.0],
#  [{'Male', 'No_enfermedad_corazon'}, {'Si_ACV'}, 1.0],
#  [{'Male', 'No_hipertension'}, {'Casado'}, 0.9375],
#  [{'Male', 'No_hipertension'}, {'Casado', 'Si_ACV'}, 0.9375],
#  [{'Male', 'No_hipertension', 'Si_ACV'}, {'Casado'}, 0.9375],
#  [{'Casado', 'Male', 'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'Male', 'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'Male'}, {'Casado'}, 0.9245283018867925],
#  [{'Male'}, {'Casado', 'Si_ACV'}, 0.9245283018867925],
#  [{'Male', 'Si_ACV'}, {'Casado'}, 0.9245283018867925],
#  [{'Casado', 'Male'}, {'Si_ACV'}, 1.0],
#  [{'Male'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension', 'Residencia_rural'}, {'Casado'}, 0.95],
#  [{'No_hipertension', 'Residencia_rural'}, {'Casado', 'Si_ACV'}, 0.95],
#  [{'No_hipertension', 'Residencia_rural', 'Si_ACV'}, {'Casado'}, 0.95],
#  [{'Casado', 'No_hipertension', 'Residencia_rural'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension', 'Residencia_rural'}, {'Si_ACV'}, 1.0],
#  [{'Residencia_rural'}, {'No_enfermedad_corazon'}, 0.8303571428571429],
#  [{'No_enfermedad_corazon', 'Residencia_rural'},
#   {'Casado'},
#   0.946236559139785],
#  [{'Casado', 'Residencia_rural'},
#   {'No_enfermedad_corazon'},
#   0.8461538461538461],
#  [{'No_enfermedad_corazon', 'Residencia_rural'},
#   {'Casado', 'Si_ACV'},
#   0.946236559139785],
#  [{'Casado', 'Residencia_rural'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.8461538461538461],
#  [{'No_enfermedad_corazon', 'Residencia_rural', 'Si_ACV'},
#   {'Casado'},
#   0.946236559139785],
#  [{'Casado', 'Residencia_rural', 'Si_ACV'},
#   {'No_enfermedad_corazon'},
#   0.8461538461538461],
#  [{'Casado', 'No_enfermedad_corazon', 'Residencia_rural'}, {'Si_ACV'}, 1.0],
#  [{'Residencia_rural'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.8303571428571429],
#  [{'Residencia_rural', 'Si_ACV'},
#   {'No_enfermedad_corazon'},
#   0.8303571428571429],
#  [{'No_enfermedad_corazon', 'Residencia_rural'}, {'Si_ACV'}, 1.0],
#  [{'Residencia_rural'}, {'Casado'}, 0.9285714285714286],
#  [{'Residencia_rural'}, {'Casado', 'Si_ACV'}, 0.9285714285714286],
#  [{'Residencia_rural', 'Si_ACV'}, {'Casado'}, 0.9285714285714286],
#  [{'Casado', 'Residencia_rural'}, {'Si_ACV'}, 1.0],
#  [{'Residencia_rural'}, {'Si_ACV'}, 1.0],
#  [{'Female', 'Residencia_urbana'}, {'Si_ACV'}, 1.0],
#  [{'Residencia_urbana', 'Trabajo_privado'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension', 'Residencia_urbana'}, {'No_enfermedad_corazon'}, 0.81],
#  [{'No_hipertension', 'Residencia_urbana'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.81],
#  [{'No_hipertension', 'Residencia_urbana', 'Si_ACV'},
#   {'No_enfermedad_corazon'},
#   0.81],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Residencia_urbana'},
#   {'Si_ACV'},
#   1.0],
#  [{'No_hipertension', 'Residencia_urbana'}, {'Casado'}, 0.86],
#  [{'No_hipertension', 'Residencia_urbana'}, {'Casado', 'Si_ACV'}, 0.86],
#  [{'No_hipertension', 'Residencia_urbana', 'Si_ACV'}, {'Casado'}, 0.86],
#  [{'Casado', 'No_hipertension', 'Residencia_urbana'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension', 'Residencia_urbana'}, {'Si_ACV'}, 1.0],
#  [{'No_enfermedad_corazon', 'Residencia_urbana'},
#   {'Casado'},
#   0.839622641509434],
#  [{'No_enfermedad_corazon', 'Residencia_urbana'},
#   {'Casado', 'Si_ACV'},
#   0.839622641509434],
#  [{'No_enfermedad_corazon', 'Residencia_urbana', 'Si_ACV'},
#   {'Casado'},
#   0.839622641509434],
#  [{'Casado', 'No_enfermedad_corazon', 'Residencia_urbana'}, {'Si_ACV'}, 1.0],
#  [{'No_enfermedad_corazon', 'Residencia_urbana'}, {'Si_ACV'}, 1.0],
#  [{'Residencia_urbana'}, {'Casado'}, 0.8421052631578947],
#  [{'Residencia_urbana'}, {'Casado', 'Si_ACV'}, 0.8421052631578947],
#  [{'Residencia_urbana', 'Si_ACV'}, {'Casado'}, 0.8421052631578947],
#  [{'Casado', 'Residencia_urbana'}, {'Si_ACV'}, 1.0],
#  [{'Residencia_urbana'}, {'Si_ACV'}, 1.0],
#  [{'Female', 'Trabajo_privado'}, {'Si_ACV'}, 1.0],
#  [{'Female', 'No_hipertension'}, {'Casado'}, 0.87],
#  [{'Female', 'No_enfermedad_corazon', 'No_hipertension'}, {'Casado'}, 0.875],
#  [{'Casado', 'Female', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.8850574712643678],
#  [{'Female', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'Casado', 'Si_ACV'},
#   0.875],
#  [{'Casado', 'Female', 'No_hipertension'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.8850574712643678],
#  [{'Female', 'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'},
#   {'Casado'},
#   0.875],
#  [{'Casado', 'Female', 'No_hipertension', 'Si_ACV'},
#   {'No_enfermedad_corazon'},
#   0.8850574712643678],
#  [{'Casado', 'Female', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'Si_ACV'},
#   1.0],
#  [{'Female', 'No_hipertension'}, {'Casado', 'Si_ACV'}, 0.87],
#  [{'Female', 'No_hipertension', 'Si_ACV'}, {'Casado'}, 0.87],
#  [{'Casado', 'Female', 'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'Female', 'No_hipertension'}, {'No_enfermedad_corazon'}, 0.88],
#  [{'Female', 'No_hipertension'}, {'No_enfermedad_corazon', 'Si_ACV'}, 0.88],
#  [{'Female', 'No_hipertension', 'Si_ACV'}, {'No_enfermedad_corazon'}, 0.88],
#  [{'Female', 'No_enfermedad_corazon', 'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'Female', 'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'Female'}, {'Casado'}, 0.8489208633093526],
#  [{'Casado', 'Female'}, {'No_enfermedad_corazon'}, 0.8813559322033898],
#  [{'Female', 'No_enfermedad_corazon'}, {'Casado'}, 0.8666666666666667],
#  [{'Casado', 'Female'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.8813559322033898],
#  [{'Female', 'No_enfermedad_corazon'},
#   {'Casado', 'Si_ACV'},
#   0.8666666666666667],
#  [{'Casado', 'Female', 'Si_ACV'},
#   {'No_enfermedad_corazon'},
#   0.8813559322033898],
#  [{'Female', 'No_enfermedad_corazon', 'Si_ACV'},
#   {'Casado'},
#   0.8666666666666667],
#  [{'Casado', 'Female', 'No_enfermedad_corazon'}, {'Si_ACV'}, 1.0],
#  [{'Female'}, {'Casado', 'Si_ACV'}, 0.8489208633093526],
#  [{'Female', 'Si_ACV'}, {'Casado'}, 0.8489208633093526],
#  [{'Casado', 'Female'}, {'Si_ACV'}, 1.0],
#  [{'Female'}, {'No_enfermedad_corazon'}, 0.8633093525179856],
#  [{'Female'}, {'No_enfermedad_corazon', 'Si_ACV'}, 0.8633093525179856],
#  [{'Female', 'Si_ACV'}, {'No_enfermedad_corazon'}, 0.8633093525179856],
#  [{'Female', 'No_enfermedad_corazon'}, {'Si_ACV'}, 1.0],
#  [{'Female'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.8053097345132744],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#   {'Casado'},
#   0.9230769230769231],
#  [{'Casado', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.8076923076923077],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#   {'Casado', 'Si_ACV'},
#   0.9230769230769231],
#  [{'Casado', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension', 'Si_ACV'},
#   0.8076923076923077],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV', 'Trabajo_privado'},
#   {'Casado'},
#   0.9230769230769231],
#  [{'Casado', 'No_enfermedad_corazon', 'Si_ACV', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.8076923076923077],
#  [{'Casado', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#   {'Si_ACV'},
#   1.0],
#  [{'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.8053097345132744],
#  [{'No_hipertension', 'Si_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.8053097345132744],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#   {'Si_ACV'},
#   1.0],
#  [{'No_hipertension', 'Trabajo_privado'}, {'Casado'}, 0.9292035398230089],
#  [{'No_hipertension', 'Trabajo_privado'},
#   {'Casado', 'Si_ACV'},
#   0.9292035398230089],
#  [{'No_hipertension', 'Si_ACV', 'Trabajo_privado'},
#   {'Casado'},
#   0.9292035398230089],
#  [{'Casado', 'No_hipertension', 'Trabajo_privado'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension', 'Trabajo_privado'}, {'Si_ACV'}, 1.0],
#  [{'No_enfermedad_corazon', 'Trabajo_privado'}, {'Casado'}, 0.896551724137931],
#  [{'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'Casado', 'Si_ACV'},
#   0.896551724137931],
#  [{'No_enfermedad_corazon', 'Si_ACV', 'Trabajo_privado'},
#   {'Casado'},
#   0.896551724137931],
#  [{'Casado', 'No_enfermedad_corazon', 'Trabajo_privado'}, {'Si_ACV'}, 1.0],
#  [{'No_enfermedad_corazon', 'Trabajo_privado'}, {'Si_ACV'}, 1.0],
#  [{'Trabajo_privado'}, {'Casado'}, 0.9041095890410958],
#  [{'Trabajo_privado'}, {'Casado', 'Si_ACV'}, 0.9041095890410958],
#  [{'Si_ACV', 'Trabajo_privado'}, {'Casado'}, 0.9041095890410958],
#  [{'Casado', 'Trabajo_privado'}, {'Si_ACV'}, 1.0],
#  [{'Trabajo_privado'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension'}, {'No_enfermedad_corazon'}, 0.8166666666666667],
#  [{'No_enfermedad_corazon', 'No_hipertension'},
#   {'Casado'},
#   0.8979591836734694],
#  [{'Casado', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.8148148148148148],
#  [{'No_enfermedad_corazon', 'No_hipertension'},
#   {'Casado', 'Si_ACV'},
#   0.8979591836734694],
#  [{'Casado', 'No_hipertension'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.8148148148148148],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'},
#   {'Casado'},
#   0.8979591836734694],
#  [{'Casado', 'No_hipertension', 'Si_ACV'},
#   {'No_enfermedad_corazon'},
#   0.8148148148148148],
#  [{'Casado', 'No_enfermedad_corazon', 'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.8166666666666667],
#  [{'No_hipertension', 'Si_ACV'},
#   {'No_enfermedad_corazon'},
#   0.8166666666666667],
#  [{'No_enfermedad_corazon', 'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension'}, {'Casado'}, 0.9],
#  [{'No_hipertension'}, {'Casado', 'Si_ACV'}, 0.9],
#  [{'No_hipertension', 'Si_ACV'}, {'Casado'}, 0.9],
#  [{'Casado', 'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'No_enfermedad_corazon'}, {'Casado'}, 0.8894472361809045],
#  [{'Casado'}, {'No_enfermedad_corazon'}, 0.8194444444444444],
#  [{'No_enfermedad_corazon'}, {'Casado', 'Si_ACV'}, 0.8894472361809045],
#  [{'Casado'}, {'No_enfermedad_corazon', 'Si_ACV'}, 0.8194444444444444],
#  [{'No_enfermedad_corazon', 'Si_ACV'}, {'Casado'}, 0.8894472361809045],
#  [{'Casado', 'Si_ACV'}, {'No_enfermedad_corazon'}, 0.8194444444444444],
#  [{'Casado', 'No_enfermedad_corazon'}, {'Si_ACV'}, 1.0],
#  [{'Si_ACV'}, {'No_enfermedad_corazon'}, 0.8122448979591836],
#  [{'No_enfermedad_corazon'}, {'Si_ACV'}, 1.0],
#  [{'Si_ACV'}, {'Casado'}, 0.8816326530612245],
#  [{'Casado'}, {'Si_ACV'}, 1.0]]

# %%
reglas_fpgrowth = pd.DataFrame(rules_fpgrowth, columns = ['Antecedente', 'Consecuente', 'Confianza'])
pd.set_option('display.max_columns', 254)
reglas_fpgrowth
# Out:
#                          Antecedente              Consecuente  Confianza
# 0                     {never smoked}                 {Casado}   0.831461
# 1                     {never smoked}         {Si_ACV, Casado}   0.831461
# 2             {Si_ACV, never smoked}                 {Casado}   0.831461
# 3             {Casado, never smoked}                 {Si_ACV}   1.000000
# 4                     {never smoked}  {No_enfermedad_corazon}   0.865169
# ..                               ...                      ...        ...
# 208  {No_enfermedad_corazon, Casado}                 {Si_ACV}   1.000000
# 209                         {Si_ACV}  {No_enfermedad_corazon}   0.812245
# 210          {No_enfermedad_corazon}                 {Si_ACV}   1.000000
# 211                         {Si_ACV}                 {Casado}   0.881633
# 212                         {Casado}                 {Si_ACV}   1.000000
#
# [213 rows x 3 columns]

# %% [markdown]
# {Vejez} -> {Si_ACV}
#
# {Female, Trabajo_privado} -> {Si_ACV}
#
# {Residencia_urbana} -> {Si_ACV}
#
# {No_enfermedad_corazon, No_hipertension} -> {Si_ACV}
#
# {Sobrepeso} -> {Si_ACV}
#
# {Casado, Si_enfermedad_corazon} -> {Si_ACV}
#
# {Diabetes} -> {Si_ACV}
#
# {Casado, Si_enfermedad_corazon, Residencia_urbana} -> {Si_ACV}
#
# {Female, Residencia_urbana} -> {Si_ACV}
#
# {Si_hipertension, Vejez} -> {Si_ACV}

# %% [markdown]
# Para encontrar reglas de asociación más fuertes, se sube el soporte al 50% con una confianza del 80%.

# %%
itemsets_fpgrowth, rules_fpgrowth = fpgrowth(datos_Si_ACV, minSupRatio=0.5, minConf=0.8)
itemsets_fpgrowth
# Out:
# [{'Residencia_urbana'},
#  {'Residencia_urbana', 'Si_ACV'},
#  {'Female'},
#  {'Female', 'Si_ACV'},
#  {'Trabajo_privado'},
#  {'Casado', 'Trabajo_privado'},
#  {'Casado', 'Si_ACV', 'Trabajo_privado'},
#  {'Si_ACV', 'Trabajo_privado'},
#  {'No_hipertension'},
#  {'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'},
#  {'Casado', 'No_hipertension'},
#  {'Casado', 'No_hipertension', 'Si_ACV'},
#  {'No_hipertension', 'Si_ACV'},
#  {'No_enfermedad_corazon'},
#  {'Casado', 'No_enfermedad_corazon'},
#  {'Casado', 'No_enfermedad_corazon', 'Si_ACV'},
#  {'No_enfermedad_corazon', 'Si_ACV'},
#  {'Casado'},
#  {'Casado', 'Si_ACV'},
#  {'Si_ACV'}]

# %%
rules_fpgrowth
# Out:
# [[{'Residencia_urbana'}, {'Si_ACV'}, 1.0],
#  [{'Female'}, {'Si_ACV'}, 1.0],
#  [{'Trabajo_privado'}, {'Casado'}, 0.9041095890410958],
#  [{'Trabajo_privado'}, {'Casado', 'Si_ACV'}, 0.9041095890410958],
#  [{'Si_ACV', 'Trabajo_privado'}, {'Casado'}, 0.9041095890410958],
#  [{'Casado', 'Trabajo_privado'}, {'Si_ACV'}, 1.0],
#  [{'Trabajo_privado'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension'}, {'No_enfermedad_corazon'}, 0.8166666666666667],
#  [{'No_enfermedad_corazon', 'No_hipertension'},
#   {'Casado'},
#   0.8979591836734694],
#  [{'Casado', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.8148148148148148],
#  [{'No_enfermedad_corazon', 'No_hipertension'},
#   {'Casado', 'Si_ACV'},
#   0.8979591836734694],
#  [{'Casado', 'No_hipertension'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.8148148148148148],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Si_ACV'},
#   {'Casado'},
#   0.8979591836734694],
#  [{'Casado', 'No_hipertension', 'Si_ACV'},
#   {'No_enfermedad_corazon'},
#   0.8148148148148148],
#  [{'Casado', 'No_enfermedad_corazon', 'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension'},
#   {'No_enfermedad_corazon', 'Si_ACV'},
#   0.8166666666666667],
#  [{'No_hipertension', 'Si_ACV'},
#   {'No_enfermedad_corazon'},
#   0.8166666666666667],
#  [{'No_enfermedad_corazon', 'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension'}, {'Casado'}, 0.9],
#  [{'No_hipertension'}, {'Casado', 'Si_ACV'}, 0.9],
#  [{'No_hipertension', 'Si_ACV'}, {'Casado'}, 0.9],
#  [{'Casado', 'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'No_hipertension'}, {'Si_ACV'}, 1.0],
#  [{'No_enfermedad_corazon'}, {'Casado'}, 0.8894472361809045],
#  [{'Casado'}, {'No_enfermedad_corazon'}, 0.8194444444444444],
#  [{'No_enfermedad_corazon'}, {'Casado', 'Si_ACV'}, 0.8894472361809045],
#  [{'Casado'}, {'No_enfermedad_corazon', 'Si_ACV'}, 0.8194444444444444],
#  [{'No_enfermedad_corazon', 'Si_ACV'}, {'Casado'}, 0.8894472361809045],
#  [{'Casado', 'Si_ACV'}, {'No_enfermedad_corazon'}, 0.8194444444444444],
#  [{'Casado', 'No_enfermedad_corazon'}, {'Si_ACV'}, 1.0],
#  [{'Si_ACV'}, {'No_enfermedad_corazon'}, 0.8122448979591836],
#  [{'No_enfermedad_corazon'}, {'Si_ACV'}, 1.0],
#  [{'Si_ACV'}, {'Casado'}, 0.8816326530612245],
#  [{'Casado'}, {'Si_ACV'}, 1.0]]

# %%
reglas_fpgrowth = pd.DataFrame(rules_fpgrowth, columns = ['Antecedente', 'Consecuente', 'Confianza'])
pd.set_option('display.max_columns', 254)
reglas_fpgrowth
# Out:
#                                          Antecedente  \
# 0                                {Residencia_urbana}
# 1                                           {Female}
# 2                                  {Trabajo_privado}
# 3                                  {Trabajo_privado}
# 4                          {Trabajo_privado, Si_ACV}
# 5                          {Trabajo_privado, Casado}
# 6                                  {Trabajo_privado}
# 7                                  {No_hipertension}
# 8           {No_hipertension, No_enfermedad_corazon}
# 9                          {No_hipertension, Casado}
# 10          {No_hipertension, No_enfermedad_corazon}
# 11                         {No_hipertension, Casado}
# 12  {No_hipertension, Si_ACV, No_enfermedad_corazon}
# 13                 {No_hipertension, Si_ACV, Casado}
# 14  {No_hipertension, No_enfermedad_corazon, Casado}
# 15                                 {No_hipertension}
# 16                         {No_hipertension, Si_ACV}
# 17          {No_hipertension, No_enfermedad_corazon}
# 18                                 {No_hipertension}
# 19                                 {No_hipertension}
# 20                         {No_hipertension, Si_ACV}
# 21                         {No_hipertension, Casado}
# 22                                 {No_hipertension}
# 23                           {No_enfermedad_corazon}
# 24                                          {Casado}
# 25                           {No_enfermedad_corazon}
# 26                                          {Casado}
# 27                   {Si_ACV, No_enfermedad_corazon}
# 28                                  {Si_ACV, Casado}
# 29                   {No_enfermedad_corazon, Casado}
# 30                                          {Si_ACV}
# 31                           {No_enfermedad_corazon}
# 32                                          {Si_ACV}
# 33                                          {Casado}
#
#                         Consecuente  Confianza
# 0                          {Si_ACV}   1.000000
# 1                          {Si_ACV}   1.000000
# 2                          {Casado}   0.904110
# 3                  {Si_ACV, Casado}   0.904110
# 4                          {Casado}   0.904110
# 5                          {Si_ACV}   1.000000
# 6                          {Si_ACV}   1.000000
# 7           {No_enfermedad_corazon}   0.816667
# 8                          {Casado}   0.897959
# 9           {No_enfermedad_corazon}   0.814815
# 10                 {Si_ACV, Casado}   0.897959
# 11  {Si_ACV, No_enfermedad_corazon}   0.814815
# 12                         {Casado}   0.897959
# 13          {No_enfermedad_corazon}   0.814815
# 14                         {Si_ACV}   1.000000
# 15  {Si_ACV, No_enfermedad_corazon}   0.816667
# 16          {No_enfermedad_corazon}   0.816667
# 17                         {Si_ACV}   1.000000
# 18                         {Casado}   0.900000
# 19                 {Si_ACV, Casado}   0.900000
# 20                         {Casado}   0.900000
# 21                         {Si_ACV}   1.000000
# 22                         {Si_ACV}   1.000000
# 23                         {Casado}   0.889447
# 24          {No_enfermedad_corazon}   0.819444
# 25                 {Si_ACV, Casado}   0.889447
# 26  {Si_ACV, No_enfermedad_corazon}   0.819444
# 27                         {Casado}   0.889447
# 28          {No_enfermedad_corazon}   0.819444
# 29                         {Si_ACV}   1.000000
# 30          {No_enfermedad_corazon}   0.812245
# 31                         {Si_ACV}   1.000000
# 32                         {Casado}   0.881633
# 33                         {Si_ACV}   1.000000

# %% [markdown]
# Se destacan las siguientes reglas:

# %% [markdown]
# {Residencia_urbana} -> {Si_ACV}
#
# {Female} -> {Si_ACV}
#
# {Trabajo_privado, Casado} -> {Si_ACV}
#
# {Casado, Si_enfermedad_corazon} -> {Si_ACV}
#
# {No_enfermedad_corazon, No_hipertension} -> {Si_ACV}
#
# {No_hipertension, No_enfermedad_corazon, Casado} -> {Si_ACV}

# %% [markdown]
# ### 10.1.2) Asociación para la clase No_ACV

# %%
itemsets_fpgrowth, rules_fpgrowth = fpgrowth(datos_No_ACV, minSupRatio=0.3, minConf=0.8)
itemsets_fpgrowth
# Out:
# [{'Unknown'},
#  {'No_ACV', 'Unknown'},
#  {'No_casado'},
#  {'No_casado', 'No_hipertension'},
#  {'No_casado', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'No_ACV', 'No_casado', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'No_ACV', 'No_casado', 'No_hipertension'},
#  {'No_casado', 'No_enfermedad_corazon'},
#  {'No_ACV', 'No_casado', 'No_enfermedad_corazon'},
#  {'No_ACV', 'No_casado'},
#  {'never smoked'},
#  {'No_hipertension', 'never smoked'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'never smoked'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension', 'never smoked'},
#  {'No_ACV', 'No_hipertension', 'never smoked'},
#  {'No_enfermedad_corazon', 'never smoked'},
#  {'No_ACV', 'No_enfermedad_corazon', 'never smoked'},
#  {'No_ACV', 'never smoked'},
#  {'Male'},
#  {'Male', 'No_hipertension'},
#  {'Male', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Male', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Male', 'No_ACV', 'No_hipertension'},
#  {'Male', 'No_enfermedad_corazon'},
#  {'Male', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Male', 'No_ACV'},
#  {'Residencia_rural'},
#  {'Casado', 'Residencia_rural'},
#  {'Casado', 'No_ACV', 'Residencia_rural'},
#  {'No_hipertension', 'Residencia_rural'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Residencia_rural'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension', 'Residencia_rural'},
#  {'No_ACV', 'No_hipertension', 'Residencia_rural'},
#  {'No_enfermedad_corazon', 'Residencia_rural'},
#  {'No_ACV', 'No_enfermedad_corazon', 'Residencia_rural'},
#  {'No_ACV', 'Residencia_rural'},
#  {'Residencia_urbana'},
#  {'Casado', 'Residencia_urbana'},
#  {'Casado', 'No_enfermedad_corazon', 'Residencia_urbana'},
#  {'Casado', 'No_ACV', 'No_enfermedad_corazon', 'Residencia_urbana'},
#  {'Casado', 'No_ACV', 'Residencia_urbana'},
#  {'No_hipertension', 'Residencia_urbana'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Residencia_urbana'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension', 'Residencia_urbana'},
#  {'No_ACV', 'No_hipertension', 'Residencia_urbana'},
#  {'No_enfermedad_corazon', 'Residencia_urbana'},
#  {'No_ACV', 'No_enfermedad_corazon', 'Residencia_urbana'},
#  {'No_ACV', 'Residencia_urbana'},
#  {'Glucosa_normal'},
#  {'Glucosa_normal', 'Trabajo_privado'},
#  {'Glucosa_normal', 'No_hipertension', 'Trabajo_privado'},
#  {'Glucosa_normal', 'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#  {'Glucosa_normal', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Glucosa_normal', 'No_ACV', 'Trabajo_privado'},
#  {'Female', 'Glucosa_normal'},
#  {'Female', 'Glucosa_normal', 'No_hipertension'},
#  {'Female', 'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Female',
#   'Glucosa_normal',
#   'No_ACV',
#   'No_enfermedad_corazon',
#   'No_hipertension'},
#  {'Female', 'Glucosa_normal', 'No_ACV', 'No_hipertension'},
#  {'Female', 'Glucosa_normal', 'No_enfermedad_corazon'},
#  {'Female', 'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Female', 'Glucosa_normal', 'No_ACV'},
#  {'Casado', 'Glucosa_normal'},
#  {'Casado', 'Glucosa_normal', 'No_hipertension'},
#  {'Casado', 'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado',
#   'Glucosa_normal',
#   'No_ACV',
#   'No_enfermedad_corazon',
#   'No_hipertension'},
#  {'Casado', 'Glucosa_normal', 'No_ACV', 'No_hipertension'},
#  {'Casado', 'Glucosa_normal', 'No_enfermedad_corazon'},
#  {'Casado', 'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Casado', 'Glucosa_normal', 'No_ACV'},
#  {'Glucosa_normal', 'No_hipertension'},
#  {'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Glucosa_normal', 'No_ACV', 'No_hipertension'},
#  {'Glucosa_normal', 'No_enfermedad_corazon'},
#  {'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Glucosa_normal', 'No_ACV'},
#  {'Trabajo_privado'},
#  {'Female', 'Trabajo_privado'},
#  {'Female', 'No_hipertension', 'Trabajo_privado'},
#  {'Female', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#  {'Female',
#   'No_ACV',
#   'No_enfermedad_corazon',
#   'No_hipertension',
#   'Trabajo_privado'},
#  {'Female', 'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#  {'Female', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Female', 'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Female', 'No_ACV', 'Trabajo_privado'},
#  {'Casado', 'Trabajo_privado'},
#  {'Casado', 'No_hipertension', 'Trabajo_privado'},
#  {'Casado', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#  {'Casado',
#   'No_ACV',
#   'No_enfermedad_corazon',
#   'No_hipertension',
#   'Trabajo_privado'},
#  {'Casado', 'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#  {'Casado', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Casado', 'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'Casado', 'No_ACV', 'Trabajo_privado'},
#  {'No_hipertension', 'Trabajo_privado'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#  {'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#  {'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'No_ACV', 'Trabajo_privado'},
#  {'Female'},
#  {'Casado', 'Female'},
#  {'Casado', 'Female', 'No_hipertension'},
#  {'Casado', 'Female', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'Female', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'Female', 'No_ACV', 'No_hipertension'},
#  {'Casado', 'Female', 'No_enfermedad_corazon'},
#  {'Casado', 'Female', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Casado', 'Female', 'No_ACV'},
#  {'Female', 'No_hipertension'},
#  {'Female', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Female', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Female', 'No_ACV', 'No_hipertension'},
#  {'Female', 'No_enfermedad_corazon'},
#  {'Female', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Female', 'No_ACV'},
#  {'Casado'},
#  {'Casado', 'No_hipertension'},
#  {'Casado', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'No_ACV', 'No_hipertension'},
#  {'Casado', 'No_enfermedad_corazon'},
#  {'Casado', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Casado', 'No_ACV'},
#  {'No_hipertension'},
#  {'No_enfermedad_corazon', 'No_hipertension'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'No_ACV', 'No_hipertension'},
#  {'No_enfermedad_corazon'},
#  {'No_ACV', 'No_enfermedad_corazon'},
#  {'No_ACV'}]

# %%
rules_fpgrowth
# Out:
# [[{'Unknown'}, {'No_ACV'}, 1.0],
#  [{'No_casado'}, {'No_hipertension'}, 0.9764414135151891],
#  [{'No_casado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.9646621202727836],
#  [{'No_casado', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9879365079365079],
#  [{'No_casado', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9792322215229704],
#  [{'No_casado'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.9646621202727836],
#  [{'No_ACV', 'No_casado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.9646621202727836],
#  [{'No_casado', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9879365079365079],
#  [{'No_casado', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.9792322215229704],
#  [{'No_ACV', 'No_casado', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9879365079365079],
#  [{'No_ACV', 'No_casado', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9792322215229704],
#  [{'No_casado', 'No_enfermedad_corazon', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'No_casado'}, {'No_ACV', 'No_hipertension'}, 0.9764414135151891],
#  [{'No_ACV', 'No_casado'}, {'No_hipertension'}, 0.9764414135151891],
#  [{'No_casado', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'No_casado'}, {'No_enfermedad_corazon'}, 0.9851208927464352],
#  [{'No_casado'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.9851208927464352],
#  [{'No_ACV', 'No_casado'}, {'No_enfermedad_corazon'}, 0.9851208927464352],
#  [{'No_casado', 'No_enfermedad_corazon'}, {'No_ACV'}, 1.0],
#  [{'No_casado'}, {'No_ACV'}, 1.0],
#  [{'never smoked'}, {'No_hipertension'}, 0.8901035673187572],
#  [{'never smoked'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.857307249712313],
#  [{'No_hipertension', 'never smoked'},
#   {'No_enfermedad_corazon'},
#   0.9631544925662573],
#  [{'No_enfermedad_corazon', 'never smoked'},
#   {'No_hipertension'},
#   0.8965102286401926],
#  [{'never smoked'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.857307249712313],
#  [{'No_ACV', 'never smoked'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.857307249712313],
#  [{'No_hipertension', 'never smoked'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9631544925662573],
#  [{'No_enfermedad_corazon', 'never smoked'},
#   {'No_ACV', 'No_hipertension'},
#   0.8965102286401926],
#  [{'No_ACV', 'No_hipertension', 'never smoked'},
#   {'No_enfermedad_corazon'},
#   0.9631544925662573],
#  [{'No_ACV', 'No_enfermedad_corazon', 'never smoked'},
#   {'No_hipertension'},
#   0.8965102286401926],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'never smoked'},
#   {'No_ACV'},
#   1.0],
#  [{'never smoked'}, {'No_ACV', 'No_hipertension'}, 0.8901035673187572],
#  [{'No_ACV', 'never smoked'}, {'No_hipertension'}, 0.8901035673187572],
#  [{'No_hipertension', 'never smoked'}, {'No_ACV'}, 1.0],
#  [{'never smoked'}, {'No_enfermedad_corazon'}, 0.956271576524741],
#  [{'never smoked'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.956271576524741],
#  [{'No_ACV', 'never smoked'}, {'No_enfermedad_corazon'}, 0.956271576524741],
#  [{'No_enfermedad_corazon', 'never smoked'}, {'No_ACV'}, 1.0],
#  [{'never smoked'}, {'No_ACV'}, 1.0],
#  [{'Male'}, {'No_hipertension'}, 0.9027055150884495],
#  [{'Male'}, {'No_enfermedad_corazon', 'No_hipertension'}, 0.8475546305931322],
#  [{'Male', 'No_hipertension'}, {'No_enfermedad_corazon'}, 0.9389048991354467],
#  [{'Male', 'No_enfermedad_corazon'}, {'No_hipertension'}, 0.9115836597649692],
#  [{'Male'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8475546305931322],
#  [{'Male', 'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8475546305931322],
#  [{'Male', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9389048991354467],
#  [{'Male', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.9115836597649692],
#  [{'Male', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9389048991354467],
#  [{'Male', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9115836597649692],
#  [{'Male', 'No_enfermedad_corazon', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Male'}, {'No_ACV', 'No_hipertension'}, 0.9027055150884495],
#  [{'Male', 'No_ACV'}, {'No_hipertension'}, 0.9027055150884495],
#  [{'Male', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Male'}, {'No_enfermedad_corazon'}, 0.9297606659729448],
#  [{'Male'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.9297606659729448],
#  [{'Male', 'No_ACV'}, {'No_enfermedad_corazon'}, 0.9297606659729448],
#  [{'Male', 'No_enfermedad_corazon'}, {'No_ACV'}, 1.0],
#  [{'Male'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'Residencia_rural'}, {'No_ACV'}, 1.0],
#  [{'Residencia_rural'}, {'No_hipertension'}, 0.9098432055749129],
#  [{'Residencia_rural'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8719512195121951],
#  [{'No_hipertension', 'Residencia_rural'},
#   {'No_enfermedad_corazon'},
#   0.9583532790809],
#  [{'No_enfermedad_corazon', 'Residencia_rural'},
#   {'No_hipertension'},
#   0.9179275561668959],
#  [{'Residencia_rural'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8719512195121951],
#  [{'No_ACV', 'Residencia_rural'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8719512195121951],
#  [{'No_hipertension', 'Residencia_rural'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9583532790809],
#  [{'No_enfermedad_corazon', 'Residencia_rural'},
#   {'No_ACV', 'No_hipertension'},
#   0.9179275561668959],
#  [{'No_ACV', 'No_hipertension', 'Residencia_rural'},
#   {'No_enfermedad_corazon'},
#   0.9583532790809],
#  [{'No_ACV', 'No_enfermedad_corazon', 'Residencia_rural'},
#   {'No_hipertension'},
#   0.9179275561668959],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Residencia_rural'},
#   {'No_ACV'},
#   1.0],
#  [{'Residencia_rural'}, {'No_ACV', 'No_hipertension'}, 0.9098432055749129],
#  [{'No_ACV', 'Residencia_rural'}, {'No_hipertension'}, 0.9098432055749129],
#  [{'No_hipertension', 'Residencia_rural'}, {'No_ACV'}, 1.0],
#  [{'Residencia_rural'}, {'No_enfermedad_corazon'}, 0.9499128919860628],
#  [{'Residencia_rural'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9499128919860628],
#  [{'No_ACV', 'Residencia_rural'},
#   {'No_enfermedad_corazon'},
#   0.9499128919860628],
#  [{'No_enfermedad_corazon', 'Residencia_rural'}, {'No_ACV'}, 1.0],
#  [{'Residencia_rural'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'Residencia_urbana'},
#   {'No_enfermedad_corazon'},
#   0.9363344051446946],
#  [{'Casado', 'Residencia_urbana'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9363344051446946],
#  [{'Casado', 'No_ACV', 'Residencia_urbana'},
#   {'No_enfermedad_corazon'},
#   0.9363344051446946],
#  [{'Casado', 'No_enfermedad_corazon', 'Residencia_urbana'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'Residencia_urbana'}, {'No_ACV'}, 1.0],
#  [{'Residencia_urbana'}, {'No_hipertension'}, 0.9134860050890585],
#  [{'Residencia_urbana'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8753180661577609],
#  [{'No_hipertension', 'Residencia_urbana'},
#   {'No_enfermedad_corazon'},
#   0.958217270194986],
#  [{'No_enfermedad_corazon', 'Residencia_urbana'},
#   {'No_hipertension'},
#   0.9193763919821827],
#  [{'Residencia_urbana'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8753180661577609],
#  [{'No_ACV', 'Residencia_urbana'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8753180661577609],
#  [{'No_hipertension', 'Residencia_urbana'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.958217270194986],
#  [{'No_enfermedad_corazon', 'Residencia_urbana'},
#   {'No_ACV', 'No_hipertension'},
#   0.9193763919821827],
#  [{'No_ACV', 'No_hipertension', 'Residencia_urbana'},
#   {'No_enfermedad_corazon'},
#   0.958217270194986],
#  [{'No_ACV', 'No_enfermedad_corazon', 'Residencia_urbana'},
#   {'No_hipertension'},
#   0.9193763919821827],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Residencia_urbana'},
#   {'No_ACV'},
#   1.0],
#  [{'Residencia_urbana'}, {'No_ACV', 'No_hipertension'}, 0.9134860050890585],
#  [{'No_ACV', 'Residencia_urbana'}, {'No_hipertension'}, 0.9134860050890585],
#  [{'No_hipertension', 'Residencia_urbana'}, {'No_ACV'}, 1.0],
#  [{'Residencia_urbana'}, {'No_enfermedad_corazon'}, 0.952078032230704],
#  [{'Residencia_urbana'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.952078032230704],
#  [{'No_ACV', 'Residencia_urbana'},
#   {'No_enfermedad_corazon'},
#   0.952078032230704],
#  [{'No_enfermedad_corazon', 'Residencia_urbana'}, {'No_ACV'}, 1.0],
#  [{'Residencia_urbana'}, {'No_ACV'}, 1.0],
#  [{'Glucosa_normal', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.9330682571239232],
#  [{'Glucosa_normal', 'Trabajo_privado'},
#   {'No_ACV', 'No_hipertension'},
#   0.9330682571239232],
#  [{'Glucosa_normal', 'No_ACV', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.9330682571239232],
#  [{'Glucosa_normal', 'No_hipertension', 'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Glucosa_normal', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9675281643472499],
#  [{'Glucosa_normal', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9675281643472499],
#  [{'Glucosa_normal', 'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9675281643472499],
#  [{'Glucosa_normal', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_ACV'},
#   1.0],
#  [{'Glucosa_normal', 'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Female', 'Glucosa_normal'}, {'No_hipertension'}, 0.9407979407979408],
#  [{'Female', 'Glucosa_normal'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.9221364221364221],
#  [{'Female', 'Glucosa_normal', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9801641586867305],
#  [{'Female', 'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9427631578947369],
#  [{'Female', 'Glucosa_normal'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.9221364221364221],
#  [{'Female', 'Glucosa_normal', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9801641586867305],
#  [{'Female', 'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.9427631578947369],
#  [{'Female', 'Glucosa_normal', 'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.9221364221364221],
#  [{'Female', 'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'No_ACV'},
#   1.0],
#  [{'Female', 'Glucosa_normal', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9801641586867305],
#  [{'Female', 'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9427631578947369],
#  [{'Female', 'Glucosa_normal'},
#   {'No_ACV', 'No_hipertension'},
#   0.9407979407979408],
#  [{'Female', 'Glucosa_normal', 'No_ACV'},
#   {'No_hipertension'},
#   0.9407979407979408],
#  [{'Female', 'Glucosa_normal', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Female', 'Glucosa_normal'}, {'No_enfermedad_corazon'}, 0.9781209781209781],
#  [{'Female', 'Glucosa_normal'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9781209781209781],
#  [{'Female', 'Glucosa_normal', 'No_ACV'},
#   {'No_enfermedad_corazon'},
#   0.9781209781209781],
#  [{'Female', 'Glucosa_normal', 'No_enfermedad_corazon'}, {'No_ACV'}, 1.0],
#  [{'Female', 'Glucosa_normal'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'Glucosa_normal'}, {'No_hipertension'}, 0.9026171637248935],
#  [{'Casado', 'Glucosa_normal'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8557516737674985],
#  [{'Casado', 'Glucosa_normal', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9480782198246797],
#  [{'Casado', 'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9059278350515464],
#  [{'Casado', 'Glucosa_normal'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8557516737674985],
#  [{'Casado', 'Glucosa_normal', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9480782198246797],
#  [{'Casado', 'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.9059278350515464],
#  [{'Casado', 'Glucosa_normal', 'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8557516737674985],
#  [{'Casado', 'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'No_ACV'},
#   1.0],
#  [{'Casado', 'Glucosa_normal', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9480782198246797],
#  [{'Casado', 'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9059278350515464],
#  [{'Casado', 'Glucosa_normal'},
#   {'No_ACV', 'No_hipertension'},
#   0.9026171637248935],
#  [{'Casado', 'Glucosa_normal', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'Glucosa_normal', 'No_ACV'},
#   {'No_hipertension'},
#   0.9026171637248935],
#  [{'Casado', 'Glucosa_normal'}, {'No_enfermedad_corazon'}, 0.9446135118685332],
#  [{'Casado', 'Glucosa_normal'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9446135118685332],
#  [{'Casado', 'Glucosa_normal', 'No_ACV'},
#   {'No_enfermedad_corazon'},
#   0.9446135118685332],
#  [{'Casado', 'Glucosa_normal', 'No_enfermedad_corazon'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'Glucosa_normal'}, {'No_ACV'}, 1.0],
#  [{'Glucosa_normal'}, {'No_hipertension'}, 0.930609097918273],
#  [{'Glucosa_normal'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.89745566692367],
#  [{'Glucosa_normal', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9643744821872411],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9341894060995185],
#  [{'Glucosa_normal'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.89745566692367],
#  [{'Glucosa_normal', 'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.89745566692367],
#  [{'Glucosa_normal', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9643744821872411],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.9341894060995185],
#  [{'Glucosa_normal', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9643744821872411],
#  [{'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9341894060995185],
#  [{'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'No_ACV'},
#   1.0],
#  [{'Glucosa_normal'}, {'No_ACV', 'No_hipertension'}, 0.930609097918273],
#  [{'Glucosa_normal', 'No_ACV'}, {'No_hipertension'}, 0.930609097918273],
#  [{'Glucosa_normal', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Glucosa_normal'}, {'No_enfermedad_corazon'}, 0.9606784888203547],
#  [{'Glucosa_normal'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.9606784888203547],
#  [{'Glucosa_normal', 'No_ACV'}, {'No_enfermedad_corazon'}, 0.9606784888203547],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'}, {'No_ACV'}, 1.0],
#  [{'Glucosa_normal'}, {'No_ACV'}, 1.0],
#  [{'Female', 'Trabajo_privado'}, {'No_hipertension'}, 0.9195544554455446],
#  [{'Female', 'Trabajo_privado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8941831683168316],
#  [{'Female', 'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9724091520861373],
#  [{'Female', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.9262820512820513],
#  [{'Female', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8941831683168316],
#  [{'Female', 'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9724091520861373],
#  [{'Female', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_ACV', 'No_hipertension'},
#   0.9262820512820513],
#  [{'Female', 'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8941831683168316],
#  [{'Female', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV'},
#   1.0],
#  [{'Female', 'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9724091520861373],
#  [{'Female', 'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.9262820512820513],
#  [{'Female', 'Trabajo_privado'},
#   {'No_ACV', 'No_hipertension'},
#   0.9195544554455446],
#  [{'Female', 'No_ACV', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.9195544554455446],
#  [{'Female', 'No_hipertension', 'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Female', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9653465346534653],
#  [{'Female', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9653465346534653],
#  [{'Female', 'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9653465346534653],
#  [{'Female', 'No_enfermedad_corazon', 'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Female', 'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'Trabajo_privado'}, {'No_hipertension'}, 0.8890633176347462],
#  [{'Casado', 'Trabajo_privado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8445839874411303],
#  [{'Casado', 'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.949970570924073],
#  [{'Casado', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.8981636060100167],
#  [{'Casado', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8445839874411303],
#  [{'Casado', 'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.949970570924073],
#  [{'Casado', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_ACV', 'No_hipertension'},
#   0.8981636060100167],
#  [{'Casado', 'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8445839874411303],
#  [{'Casado', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV'},
#   1.0],
#  [{'Casado', 'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.949970570924073],
#  [{'Casado', 'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.8981636060100167],
#  [{'Casado', 'Trabajo_privado'},
#   {'No_ACV', 'No_hipertension'},
#   0.8890633176347462],
#  [{'Casado', 'No_ACV', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.8890633176347462],
#  [{'Casado', 'No_hipertension', 'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9403453689167975],
#  [{'Casado', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9403453689167975],
#  [{'Casado', 'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9403453689167975],
#  [{'Casado', 'No_enfermedad_corazon', 'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Trabajo_privado'}, {'No_hipertension'}, 0.9116555308092057],
#  [{'Trabajo_privado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.876391982182628],
#  [{'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9613192182410424],
#  [{'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.919392523364486],
#  [{'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.876391982182628],
#  [{'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.876391982182628],
#  [{'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9613192182410424],
#  [{'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_ACV', 'No_hipertension'},
#   0.919392523364486],
#  [{'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9613192182410424],
#  [{'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.919392523364486],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV'},
#   1.0],
#  [{'Trabajo_privado'}, {'No_ACV', 'No_hipertension'}, 0.9116555308092057],
#  [{'No_ACV', 'Trabajo_privado'}, {'No_hipertension'}, 0.9116555308092057],
#  [{'No_hipertension', 'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Trabajo_privado'}, {'No_enfermedad_corazon'}, 0.9532293986636972],
#  [{'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9532293986636972],
#  [{'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9532293986636972],
#  [{'No_enfermedad_corazon', 'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'Female'}, {'No_hipertension'}, 0.8883388338833883],
#  [{'Casado', 'Female'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8547854785478548],
#  [{'Casado', 'Female', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9622291021671827],
#  [{'Casado', 'Female', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.8946459412780656],
#  [{'Casado', 'Female'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8547854785478548],
#  [{'Casado', 'Female', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9622291021671827],
#  [{'Casado', 'Female', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.8946459412780656],
#  [{'Casado', 'Female', 'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8547854785478548],
#  [{'Casado', 'Female', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'No_ACV'},
#   1.0],
#  [{'Casado', 'Female', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9622291021671827],
#  [{'Casado', 'Female', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.8946459412780656],
#  [{'Casado', 'Female'}, {'No_ACV', 'No_hipertension'}, 0.8883388338833883],
#  [{'Casado', 'Female', 'No_ACV'}, {'No_hipertension'}, 0.8883388338833883],
#  [{'Casado', 'Female', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'Female'}, {'No_enfermedad_corazon'}, 0.9554455445544554],
#  [{'Casado', 'Female'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9554455445544554],
#  [{'Casado', 'Female', 'No_ACV'},
#   {'No_enfermedad_corazon'},
#   0.9554455445544554],
#  [{'Casado', 'Female', 'No_enfermedad_corazon'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'Female'}, {'No_ACV'}, 1.0],
#  [{'Female'}, {'No_hipertension'}, 0.91800878477306],
#  [{'Female'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8920204978038068],
#  [{'Female', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9716905901116427],
#  [{'Female', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9234558544903373],
#  [{'Female'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.8920204978038068],
#  [{'Female', 'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8920204978038068],
#  [{'Female', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9716905901116427],
#  [{'Female', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.9234558544903373],
#  [{'Female', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9716905901116427],
#  [{'Female', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9234558544903373],
#  [{'Female', 'No_enfermedad_corazon', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Female'}, {'No_ACV', 'No_hipertension'}, 0.91800878477306],
#  [{'Female', 'No_ACV'}, {'No_hipertension'}, 0.91800878477306],
#  [{'Female', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Female'}, {'No_enfermedad_corazon'}, 0.9659590043923866],
#  [{'Female'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.9659590043923866],
#  [{'Female', 'No_ACV'}, {'No_enfermedad_corazon'}, 0.9659590043923866],
#  [{'Female', 'No_enfermedad_corazon'}, {'No_ACV'}, 1.0],
#  [{'Female'}, {'No_ACV'}, 1.0],
#  [{'Casado'}, {'No_hipertension'}, 0.8773429792831305],
#  [{'Casado'}, {'No_enfermedad_corazon', 'No_hipertension'}, 0.825386386057218],
#  [{'Casado', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9407796101949025],
#  [{'Casado', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.8847373986605569],
#  [{'Casado'},
#   {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#   0.825386386057218],
#  [{'Casado', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9407796101949025],
#  [{'Casado', 'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.825386386057218],
#  [{'Casado', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.8847373986605569],
#  [{'Casado', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9407796101949025],
#  [{'Casado', 'No_enfermedad_corazon', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.8847373986605569],
#  [{'Casado'}, {'No_ACV', 'No_hipertension'}, 0.8773429792831305],
#  [{'Casado', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'No_ACV'}, {'No_hipertension'}, 0.8773429792831305],
#  [{'Casado'}, {'No_enfermedad_corazon'}, 0.932916803682999],
#  [{'Casado'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.932916803682999],
#  [{'Casado', 'No_ACV'}, {'No_enfermedad_corazon'}, 0.932916803682999],
#  [{'Casado', 'No_enfermedad_corazon'}, {'No_ACV'}, 1.0],
#  [{'Casado'}, {'No_ACV'}, 1.0],
#  [{'No_hipertension'}, {'No_enfermedad_corazon'}, 0.9582842328541127],
#  [{'No_enfermedad_corazon'}, {'No_hipertension'}, 0.9186624491640307],
#  [{'No_ACV'},
#   {'No_enfermedad_corazon', 'No_hipertension'},
#   0.8736570691877954],
#  [{'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9582842328541127],
#  [{'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.9186624491640307],
#  [{'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9582842328541127],
#  [{'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9186624491640307],
#  [{'No_enfermedad_corazon', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'No_ACV'}, {'No_hipertension'}, 0.9116888697894284],
#  [{'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'No_ACV'}, {'No_enfermedad_corazon'}, 0.9510098839707778],
#  [{'No_enfermedad_corazon'}, {'No_ACV'}, 1.0]]

# %%
reglas_fpgrowth = pd.DataFrame(rules_fpgrowth, columns = ['Antecedente', 'Consecuente', 'Confianza'])
pd.set_option('display.max_columns', 254)
reglas_fpgrowth
# Out:
#                                   Antecedente  \
# 0                                   {Unknown}
# 1                                 {No_casado}
# 2                                 {No_casado}
# 3                {No_hipertension, No_casado}
# 4          {No_enfermedad_corazon, No_casado}
# ..                                        ...
# 289  {No_hipertension, No_enfermedad_corazon}
# 290                                  {No_ACV}
# 291                         {No_hipertension}
# 292                                  {No_ACV}
# 293                   {No_enfermedad_corazon}
#
#                                   Consecuente  Confianza
# 0                                    {No_ACV}   1.000000
# 1                           {No_hipertension}   0.976441
# 2    {No_hipertension, No_enfermedad_corazon}   0.964662
# 3                     {No_enfermedad_corazon}   0.987937
# 4                           {No_hipertension}   0.979232
# ..                                        ...        ...
# 289                                  {No_ACV}   1.000000
# 290                         {No_hipertension}   0.911689
# 291                                  {No_ACV}   1.000000
# 292                   {No_enfermedad_corazon}   0.951010
# 293                                  {No_ACV}   1.000000
#
# [294 rows x 3 columns]

# %% [markdown]
# {No_casado, No_hipertension} -> {No_ACV}
#
# {No_hipertension, Residencia_rural} -> {No_ACV}
#
# {Casado, Glucosa_normal, No_enfermedad_corazon} -> {No_ACV}
#
# {No_casado, No_enfermedad_corazon, No_hipertension} -> {No_ACV}
#
# {Male, No_enfermedad_corazon, No_hipertension} -> {No_ACV}
#
# {Male, No_hipertension} -> {No_ACV}
#
# {No_enfermedad_corazon, never smoked} -> {No_ACV}
#
# {Casado, Residencia_rural} -> {No_ACV}
#
# {No_enfermedad_corazon, Trabajo_privado} -> {No_ACV}
#
# {Female, No_enfermedad_corazon, No_hipertension, Trabajo_privado} -> {No_ACV}
#
# {Casado, No_hipertension, Trabajo_privado} -> {No_ACV}

# %% [markdown]
# Con el fin de encontrar solo las reglas de asociación más fuertes, se sube el soporte al 50% con una confianza del 90%

# %%
itemsets_fpgrowth, rules_fpgrowth = fpgrowth(datos_No_ACV, minSupRatio=0.5, minConf=0.9)
itemsets_fpgrowth
# Out:
# [{'Residencia_urbana'},
#  {'No_ACV', 'Residencia_urbana'},
#  {'Glucosa_normal'},
#  {'Glucosa_normal', 'No_hipertension'},
#  {'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Glucosa_normal', 'No_ACV', 'No_hipertension'},
#  {'Glucosa_normal', 'No_enfermedad_corazon'},
#  {'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Glucosa_normal', 'No_ACV'},
#  {'Trabajo_privado'},
#  {'No_hipertension', 'Trabajo_privado'},
#  {'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#  {'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#  {'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#  {'No_ACV', 'Trabajo_privado'},
#  {'Female'},
#  {'Female', 'No_hipertension'},
#  {'Female', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Female', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Female', 'No_ACV', 'No_hipertension'},
#  {'Female', 'No_enfermedad_corazon'},
#  {'Female', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Female', 'No_ACV'},
#  {'Casado'},
#  {'Casado', 'No_hipertension'},
#  {'Casado', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'Casado', 'No_ACV', 'No_hipertension'},
#  {'Casado', 'No_enfermedad_corazon'},
#  {'Casado', 'No_ACV', 'No_enfermedad_corazon'},
#  {'Casado', 'No_ACV'},
#  {'No_hipertension'},
#  {'No_enfermedad_corazon', 'No_hipertension'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'No_ACV', 'No_hipertension'},
#  {'No_enfermedad_corazon'},
#  {'No_ACV', 'No_enfermedad_corazon'},
#  {'No_ACV'}]

# %%
rules_fpgrowth
# Out:
# [[{'Residencia_urbana'}, {'No_ACV'}, 1.0],
#  [{'Glucosa_normal'}, {'No_hipertension'}, 0.930609097918273],
#  [{'Glucosa_normal', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9643744821872411],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9341894060995185],
#  [{'Glucosa_normal', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9643744821872411],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.9341894060995185],
#  [{'Glucosa_normal', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9643744821872411],
#  [{'Glucosa_normal', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9341894060995185],
#  [{'Glucosa_normal', 'No_enfermedad_corazon', 'No_hipertension'},
#   {'No_ACV'},
#   1.0],
#  [{'Glucosa_normal'}, {'No_ACV', 'No_hipertension'}, 0.930609097918273],
#  [{'Glucosa_normal', 'No_ACV'}, {'No_hipertension'}, 0.930609097918273],
#  [{'Glucosa_normal', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Glucosa_normal'}, {'No_enfermedad_corazon'}, 0.9606784888203547],
#  [{'Glucosa_normal'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.9606784888203547],
#  [{'Glucosa_normal', 'No_ACV'}, {'No_enfermedad_corazon'}, 0.9606784888203547],
#  [{'Glucosa_normal', 'No_enfermedad_corazon'}, {'No_ACV'}, 1.0],
#  [{'Glucosa_normal'}, {'No_ACV'}, 1.0],
#  [{'Trabajo_privado'}, {'No_hipertension'}, 0.9116555308092057],
#  [{'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9613192182410424],
#  [{'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.919392523364486],
#  [{'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9613192182410424],
#  [{'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_ACV', 'No_hipertension'},
#   0.919392523364486],
#  [{'No_ACV', 'No_hipertension', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9613192182410424],
#  [{'No_ACV', 'No_enfermedad_corazon', 'Trabajo_privado'},
#   {'No_hipertension'},
#   0.919392523364486],
#  [{'No_enfermedad_corazon', 'No_hipertension', 'Trabajo_privado'},
#   {'No_ACV'},
#   1.0],
#  [{'Trabajo_privado'}, {'No_ACV', 'No_hipertension'}, 0.9116555308092057],
#  [{'No_ACV', 'Trabajo_privado'}, {'No_hipertension'}, 0.9116555308092057],
#  [{'No_hipertension', 'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Trabajo_privado'}, {'No_enfermedad_corazon'}, 0.9532293986636972],
#  [{'Trabajo_privado'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9532293986636972],
#  [{'No_ACV', 'Trabajo_privado'},
#   {'No_enfermedad_corazon'},
#   0.9532293986636972],
#  [{'No_enfermedad_corazon', 'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Trabajo_privado'}, {'No_ACV'}, 1.0],
#  [{'Female'}, {'No_hipertension'}, 0.91800878477306],
#  [{'Female', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9716905901116427],
#  [{'Female', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9234558544903373],
#  [{'Female', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9716905901116427],
#  [{'Female', 'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.9234558544903373],
#  [{'Female', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9716905901116427],
#  [{'Female', 'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9234558544903373],
#  [{'Female', 'No_enfermedad_corazon', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Female'}, {'No_ACV', 'No_hipertension'}, 0.91800878477306],
#  [{'Female', 'No_ACV'}, {'No_hipertension'}, 0.91800878477306],
#  [{'Female', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Female'}, {'No_enfermedad_corazon'}, 0.9659590043923866],
#  [{'Female'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.9659590043923866],
#  [{'Female', 'No_ACV'}, {'No_enfermedad_corazon'}, 0.9659590043923866],
#  [{'Female', 'No_enfermedad_corazon'}, {'No_ACV'}, 1.0],
#  [{'Female'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9407796101949025],
#  [{'Casado', 'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9407796101949025],
#  [{'Casado', 'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9407796101949025],
#  [{'Casado', 'No_enfermedad_corazon', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Casado', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'Casado'}, {'No_enfermedad_corazon'}, 0.932916803682999],
#  [{'Casado'}, {'No_ACV', 'No_enfermedad_corazon'}, 0.932916803682999],
#  [{'Casado', 'No_ACV'}, {'No_enfermedad_corazon'}, 0.932916803682999],
#  [{'Casado', 'No_enfermedad_corazon'}, {'No_ACV'}, 1.0],
#  [{'Casado'}, {'No_ACV'}, 1.0],
#  [{'No_hipertension'}, {'No_enfermedad_corazon'}, 0.9582842328541127],
#  [{'No_enfermedad_corazon'}, {'No_hipertension'}, 0.9186624491640307],
#  [{'No_hipertension'},
#   {'No_ACV', 'No_enfermedad_corazon'},
#   0.9582842328541127],
#  [{'No_enfermedad_corazon'},
#   {'No_ACV', 'No_hipertension'},
#   0.9186624491640307],
#  [{'No_ACV', 'No_hipertension'},
#   {'No_enfermedad_corazon'},
#   0.9582842328541127],
#  [{'No_ACV', 'No_enfermedad_corazon'},
#   {'No_hipertension'},
#   0.9186624491640307],
#  [{'No_enfermedad_corazon', 'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'No_ACV'}, {'No_hipertension'}, 0.9116888697894284],
#  [{'No_hipertension'}, {'No_ACV'}, 1.0],
#  [{'No_ACV'}, {'No_enfermedad_corazon'}, 0.9510098839707778],
#  [{'No_enfermedad_corazon'}, {'No_ACV'}, 1.0]]

# %%
reglas_fpgrowth = pd.DataFrame(rules_fpgrowth, columns = ['Antecedente', 'Consecuente', 'Confianza'])
pd.set_option('display.max_columns', 254)
reglas_fpgrowth
# Out:
#                                  Antecedente                      Consecuente  \
# 0                        {Residencia_urbana}                         {No_ACV}
# 1                           {Glucosa_normal}                {No_hipertension}
# 2          {No_hipertension, Glucosa_normal}          {No_enfermedad_corazon}
# 3    {No_enfermedad_corazon, Glucosa_normal}                {No_hipertension}
# 4          {No_hipertension, Glucosa_normal}  {No_ACV, No_enfermedad_corazon}
# ..                                       ...                              ...
# 65  {No_hipertension, No_enfermedad_corazon}                         {No_ACV}
# 66                                  {No_ACV}                {No_hipertension}
# 67                         {No_hipertension}                         {No_ACV}
# 68                                  {No_ACV}          {No_enfermedad_corazon}
# 69                   {No_enfermedad_corazon}                         {No_ACV}
#
#     Confianza
# 0    1.000000
# 1    0.930609
# 2    0.964374
# 3    0.934189
# 4    0.964374
# ..        ...
# 65   1.000000
# 66   0.911689
# 67   1.000000
# 68   0.951010
# 69   1.000000
#
# [70 rows x 3 columns]

# %% [markdown]
# Se destacan las siguientes reglas:
#
# {Glucosa_normal, No_enfermedad_corazon, No_hipertension} -> {No_ACV}
#
# {Casado, No_enfermedad_corazon, No_hipertension} -> {No_ACV}
#
# {No_enfermedad_corazon, No_hipertension, Trabajo_privado} -> {No_ACV}

# %% [markdown]
# ### 10.1.3) Uso del algoritmo con ambas clases

# %% [markdown]
# Finalmente, para encontrar las mejores reglas se establece un valor umbral de 60% para el soporte y 90% para la confianza.

# %%
itemsets_fpgrowth, rules_fpgrowth = fpgrowth(datos_asociacion_lista, minSupRatio=0.6, minConf=0.9)
itemsets_fpgrowth
# Out:
# [{'Casado'},
#  {'Casado', 'No_enfermedad_corazon'},
#  {'Casado', 'No_ACV'},
#  {'No_hipertension'},
#  {'No_enfermedad_corazon', 'No_hipertension'},
#  {'No_ACV', 'No_enfermedad_corazon', 'No_hipertension'},
#  {'No_ACV', 'No_hipertension'},
#  {'No_enfermedad_corazon'},
#  {'No_ACV', 'No_enfermedad_corazon'},
#  {'No_ACV'}]

# %%
reglas_fpgrowth = pd.DataFrame(rules_fpgrowth, columns = ['Antecedente', 'Consecuente', 'Confianza'])
pd.set_option('display.max_columns', 254)
reglas_fpgrowth
# Out:
#                                  Antecedente                      Consecuente  \
# 0                                   {Casado}          {No_enfermedad_corazon}
# 1                                   {Casado}                         {No_ACV}
# 2                    {No_enfermedad_corazon}                {No_hipertension}
# 3                          {No_hipertension}          {No_enfermedad_corazon}
# 4                          {No_hipertension}  {No_enfermedad_corazon, No_ACV}
# 5            {No_enfermedad_corazon, No_ACV}                {No_hipertension}
# 6   {No_enfermedad_corazon, No_hipertension}                         {No_ACV}
# 7                  {No_ACV, No_hipertension}          {No_enfermedad_corazon}
# 8                                   {No_ACV}                {No_hipertension}
# 9                          {No_hipertension}                         {No_ACV}
# 10                   {No_enfermedad_corazon}                         {No_ACV}
# 11                                  {No_ACV}          {No_enfermedad_corazon}
#
#     Confianza
# 0    0.925391
# 1    0.933681
# 2    0.910919
# 3    0.952521
# 4    0.919286
# 5    0.918662
# 6    0.965108
# 7    0.958284
# 8    0.911689
# 9    0.959304
# 10   0.956973
# 11   0.951010

# %% [markdown]
# De las anteriores reglas se destacan las siguientes:
#
#
# {No_enfermedad_corazon}	-> {No_hipertension}
#
# {No_hipertension} -> {No_enfermedad_corazon}
#
# {No_enfermedad_corazon, No_ACV}	-> {No_hipertension}
#
# {No_enfermedad_corazon, No_hipertension} -> {No_ACV}
#
# {No_ACV, No_hipertension} -> {No_enfermedad_corazon} *** buena regla
#
# {No_hipertension} -> {No_ACV}
#
# {No_enfermedad_corazon} -> {No_ACV}
#
# {No_ACV, No_hipertension} -> {No_enfermedad_corazon}
#
#
# Estas reglas están soportadas por valores de soporte y confianza altos. La regla más importante es {No_enfermedad_corazon, No_hipertension} -> {No_ACV}, y con ella se podría prepecir si la persona no ha sufrido accidente cerebro-vascular.
#
# Otras reglas interesantes son {No_hipertension} -> {No_enfermedad_corazon}, {No_enfermedad_corazon} -> {No_hipertension} y
# {No_ACV, No_enfermedad_corazon} -> {No_hipertension}

# %% [markdown]
# ## 10.2) Comparativa de rendimiento de los algoritmos

# %% [markdown]
# Los algoritmos usados para hacer la extracción de reglas interesantes tuvieron un desempeño esperado y fue buena la búsqueda de dichas reglas. En este orden de ideas, la utilización de un algoritmo u otro es indiferente en cuanto a la calidad de la extracción de reglas.
#
# Sin embargo, se prefiere hacer uso del algoritmo FP-Growth ya que este consume menos recursos computacionales y el tiempo de ejecución es menor comparado con el algoritmo Apriori.

# %% [markdown]
# # 11) Aplicación de algoritmos de agrupación

# %% [markdown]
# ## 11.1) K-means

# %% [markdown]
# Es bien sabido que K-means requiere como parámetro el número de clusters; en esta aplicación existen dos valores para la clase, No_ACV y Si_ACV, así que K = 2 y no hace falta realizar una gráfica del codo para determinar el valor de K.
#
# Como datos de entrada se utilizan aquellos quer fueron reducidos de dimensionalidad por PCA a una dimensión igual a 7, y a partir de ahora se utilizará dicho conjunto de datos ya procesado.

# %%
from sklearn import cluster
datos_reducidos = datos_pca.copy()
k_means = cluster.KMeans(n_clusters=2, max_iter=10000, random_state=1 , algorithm = 'elkan', n_init = 30)
k_means.fit(datos_reducidos) 
etiquetas = k_means.labels_
from collections import Counter
Counter(etiquetas)
# Out:
# Counter({0: 3257, 1: 1642})

# %% [markdown]
# Luego se construye un dataframe con el cual podemos visualizar las agrupaciones que realizó K-means comparadas con la clase de accidente cerebro-vascular.

# %%
clase = datos_numericos['stroke'].tolist()
resultados_kmeans = pd.DataFrame(clase, columns=['ACV'])
resultados_kmeans = resultados_kmeans.assign(Prediccion_ACV = lambda x: etiquetas)
resultados_kmeans
# Out:
#       ACV  Prediccion_ACV
# 0     1.0               0
# 1     1.0               0
# 2     1.0               0
# 3     1.0               0
# 4     1.0               0
# ...   ...             ...
# 4894  0.0               1
# 4895  0.0               0
# 4896  0.0               0
# 4897  0.0               0
# 4898  0.0               0
#
# [4899 rows x 2 columns]

# %%
centroids = k_means.cluster_centers_
centroids
# Out:
# array([[-0.36901927,  0.02629955,  0.0358726 , -0.06509119, -0.02988791,
#         -0.02655505, -0.01161134],
#        [ 0.73197062, -0.05216665, -0.07115533,  0.12911205,  0.05928437,
#          0.05267345,  0.02303174]])

# %% [markdown]
# Ahora se procede a realizar el proceso de validación. Primeramente se realiza el cálculo de medidas de validación internas.

# %% [markdown]
# ### 11.1.1) Coeficiente de Silouette

# %%
from sklearn import metrics
coeficiente_silhouette = metrics.silhouette_score(datos_reducidos, etiquetas, metric='euclidean')
print("Coeficiente de Silhouette: "+ str(coeficiente_silhouette))
# Out:
# Coeficiente de Silhouette: 0.27705012289104897

# %% [markdown]
# Se obtiene un coeficiente de Silhouette de 0.277, lo que indica que hay cierta tendencia a la indiferencia en los resultados de la agrupación. Es decir que dichos resultados no son ni buenos ni malos.

# %%
from yellowbrick.cluster import SilhouetteVisualizer
visualizer = SilhouetteVisualizer(k_means, colors='yellowbrick')
visualizer.fit(datos_reducidos)
plt.plot()
# Out:
# []

# %% [markdown]
# Se puede apreciar un desbalanceo en el tamaño de los grupos.

# %% [markdown]
# ### 11.1.2) Índice Davies-Bouldin

# %%
from sklearn.metrics import davies_bouldin_score
db = davies_bouldin_score(datos_reducidos, etiquetas)
print("Índice de Davies Bouldin: "+str(db))
# Out:
# Índice de Davies Bouldin: 1.592848583993158

# %% [markdown]
# Se obtiene un valor de 1.59. Dicho valor no es cercano a cero, por tanto la agrupación no es la mejor; adicionalmente, este valor no es muy grande, así que la agrupación no es del todo mala. Se concluye que es indiferente la agrupación realizada con k-means.

# %% [markdown]
# ### 11.1.3) Precision

# %% [markdown]
# Se elabora una función que calcula los valores de precision y recall.

# %%
def precision_recall(clase_supervision,clase_generada):
    VP = 0
    FP = 0
    FN = 0
    VN = 0
    total = len(clase_supervision)
    for i in range(0,total):
        if clase_generada[i] == 1:
            if clase_supervision[i] == 1:
                VP = VP+1
                #print("VP:    clase_supervision: "+str(clase_supervision[i])+" clase_generada: "+str(clase_generada[i])+"  total VP: "+str(VP))
            elif clase_supervision[i] == 0:
                FP = FP+1
                #print("FP:    clase_supervision: "+str(clase_supervision[i])+" clase_generada: "+str(clase_generada[i])+"  total FP: "+str(FP))
        elif clase_generada[i] == 0:
            if clase_supervision[i] == 1:
                FN=FN+1
                #print("FN:    clase_supervision: "+str(clase_supervision[i])+" clase_generada: "+str(clase_generada[i])+"  total FN: "+str(FN))
            elif clase_supervision[i] == 0:
                VN = VN+1
                #print("VN:    clase_supervision: "+str(clase_supervision[i])+" clase_generada: "+str(clase_generada[i])+"  total VN: "+str(VN))
    precision = VP/(VP+FP)
    recall = VP/(VP+FN)
    return precision,recall, VP, FP, FN, VN

# %%
precision,recall, VP, FP, FN, VN = precision_recall(clase,etiquetas)
print("Verdaderos positivos: "+str(VP))
print("Falsos positivos: "+str(FP))
print("Falsos negativos: "+str(FN))
print("Verdaderos negativos: "+str(VN))
# Out:
# Verdaderos positivos: 29
# Falsos positivos: 1613
# Falsos negativos: 216
# Verdaderos negativos: 3041

# %%
print("Precisión  "+str(precision))
# Out:
# Precisión  0.01766138855054811

# %% [markdown]
# Se obtiene un valor regular de precision, lo cual indica que hay un número no despreciable de falsos positivos resultantes de la agrupación k-means.

# %% [markdown]
# ### 11.1.4) Recall

# %%
print("Recall: "+str(recall))
# Out:
# Recall: 0.11836734693877551

# %% [markdown]
# Se obtiene un valor alto de recall, lo cual indica que la cantidad de falsos negativos es baja comparada con la cantidad de verdaderos positivos.

# %% [markdown]
# ### 11.1.5) Medida F1

# %%
F1 = 2/(1/precision+1/recall)
print("Valor de medida F1 calculada a partir de los valores de precision y recall:  "+str(F1))
# Out:
# Valor de medida F1 calculada a partir de los valores de precision y recall:  0.03073661897191309

# %% [markdown]
# Se obtiene un resultado bueno, pero es posible mejorar.

# %% [markdown]
# ## 11.2) DBSCAN

# %% [markdown]
# Ahora se usará un algoritmo basado en densidad. Con dicho algoritmo se tiene la ventaja de que cualquier ruido que haya quedado en el conjunto de datos es eliminado.
#
# Sin embargo, es necesario fijar los parámetros de la distancia $\epsilon$ y el número mínimo de puntos minPoints que deben existir dentro de un círculo de radio $\epsilon$ para que un punto sea considerado como "core point". Así que primeramente se ejecuta el algoritmo k-nearest neighbor con el cual, realizando algunos cálculos, podemos saber cuál es el valor de $\epsilon$ óptimo.
#
# Después de muchas pruebas, se concluyó que el desempeño de DBSCAN es mejor cuando este usa las 10 columnas originales del conjunto de datos, comparado con el desempeño del algoritmo usando los datos reducidos a 7 columnas por PCA.
#
# Así que se trabaja con los datos sin PCA.

# %%
datos_norm = datos_normalizados.copy()
datos_norm.shape
# Out:
# (4899, 10)

# %% [markdown]
# A manera de ayuda para determinar el parámetro $\epsilon$, se ejecuta un fragmento de código con el cual se puede obtener una gráfica que estima el $\epsilon$ óptimo.

# %%
from sklearn.neighbors import NearestNeighbors
nbrs = NearestNeighbors(n_neighbors=5).fit(datos_norm)
neigh_dist, neigh_ind = nbrs.kneighbors(datos_norm)
sort_neigh_dist = np.sort(neigh_dist, axis=0)

# %%
import matplotlib.pyplot as plt
k_dist = sort_neigh_dist[:, 4]
plt.plot(k_dist)
plt.axhline(y=2.5, linewidth=1, linestyle='dashed', color='k')
plt.ylabel("k-NN distance")
plt.xlabel("Sorted observations (4th NN)")
plt.show()

# %% [markdown]
# Se observa que el punto de inflexión de la gráfica, momento justo antes de que la gráfica trace el fuerte movimiento vertical, ese es el mejor punto para el valor de $\epsilon$.
#
# Aproximadamente, $\epsilon = 0.4$
#
# Luego de ello, se procede a inicializar el algoritmo DBSCAN.

# %%
from sklearn.cluster import DBSCAN
cluster_DBSCAN = DBSCAN(eps=0.4, min_samples=4, metric = 'euclidean').fit(datos_norm)
etiquetas = cluster_DBSCAN.labels_
from collections import Counter
Counter(etiquetas)
# Out:
# Counter({0: 59,
#          1: 48,
#          2: 844,
#          3: 100,
#          4: 520,
#          5: 9,
#          6: 438,
#          -1: 150,
#          7: 21,
#          8: 68,
#          10: 786,
#          11: 105,
#          9: 491,
#          12: 328,
#          13: 336,
#          14: 85,
#          15: 35,
#          21: 7,
#          16: 440,
#          23: 3,
#          18: 9,
#          19: 4,
#          20: 5,
#          17: 4,
#          22: 4})

# %% [markdown]
# Se crea una gran cantidad de clusters que, podrían representar clasificaciones de los pacientes no vienen al caso de la predicción de existencia de ACV. Con pruebas de ensayo y error se logra obtener 2 clusters para valores $\epsilon = 1.0055$ y min_samples = 100.

# %%
cluster_DBSCAN = DBSCAN(eps=1.0055, min_samples=100, metric = 'euclidean').fit(datos_norm)
etiquetas = cluster_DBSCAN.labels_
from collections import Counter
Counter(etiquetas)
# Out:
# Counter({0: 4635, -1: 264})

# %%
T = len(etiquetas)
for i in range (0,T):
    if etiquetas[i] == -1:
        etiquetas[i] = 1
Counter(etiquetas)
# Out:
# Counter({0: 4635, 1: 264})

# %%
clase = datos_numericos['stroke'].tolist()
resultados_DBSCAN = pd.DataFrame(clase, columns=['ACV'])
resultados_DBSCAN = resultados_DBSCAN.assign(Prediccion_ACV = lambda x: etiquetas)
resultados_DBSCAN
# Out:
#       ACV  Prediccion_ACV
# 0     1.0               0
# 1     1.0               1
# 2     1.0               0
# 3     1.0               0
# 4     1.0               0
# ...   ...             ...
# 4894  0.0               0
# 4895  0.0               0
# 4896  0.0               0
# 4897  0.0               0
# 4898  0.0               0
#
# [4899 rows x 2 columns]

# %% [markdown]
# Ahora se procede a realizar el proceso de validación. Primeramente se realiza el cálculo de medidas de validación internas.

# %% [markdown]
# ### 11.2.1) Coeficiente de Silhouette

# %%
coeficiente_silhouette = metrics.silhouette_score(datos_norm, etiquetas, metric='euclidean')
print("Coeficiente de Silhouette: "+ str(coeficiente_silhouette))
# Out:
# Coeficiente de Silhouette: 0.19188666153424477

# %% [markdown]
# Se obtiene un coeficiente de Silhouette de 0.19. Dicho valor es cercano a 0, lo cual indica que los resultados del proceso de clustering son indiferentes, es decir ni buenos ni malos.

# %% [markdown]
# #### 11.2.2) Índice Davies-Bouldin

# %%
db = davies_bouldin_score(datos_norm, etiquetas)
print("Índice de Davies Bouldin: "+str(db))
# Out:
# Índice de Davies Bouldin: 2.3967597156492295

# %% [markdown]
# Se obtiene un valor de 2.39. Dicho valor no es cercano a cero, por tanto la agrupación no es la mejor; adicionalmente, este valor no es muy grande, así que la agrupación no es del todo mala. Se concluye que es indiferente la agrupación realizada con DBSCAN.

# %% [markdown]
# ### 11.2.3) ´Precision

# %% [markdown]
# Ahora se realizarán los cálculos para medidas de validación externas como lo son precision, recall, F1. Así que se hará uso de una función que realiza estos cálculos.

# %%
precision,recall, VP, FP, FN, VN = precision_recall(clase,etiquetas)
print("Verdaderos positivos: "+str(VP))
print("Falsos positivos: "+str(FP))
print("Falsos negativos: "+str(FN))
print("Verdaderos negativos: "+str(VN))
# Out:
# Verdaderos positivos: 48
# Falsos positivos: 216
# Falsos negativos: 197
# Verdaderos negativos: 4438

# %%
print("Precisión  "+str(precision))
# Out:
# Precisión  0.18181818181818182

# %% [markdown]
# Se obtiene un valor de precision del 18.2%, el cual indica gran cantidad de falsos positivos.

# %% [markdown]
# ### 11.2.4) Recall

# %%
print("Recall: "+str(recall))
# Out:
# Recall: 0.19591836734693877

# %% [markdown]
# Se tiene un valor de 19.6%, el cual es un valor bajo del cual se infiere que hay gran presencia de falsos negativos.

# %% [markdown]
# ### 11.2.5) Medida F1

# %%
F1 = 2/(1/precision+1/recall)
print("Valor de medida F1 calculada a partir de los valores de precision y recall:  "+str(F1))
# Out:
# Valor de medida F1 calculada a partir de los valores de precision y recall:  0.1886051080550098

# %%
coeficiente_silhouette = metrics.silhouette_score(datos_norm, etiquetas, metric='euclidean')
print("Coeficiente de Silhouette: "+ str(coeficiente_silhouette))
db = davies_bouldin_score(datos_norm, etiquetas)
print("Índice de Davies Bouldin: "+str(db))
precision,recall, VP, FP, FN, VN = precision_recall(clase,etiquetas)
print("Verdaderos positivos: "+str(VP))
print("Falsos positivos: "+str(FP))
print("Falsos negativos: "+str(FN))
print("Verdaderos negativos: "+str(VN))
print("Precisión  "+str(precision))
print("Recall: "+str(recall))
F1 = 2/(1/precision+1/recall)
print("Valor de medida F1: "+str(F1))
# Out:
# Coeficiente de Silhouette: 0.19188666153424477
# Índice de Davies Bouldin: 2.3967597156492295
# Verdaderos positivos: 48
# Falsos positivos: 216
# Falsos negativos: 197
# Verdaderos negativos: 4438
# Precisión  0.18181818181818182
# Recall: 0.19591836734693877
# Valor de medida F1: 0.1886051080550098

# %% [markdown]
# ### Conclusión:

# %% [markdown]
# El algoritmo tiene un desempeño malo según las medidas de validación externas; los valores de precision, recall y medida F1 son muy bajos. En adición, según medidas de validación internas, el algoritmo tiene un desempeño regular arrojando resultados de los cuales se deduce que el algoritmo es indiferente.
#
# Esto permite concluir que el algoritmo no predice bien la presencia de accidente cerero-vascular dada la información del conjunto de datos, y la calidad de los clusters es regular obteniendo valores de cohesión y separación no tan buenos.
#
# No es posible graficar los clusters pero se puede inferir que los puntos pertenecientes a un cluster no son cercanos entre sí, y los dos clusters no se encuentran lo suficientemente separados.

# %% [markdown]
# ## 11.3) OPTICS

# %% [markdown]
# Se ejecutará el algoritmo de clustering OPTICS el cual se basa en densidad y resulta ser una versión mejorada de DBSCAN ya que no se requiere realizar un ajuste fino a los parámetros. Basta con establecer un $\epsilon$ grande (es una buena práctica que este valor sea grande) y el mínimo número de puntos para los cuales es válida un área local.
#
# En este caso, max_eps = 1000 y min_samples = 800.
#
# Después de muchas pruebas, se concluyó que el desempeño de DBSCAN es mejor cuando este usa las 10 columnas originales del conjunto de datos, comparado con el desempeño del algoritmo usando los datos reducidos a 7 columnas por PCA.
#
# Así que se trabaja con los datos sin PCA.

# %%
from sklearn.cluster import OPTICS, cluster_optics_dbscan
cluster_OPTICS = OPTICS(max_eps = 1000, min_samples=800, metric = 'euclidean')
cluster_OPTICS.fit(datos_norm)
space = np.arange(len(datos_norm))
reachability = cluster_OPTICS.reachability_[cluster_OPTICS.ordering_]
etiquetas = cluster_OPTICS.labels_[cluster_OPTICS.ordering_]

# %%
Counter(etiquetas)
# Out:
# Counter({-1: 4054, 0: 845})

# %%
T = len(etiquetas)
for i in range (0,T):
    if etiquetas[i] == -1:
        etiquetas[i] = 0
    elif etiquetas[i] == 0:
        etiquetas[i] = 1
Counter(etiquetas)
# Out:
# Counter({0: 4054, 1: 845})

# %%
clase = datos_numericos['stroke'].tolist()
resultados_OPTICS = pd.DataFrame(clase, columns=['ACV'])
resultados_OPTICS = resultados_OPTICS.assign(Prediccion_ACV = lambda x: etiquetas)
resultados_OPTICS
# Out:
#       ACV  Prediccion_ACV
# 0     1.0               0
# 1     1.0               0
# 2     1.0               0
# 3     1.0               0
# 4     1.0               0
# ...   ...             ...
# 4894  0.0               0
# 4895  0.0               0
# 4896  0.0               0
# 4897  0.0               0
# 4898  0.0               0
#
# [4899 rows x 2 columns]

# %%
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
G = gridspec.GridSpec(2, 3)
ax1 = plt.subplot(G[0, :])
#ax2 = plt.subplot(G[1, 0])
#ax3 = plt.subplot(G[1, 1])
#ax4 = plt.subplot(G[1, 2])

colors = ['g.', 'r.', 'b.', 'y.', 'c.']
for klass, color in zip(range(0, 5), colors):
    Xk = space[etiquetas == klass]
    Rk = reachability[etiquetas == klass]
    ax1.plot(Xk, Rk, color, alpha=0.3)
ax1.plot(space[labels == -1], reachability[labels == -1], 'k.', alpha=0.3)
ax1.plot(space, np.full_like(space, 2., dtype=float), 'k-', alpha=0.5)
ax1.plot(space, np.full_like(space, 0.5, dtype=float), 'k-.', alpha=0.5)
ax1.set_ylabel('Reachability (epsilon distance)')
ax1.set_title('Reachability Plot')
# Out:
# Text(0.5, 1.0, 'Reachability Plot')

# %% [markdown]
# Ahora se procede a realizar el proceso de validación. Primeramente se realiza el cálculo de medidas de validación internas.

# %% [markdown]
# ### 11.3.1) Coeficiente de Silhouette

# %%
coeficiente_silhouette = metrics.silhouette_score(datos_norm, etiquetas, metric='euclidean')
print("Coeficiente de Silhouette: "+ str(coeficiente_silhouette))
# Out:
# Coeficiente de Silhouette: 0.003241785791661026

# %% [markdown]
# Se obtiene un valor cercano a cero en el coeficiente de Silhouette, lo cual indica que la agrupación es indiferente, no es buena ni mala.

# %% [markdown]
# ### 11.3.2) índice Davies-Bouldin

# %%
db = davies_bouldin_score(datos_norm, etiquetas)
print("Índice de Davies Bouldin: "+str(db))
# Out:
# Índice de Davies Bouldin: 17.277608717033253

# %% [markdown]
# Se obtiene un índice Davies-Bouldin alto, lo cual indica que el proceso de agrupación es regular y se puede mejorar.

# %% [markdown]
# ### 11.3.3) Precision

# %% [markdown]
# Ahora se realizarán los cálculos para medidas de validación externas como lo son precision, recall, F1. Así que se hará uso de una función que realiza estos cálculos.

# %%
precision,recall, VP, FP, FN, VN = precision_recall(clase,etiquetas)
print("Verdaderos positivos: "+str(VP))
print("Falsos positivos: "+str(FP))
print("Falsos negativos: "+str(FN))
print("Verdaderos negativos: "+str(VN))
# Out:
# Verdaderos positivos: 194
# Falsos positivos: 651
# Falsos negativos: 51
# Verdaderos negativos: 4003

# %%
print("Precisión  "+str(precision))
# Out:
# Precisión  0.22958579881656804

# %% [markdown]
# Se obtiene una precisión del 22.9%, el cual indica un mal desempeño del algorimto, con mucha presencia de falsos positivos.

# %% [markdown]
# ### 11.3.4) Recall

# %%
print("Recall: "+str(recall))
# Out:
# Recall: 0.7918367346938775

# %% [markdown]
# Se obtiene un valor de recall del 79%, el cual es bueno. Se puede concluir que hay pocos falsos negativos.

# %% [markdown]
# ### 11.3.5) Medida F1

# %%
F1 = 2/(1/precision+1/recall)
print("Valor de medida F1 calculada a partir de los valores de precision y recall:  "+str(F1))
# Out:
# Valor de medida F1 calculada a partir de los valores de precision y recall:  0.35596330275229354

# %%
coeficiente_silhouette = metrics.silhouette_score(datos_norm, etiquetas, metric='euclidean')
print("Coeficiente de Silhouette: "+ str(coeficiente_silhouette))
db = davies_bouldin_score(datos_norm, etiquetas)
print("Índice de Davies Bouldin: "+str(db))
precision,recall, VP, FP, FN, VN = precision_recall(clase,etiquetas)
print("Verdaderos positivos: "+str(VP))
print("Falsos positivos: "+str(FP))
print("Falsos negativos: "+str(FN))
print("Verdaderos negativos: "+str(VN))
print("Precisión  "+str(precision))
print("Recall: "+str(recall))
F1 = 2/(1/precision+1/recall)
print("Valor de medida F1: "+str(F1))
# Out:
# Coeficiente de Silhouette: 0.003241785791661026
# Índice de Davies Bouldin: 17.277608717033253
# Verdaderos positivos: 194
# Falsos positivos: 651
# Falsos negativos: 51
# Verdaderos negativos: 4003
# Precisión  0.22958579881656804
# Recall: 0.7918367346938775
# Valor de medida F1: 0.35596330275229354

# %% [markdown]
# ### Conclusión:

# %% [markdown]
# El algoritmo tiene un desempeño malo según las medidas de validación externas; los valores de precision, recall y medida F1 son muy bajos. En adición, según medidas de validación internas, el algoritmo tiene un desempeño regular arrojando resultados de los cuales se deduce que el algoritmo es indiferente.
#
# Esto permite concluir que el algoritmo no predice bien la presencia de accidente cerero-vascular dada la información del conjunto de datos, y la calidad de los clusters es regular obteniendo valores de cohesión y separación no tan buenos.
#
# No es posible graficar los clusters pero se puede inferir que los puntos pertenecientes a un cluster no son cercanos entre sí, y los dos clusters no se encuentran lo suficientemente separados.
#
# Finalmente, las medidas de validación internas son peores que en DBSCAN, pero en cuanto a validación externa es mejor OPTICS

# %% [markdown]
# # 1.4) Expectation-maximization, algoritmo de mezcla gaussiana

# %% [markdown]
# Ahora se utilizará un algoritmo basado en modelos de probabilidad, ya que con los algoritmos de partición y densidad no se obtuvieron los resultados esperados.
#
# Además, como parámetro del modelo se puede fijar el número de clusters; en esta aplicación es útil ya que la agrupación debe hacerse para Si_ACV y No_ACV.

# %%
from sklearn.mixture import GaussianMixture
from numpy import unique
gaussian_model = GaussianMixture(n_components=2)
gaussian_model.fit(datos_reducidos)
etiquetas = gaussian_model.predict(datos_reducidos)
Counter(etiquetas)
# Out:
# Counter({1: 703, 0: 4196})

# %%
T = len(etiquetas)
for i in range (0,T):
    if etiquetas[i] == 1:
        etiquetas[i] = 0
    elif etiquetas[i] == 0:
        etiquetas[i] = 1
Counter(etiquetas)
# Out:
# Counter({0: 703, 1: 4196})

# %%
clase = datos_numericos['stroke'].tolist()
resultados_EM = pd.DataFrame(clase, columns=['ACV'])
resultados_EM = resultados_EM.assign(Prediccion_ACV = lambda x: etiquetas)
resultados_EM
# Out:
#       ACV  Prediccion_ACV
# 0     1.0               0
# 1     1.0               0
# 2     1.0               1
# 3     1.0               0
# 4     1.0               1
# ...   ...             ...
# 4894  0.0               1
# 4895  0.0               1
# 4896  0.0               0
# 4897  0.0               1
# 4898  0.0               0
#
# [4899 rows x 2 columns]

# %% [markdown]
# Ahora se procede a realizar el proceso de validación. Primeramente se realiza el cálculo de medidas de validación internas.

# %% [markdown]
# ### 11.4.1) Coeficiente de Silhouette

# %%
coeficiente_silhouette = metrics.silhouette_score(datos_reducidos, etiquetas, metric='euclidean')
print("Coeficiente de Silhouette: "+ str(coeficiente_silhouette))
# Out:
# Coeficiente de Silhouette: 0.19061871023263327

# %% [markdown]
# Se obtiene un coeficiente de Silhouette pequeño y cercano a 0, lo cual indica que los resultados del proceso de clustering son indiferentes, es decir ni buenos ni malos.

# %% [markdown]
# ### 11.4.2) índice Davies-Bouldin

# %%
db = davies_bouldin_score(datos_norm, etiquetas)
print("Índice de Davies Bouldin: "+str(db))
# Out:
# Índice de Davies Bouldin: 1.6729198689071734

# %% [markdown]
# El valor obtenido no es cercano a cero, por tanto la agrupación no es la mejor; adicionalmente, este valor no es muy grande, así que la agrupación no es del todo mala.

# %% [markdown]
# ### 11.4.3) Precision

# %%
precision,recall, VP, FP, FN, VN = precision_recall(clase,etiquetas)
print("Verdaderos positivos: "+str(VP))
print("Falsos positivos: "+str(FP))
print("Falsos negativos: "+str(FN))
print("Verdaderos negativos: "+str(VN))
# Out:
# Verdaderos positivos: 146
# Falsos positivos: 4050
# Falsos negativos: 99
# Verdaderos negativos: 604

# %%
print("Precisión  "+str(precision))
# Out:
# Precisión  0.03479504289799809

# %% [markdown]
# Se obtiene un valor de precision demasiado bajo, con gran presencia de falsos positivos. Esto puede ser debido a que la cantidad de registros que son positivos en el conjunto de datos es 20 veces menor que aquellos negativos; este desbalanceo hace probable que el algoritmo tome datos con clase negativa y los agrupe en la clase positiva.

# %% [markdown]
# ### 1.4.4) Recall

# %%
print("Recall: "+str(recall))
# Out:
# Recall: 0.5959183673469388

# %% [markdown]
# Se obtiene un valor medio para esta medida, lo cual indica una igual presencia de falsos negativos comparada con la cantidad de verdaderos positivos.

# %% [markdown]
# ### 1.4.5) Medida F1

# %%
F1 = 2/(1/precision+1/recall)
print("Valor de medida F1 calculada a partir de los valores de precision y recall:  "+str(F1))
# Out:
# Valor de medida F1 calculada a partir de los valores de precision y recall:  0.06575095699166854

# %%
coeficiente_silhouette = metrics.silhouette_score(datos_norm, etiquetas, metric='euclidean')
print("Coeficiente de Silhouette: "+ str(coeficiente_silhouette))
db = davies_bouldin_score(datos_norm, etiquetas)
print("Índice de Davies Bouldin: "+str(db))
precision,recall, VP, FP, FN, VN = precision_recall(clase,etiquetas)
print("Verdaderos positivos: "+str(VP))
print("Falsos positivos: "+str(FP))
print("Falsos negativos: "+str(FN))
print("Verdaderos negativos: "+str(VN))
print("Precisión  "+str(precision))
print("Recall: "+str(recall))
F1 = 2/(1/precision+1/recall)
print("Valor de medida F1: "+str(F1))
# Out:
# Coeficiente de Silhouette: 0.1853940099849396
# Índice de Davies Bouldin: 2.399255863862991
# Verdaderos positivos: 146
# Falsos positivos: 4050
# Falsos negativos: 99
# Verdaderos negativos: 604
# Precisión  0.03479504289799809
# Recall: 0.5959183673469388
# Valor de medida F1: 0.06575095699166854

# %% [markdown]
# ### 1.4.6) Conclusión

# %% [markdown]
# El algoritmo no logró mejorar sustancialmente las medidas de validación internas, lo cual indica que la calidad de los clusters no es la mejor.
#
# En cuanto a medidas de validación externas se obtuvo un mal resultado en cuanto a precisión, sin embargo el recall no es malo, lo que significa que el algoritmo logró agrupar medianamente bien los casos en que no se tiene ACV.

# %% [markdown]
# # 1.5) Agrupamiento espectral

# %% [markdown]
# Ahora se utiliza un algoritmo basado en el uso de grafos. Esto con el fin de mejorar los resultados obtenidos con otro tipo de algoritmos.

# %%
from sklearn.cluster import SpectralClustering
spectral_cluster_model= SpectralClustering(affinity='rbf', assign_labels='kmeans', coef0=1, degree=3, eigen_solver=None, eigen_tol=0.0, gamma=1.0, kernel_params=None, n_clusters=2, n_components=None, n_init=10, n_jobs=None, n_neighbors=10, random_state=None)
etiquetas = spectral_cluster_model.fit_predict(datos_reducidos)
Counter(etiquetas)
# Out:
# Counter({0: 3366, 1: 1533})

# %%
clase = datos_numericos['stroke'].tolist()
resultados_SC = pd.DataFrame(clase, columns=['ACV'])
resultados_SC = resultados_SC.assign(Prediccion_ACV = lambda x: etiquetas)
resultados_SC
# Out:
#       ACV  Prediccion_ACV
# 0     1.0               0
# 1     1.0               0
# 2     1.0               0
# 3     1.0               0
# 4     1.0               0
# ...   ...             ...
# 4894  0.0               1
# 4895  0.0               0
# 4896  0.0               0
# 4897  0.0               0
# 4898  0.0               0
#
# [4899 rows x 2 columns]

# %%
coeficiente_silhouette = metrics.silhouette_score(datos_reducidos, etiquetas, metric='euclidean')
print("Coeficiente de Silhouette: "+ str(coeficiente_silhouette))
# Out:
# Coeficiente de Silhouette: 0.2705895110765802

# %%
db = davies_bouldin_score(datos_norm, etiquetas)
print("Índice de Davies Bouldin: "+str(db))
# Out:
# Índice de Davies Bouldin: 1.6599935445575722

# %%
precision,recall, VP, FP, FN, VN = precision_recall(clase,etiquetas)
print("Verdaderos positivos: "+str(VP))
print("Falsos positivos: "+str(FP))
print("Falsos negativos: "+str(FN))
print("Verdaderos negativos: "+str(VN))
# Out:
# Verdaderos positivos: 13
# Falsos positivos: 1520
# Falsos negativos: 232
# Verdaderos negativos: 3134

# %%
print("Precisión  "+str(precision))
# Out:
# Precisión  0.008480104370515329

# %%
print("Recall: "+str(recall))
# Out:
# Recall: 0.053061224489795916

# %%
F1 = 2/(1/precision+1/recall)
print("Valor de medida F1 calculada a partir de los valores de precision y recall:  "+str(F1))
# Out:
# Valor de medida F1 calculada a partir de los valores de precision y recall:  0.014623172103487063

# %%
coeficiente_silhouette = metrics.silhouette_score(datos_norm, etiquetas, metric='euclidean')
print("Coeficiente de Silhouette: "+ str(coeficiente_silhouette))
db = davies_bouldin_score(datos_norm, etiquetas)
print("Índice de Davies Bouldin: "+str(db))
precision,recall, VP, FP, FN, VN = precision_recall(clase,etiquetas)
print("Verdaderos positivos: "+str(VP))
print("Falsos positivos: "+str(FP))
print("Falsos negativos: "+str(FN))
print("Verdaderos negativos: "+str(VN))
print("Precisión  "+str(precision))
print("Recall: "+str(recall))
F1 = 2/(1/precision+1/recall)
print("Valor de medida F1: "+str(F1))
# Out:
# Coeficiente de Silhouette: 0.2456019677038713
# Índice de Davies Bouldin: 1.6599935445575722
# Verdaderos positivos: 13
# Falsos positivos: 1520
# Falsos negativos: 232
# Verdaderos negativos: 3134
# Precisión  0.008480104370515329
# Recall: 0.053061224489795916
# Valor de medida F1: 0.014623172103487063

# %% [markdown]
# # 1.6) Algoritmo Birch

# %% [markdown]
# Ahora se utilizará un algoritmo de agrupación jerárquica, distinto a los algoritmos anteriormente utilizados. Esto para probar si este algoritmo puede realizar una buena agrupación.

# %%
from sklearn.cluster import Birch
birch_model = Birch(threshold=1., n_clusters=2)
birch_model.fit(datos_reducidos)
etiquetas = birch_model.predict(datos_reducidos)
Counter(etiquetas)
# Out:
# Counter({0: 4434, 1: 465})

# %%
clase = datos_numericos['stroke'].tolist()
resultados_SC = pd.DataFrame(clase, columns=['ACV'])
resultados_SC = resultados_SC.assign(Prediccion_ACV = lambda x: etiquetas)
resultados_SC
# Out:
#       ACV  Prediccion_ACV
# 0     1.0               0
# 1     1.0               0
# 2     1.0               0
# 3     1.0               1
# 4     1.0               0
# ...   ...             ...
# 4894  0.0               0
# 4895  0.0               0
# 4896  0.0               1
# 4897  0.0               0
# 4898  0.0               1
#
# [4899 rows x 2 columns]

# %%
coeficiente_silhouette = metrics.silhouette_score(datos_reducidos, etiquetas, metric='euclidean')
print("Coeficiente de Silhouette: "+ str(coeficiente_silhouette))
db = davies_bouldin_score(datos_norm, etiquetas)
print("Índice de Davies Bouldin: "+str(db))
precision,recall, VP, FP, FN, VN = precision_recall(clase,etiquetas)
print("Verdaderos positivos: "+str(VP))
print("Falsos positivos: "+str(FP))
print("Falsos negativos: "+str(FN))
print("Verdaderos negativos: "+str(VN))
print("Precisión  "+str(precision))
print("Recall: "+str(recall))
F1 = 2/(1/precision+1/recall)
print("Valor de medida F1 :"+str(F1))
# Out:
# Coeficiente de Silhouette: 0.2013557154355823
# Índice de Davies Bouldin: 1.857698601263341
# Verdaderos positivos: 62
# Falsos positivos: 403
# Falsos negativos: 183
# Verdaderos negativos: 4251
# Precisión  0.13333333333333333
# Recall: 0.2530612244897959
# Valor de medida F1 :0.17464788732394365

# %% [markdown]
# ### 1.6.1) Conclusión

# %% [markdown]
# No se obtuvieron mejores resultados que los algoritmos de partición, densidad ni basados en modelos de probabilidad.

# %% [markdown]
# # 1.7) Algoritmo de agrupación aglomerativa

# %% [markdown]
# Finalmente se hace uso de este algoritmo basado en jerarquías. Se puede fijar el número de clusters y tiene pocos parámetros, lo que facilita su uso.

# %%
from sklearn.cluster import AgglomerativeClustering
agglomerative_model = AgglomerativeClustering(n_clusters=2, affinity = 'euclidean')

# asignar cada punto de datos a un grupo
etiquetas = agglomerative_model.fit_predict(datos_reducidos)
Counter(etiquetas)
# Out:
# Counter({0: 3327, 1: 1572})

# %%
clase = datos_numericos['stroke'].tolist()
resultados_SC = pd.DataFrame(clase, columns=['ACV'])
resultados_SC = resultados_SC.assign(Prediccion_ACV = lambda x: etiquetas)
resultados_SC
# Out:
#       ACV  Prediccion_ACV
# 0     1.0               0
# 1     1.0               0
# 2     1.0               0
# 3     1.0               0
# 4     1.0               0
# ...   ...             ...
# 4894  0.0               1
# 4895  0.0               0
# 4896  0.0               0
# 4897  0.0               0
# 4898  0.0               0
#
# [4899 rows x 2 columns]

# %%
coeficiente_silhouette = metrics.silhouette_score(datos_reducidos, etiquetas, metric='euclidean')
print("Coeficiente de Silhouette: "+ str(coeficiente_silhouette))
db = davies_bouldin_score(datos_norm, etiquetas)
print("Índice de Davies Bouldin: "+str(db))
precision,recall, VP, FP, FN, VN = precision_recall(clase,etiquetas)
print("Verdaderos positivos: "+str(VP))
print("Falsos positivos: "+str(FP))
print("Falsos negativos: "+str(FN))
print("Verdaderos negativos: "+str(VN))
print("Precisión  "+str(precision))
print("Recall: "+str(recall))
F1 = 2/(1/precision+1/recall)
print("Valor de medida F1: "+str(F1))
# Out:
# Coeficiente de Silhouette: 0.27220792938381894
# Índice de Davies Bouldin: 1.6624148339042972
# Verdaderos positivos: 15
# Falsos positivos: 1557
# Falsos negativos: 230
# Verdaderos negativos: 3097
# Precisión  0.009541984732824428
# Recall: 0.061224489795918366
# Valor de medida F1: 0.01651073197578426

# %% [markdown]
# ### 1.7.1) Conclusión

# %% [markdown]
# No se obtuvieron mejores resultados que los algoritmos de partición, densidad, basados en modelos de probabilidad ni los jerárquicos usados con anterioridad.
